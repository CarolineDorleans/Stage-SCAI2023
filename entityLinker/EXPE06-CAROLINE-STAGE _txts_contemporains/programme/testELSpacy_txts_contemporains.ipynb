# %% [markdown]
# 02/06/2023
# notebook
# objectif : évaluer les performances de EL sur des textes contemporains
# contexte : suite à la réunion du 02/06/2023

# %% [markdown]
# # Evaluation comparative  du système d'entity linking de SpaCy

# %%
import spacy
import glob
import pandas as pd
import os
import time
import json
from art import *

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

def stocker(chemin, contenu):
    with open(chemin, "w") as fichier:
        json.dump(contenu, fichier, indent=2)

def stocker_tex(name, contenu):
    with open(name, "w") as file:
        file.write(contenu)

def tableau(data):
    df = pd.DataFrame(data)
    table_latex = df.to_latex(index=False)
    print(table_latex)
    #stocker_tex("txts-contemporains.tex", df.to_latex(index=False))
    #stocker("txts-contemporains.json", df.to_dict('index'))

t0 = time.time()  
bilan = []
def process (texte):
    models = ["fr_core_news_sm","fr_core_news_lg","en_core_web_sm", "en_core_web_lg", "en_core_web_md"]
    for model in models :
        tprint (model, font="cybermedium")
        nlp = spacy.load(model)
        # add pipeline (declared through entry_points in setup.py)
        nlp.add_pipe("entityLinker", last=True)
        doc = nlp(texte)
        # returns all entities in the whole document
        all_linked_entities = doc._.linkedEntities
        # iterates over sentences and prints linked entities
        for ent in doc._.linkedEntities:
            bilan.append({
                "modele": model,
                "contexte" : texte,
                "url" : ent.get_url(),
                "label": ent.get_label(),
                "description" : ent.get_description(),
                "span" : ent.get_span(),
            })
    #print(bialn)
    #tableau(bilan)
    print (bilan)

# %%
def read (texte):
    models = ["fr_core_news_sm","fr_core_news_lg","en_core_web_sm", "en_core_web_lg", "en_core_web_md"]
    for model in models :
        tprint (model, font="cybermedium")
        nlp = spacy.load("en_core_web_md")
        # add pipeline (declared through entry_points in setup.py)
        nlp.add_pipe("entityLinker", last=True)
        doc = nlp(texte)
        # returns all entities in the whole document
        all_linked_entities = doc._.linkedEntities
        # iterates over sentences and prints linked entities
        for sent in doc.sents:
            sent._.linkedEntities.pretty_print()

# %% [markdown]
# ## Avec un extrait de la page Wikipédia "Discord"

# %% [markdown]
# ### En français

# %% [markdown]
# Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. "

# %%
extrait = "Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web.  "

# %%
read(extrait)
# Out:
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     ____ _  _
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      [__  |\/|
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ ___] |  |
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q115 Ethiopia                  country in East Africa                            >
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q466 World Wide Web            system of interlinked hypertext documents accessed via the Internet>
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     _    ____
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      |    | __
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ |___ |__]
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q115 Ethiopia                  country in East Africa                            >
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q466 World Wide Web            system of interlinked hypertext documents accessed via the Internet>
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      ____ _  _
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     [__  |\/|
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ ___] |  |
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q115 Ethiopia                  country in East Africa                            >
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q466 World Wide Web            system of interlinked hypertext documents accessed via the Internet>
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _    ____
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |    | __
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |___ |__]
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q115 Ethiopia                  country in East Africa                            >
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q466 World Wide Web            system of interlinked hypertext documents accessed via the Internet>
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _  _ ___
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |\/| |  \
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |  | |__/
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q183 Germany                   federal parliamentary republic in central-western Europe>
# <EntityElement: https://www.wikidata.org/wiki/Q115 Ethiopia                  country in East Africa                            >
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q466 World Wide Web            system of interlinked hypertext documents accessed via the Internet>

# %%
\footnotesize{
\begin{tabular}{|p{2cm}|p{2cm}|p{2cm}}
\hline


& span,
& label,
& définition, 
\\ \hline
de
& Germany : 
& federal parliamentary republic in central-western Europe
\\ \hline
VoIP
& Voice over IP 
& methods of delivering voice communications and multimedia over IP networks
\\ \hline
et  
    &Ethiopia
    &country in East AfricamacOS 
\\ \hline
macOS   
    & macOS 
    & operating system for Apple computers, launched in 2001 as Mac OS X
\\ \hline
Linux
    &Linux
    &operating system family that use the Linux kernel, including GNU/Linux and Android>
\\ \hline
Android 
    & Android 
    & open-source operating system for mobile devices created by Google
 \\ \hline
Web
    World Wide Web
    system of interlinked hypertext documents accessed via the Internet

    
\\ \hline
\end{tabular}}

# %%
process(extrait)
# Out:
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     ____ _  _
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      [__  |\/|
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ ___] |  |
#
#
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     _    ____
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      |    | __
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ |___ |__]
#
#
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      ____ _  _
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     [__  |\/|
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ ___] |  |
#
#
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _    ____
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |    | __
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |___ |__]
#
#
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _  _ ___
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |\/| |  \
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |  | |__/
#
#
# [{'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q22907849', 'label': 'Discord', 'description': 'instant messenging and VOIP software targeted at gamers', 'span': Discord}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q81945', 'label': 'Voice over Internet Protocol', 'description': 'commonly refers to methods of delivering voice communications and multimedia over IP networks', 'span': VoIP}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q859884', 'label': 'exploitation', 'description': 'the use of someone or something in an unjust or cruel manner', 'span': exploitation}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q1406', 'label': 'Microsoft Windows', 'description': 'family of operating systems produced for personal computers, servers, smartphones and embedded devices', 'span': Windows}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q14116', 'label': 'macOS', 'description': 'operating system for Apple computers, launched in 2001 as Mac OS X', 'span': macOS}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q388', 'label': 'Linux', 'description': 'operating system family that use the Linux kernel, including GNU/Linux and Android', 'span': Linux}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q94', 'label': 'Android', 'description': 'open-source operating system for mobile devices created by Google', 'span': Android}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q48493', 'label': 'iOS', 'description': 'mobile operating system by Apple', 'span': iOS}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iOS ainsi que sur les navigateurs web. ', 'url': 'https://www.wikidata.org/wiki/Q466', 'label': 'World Wide Web', 'description': 'system of interlinked hypertext documents accessed via the Internet', 'span': web}, {'modele': 'fr_core_news_lg', 'contexte': 'Discord est un logiciel propriétaire gratuit de VoIP et de messagerie instantanée. Il fonctionne sur les systèmes d’exploitation Windows, macOS, Linux, Android, iO ...

# %% [markdown]
# ## En anglais

# %% [markdown]
# Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.

# %%
discord = "Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers."

# %%
read(discord)
# Out:
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     ____ _  _
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      [__  |\/|
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ ___] |  |
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q16963779 instant                   an infinitesimal moment in time, a moment whose passage is instantaneous>
# <EntityElement: https://www.wikidata.org/wiki/Q241317 computing platform        hardware architecture and/or software framework   >
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q48493 iOS                       mobile operating system by Apple                  >
# <EntityElement: https://www.wikidata.org/wiki/Q64350339 iPadOS                    mobile operating system of the iPad               >
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q6368 web browser               software application for retrieving, presenting and traversing information resources on the World Wi>
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     _    ____
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      |    | __
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ |___ |__]
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q16963779 instant                   an infinitesimal moment in time, a moment whose passage is instantaneous>
# <EntityElement: https://www.wikidata.org/wiki/Q241317 computing platform        hardware architecture and/or software framework   >
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q48493 iOS                       mobile operating system by Apple                  >
# <EntityElement: https://www.wikidata.org/wiki/Q64350339 iPadOS                    mobile operating system of the iPad               >
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q6368 web browser               software application for retrieving, presenting and traversing information resources on the World Wi>
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      ____ _  _
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     [__  |\/|
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ ___] |  |
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q16963779 instant                   an infinitesimal moment in time, a moment whose passage is instantaneous>
# <EntityElement: https://www.wikidata.org/wiki/Q241317 computing platform        hardware architecture and/or software framework   >
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q48493 iOS                       mobile operating system by Apple                  >
# <EntityElement: https://www.wikidata.org/wiki/Q64350339 iPadOS                    mobile operating system of the iPad               >
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q6368 web browser               software application for retrieving, presenting and traversing information resources on the World Wi>
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _    ____
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |    | __
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |___ |__]
#
#
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q16963779 instant                   an infinitesimal moment in time, a moment whose passage is instantaneous>
# <EntityElement: https://www.wikidata.org/wiki/Q241317 computing platform        hardware architecture and/or software framework   >
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q48493 iOS                       mobile operating system by Apple                  >
# <EntityElement: https://www.wikidata.org/wiki/Q64350339 iPadOS                    mobile operating system of the iPad               >
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q6368 web browser               software application for retrieving, presenting and traversing information resources on the World Wi>
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _  _ ___
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |\/| |  \
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |  | |__/
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q81945 Voice over Internet Protocol commonly refers to methods of delivering voice communications and multimedia over IP networks>
# <EntityElement: https://www.wikidata.org/wiki/Q16963779 instant                   an infinitesimal moment in time, a moment whose passage is instantaneous>
# <EntityElement: https://www.wikidata.org/wiki/Q241317 computing platform        hardware architecture and/or software framework   >
# <EntityElement: https://www.wikidata.org/wiki/Q22907849 Discord                   instant messenging and VOIP software targeted at gamers>
# <EntityElement: https://www.wikidata.org/wiki/Q1406 Microsoft Windows         family of operating systems produced for personal computers, servers, smartphones and embedded devic>
# <EntityElement: https://www.wikidata.org/wiki/Q14116 macOS                     operating system for Apple computers, launched in 2001 as Mac OS X>
# <EntityElement: https://www.wikidata.org/wiki/Q94 Android                   open-source operating system for mobile devices created by Google>
# <EntityElement: https://www.wikidata.org/wiki/Q48493 iOS                       mobile operating system by Apple                  >
# <EntityElement: https://www.wikidata.org/wiki/Q64350339 iPadOS                    mobile operating system of the iPad               >
# <EntityElement: https://www.wikidata.org/wiki/Q388 Linux                     operating system family that use the Linux kernel, including GNU/Linux and Android>
# <EntityElement: https://www.wikidata.org/wiki/Q6368 web browser               software application for retrieving, presenting and traversing information resources on the World Wi>

# %%
\footnotesize{
\begin{tabular}{|p{1,5cm}|p{1,5cm}|p{7cm}|}
\hline
\textbf{ span}
& \textbf{label}
& \textbf{définition}
\\ \hline
Discord 
    & Discord
    & instant messenging and VOIP software targeted at gamers
\\ \hline
VoIP
& Voice over IP 
& methods of delivering voice communications and multimedia over IP networks
\\ \hline
instant
    & instant                   
    & an infinitesimal moment in time, a moment whose passage is instantaneous
\\ \hline
macOS   
    & macOS 
    & operating system for Apple computers, launched in 2001 as Mac OS X
\\ \hline
Linux
    &Linux
    &operating system family that use the Linux kernel, including GNU/Linux and Android>
\\ \hline
Android 
    & Android 
    & open-source operating system for mobile devices created by Google
iOS
    & iOS
    & mobile operating system by Apple
iPadOS 
    & iPadOS
    & mobile operating system of the iPad
 \\ \hline
web browser
    & web browser
    & software application for retrieving, presenting, and traversing information resources on the World Wide Web

    
\\ \hline
\end{tabular}}

# %% [markdown]
# Alors que les entités nommées sont presques les mêmes ,nous pouvons noter des différences notables, le concept associé au mot web different
# Il apparait en premier lieu que
# Nous constatons que le modèle d'entity linking semble pensé pour l'anglais et non pour le français pusque qu'il n'identifie "et" et "de" comme des stop word.
# Une autre grosse différence set que sur le texte français "Discord" n'est pas identifié comme une entité nommée

# %% [markdown]
# ## extrait de la page Wikipédia "Nabilla"

# %% [markdown]
# En novembre 2013, elle est la vedette de sa propre émission de téléréalité, Allô Nabilla, ce qui est une première en France, le concept étant repris des États-Unis où l’on suit la vie des stars, notamment comme avec Kesha, Paris Hilton ou les Kardashian.

# %%
nabilla ="En novembre 2013, elle est la vedette de sa propre émission de téléréalité, Allô Nabilla, ce qui est une première en France, le concept étant repris des États-Unis où l’on suit la vie des stars, notamment comme avec Kesha, Paris Hilton ou les Kardashian. "

# %%
read(nabilla)
# Out:
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     ____ _  _
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      [__  |\/|
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ ___] |  |
#
#
# ____ ____     ____ ____ ____ ____     _  _ ____ _ _ _ ____     _    ____
# |___ |__/     |    |  | |__/ |___     |\ | |___ | | | [__      |    | __
# |    |  \ ___ |___ |__| |  \ |___ ___ | \| |___ |_|_| ___] ___ |___ |__]
#
#
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      ____ _  _
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     [__  |\/|
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ ___] |  |
#
#
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _    ____
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |    | __
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |___ |__]
#
#
# ____ _  _     ____ ____ ____ ____     _ _ _ ____ ___      _  _ ___
# |___ |\ |     |    |  | |__/ |___     | | | |___ |__]     |\/| |  \
# |___ | \| ___ |___ |__| |  \ |___ ___ |_|_| |___ |__] ___ |  | |__/
#
#
# \begin{tabular}{llllll}
# \toprule
#          modele &                                           contexte &                                     url &                        label &                                        description &            span \\
# \midrule
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q8765 &                    Aragonese &                                   Romance language &            (an) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... &  https://www.wikidata.org/wiki/Q1164740 &                 The American & 2010 American thriller film directed by Anton C... &      (American) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q1406 &            Microsoft Windows & family of operating systems produced for person... &       (Windows) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q14116 &                        macOS & operating system for Apple computers, launched ... &         (macOS) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... &       https://www.wikidata.org/wiki/Q94 &                      Android & open-source operating system for mobile devices... &       (Android) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q48493 &                          iOS &                   mobile operating system by Apple &           (iOS) \\
# fr\_core\_news\_sm & Discord is an American VoIP and instant messagi... &      https://www.wikidata.org/wiki/Q388 &                        Linux & operating system family that use the Linux kern... &         (Linux) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q8765 &                    Aragonese &                                   Romance language &            (an) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &  https://www.wikidata.org/wiki/Q1164740 &                 The American & 2010 American thriller film directed by Anton C... &      (American) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q81945 & Voice over Internet Protocol & commonly refers to methods of delivering voice ... &          (VoIP) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q1406 &            Microsoft Windows & family of operating systems produced for person... &       (Windows) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q14116 &                        macOS & operating system for Apple computers, launched ... &         (macOS) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &       https://www.wikidata.org/wiki/Q94 &                      Android & open-source operating system for mobile devices... &       (Android) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q48493 &                          iOS &                   mobile operating system by Apple &           (iOS) \\
# fr\_core\_news\_lg & Discord is an American VoIP and instant messagi... &      https://www.wikidata.org/wiki/Q388 &                        Linux & operating system family that use the Linux kern... &         (Linux) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q81945 & Voice over Internet Protocol & commonly refers to methods of delivering voice ... &          (VoIP) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q16963779 &                      instant & an infinitesimal moment in time, a moment whose... &       (instant) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &   https://www.wikidata.org/wiki/Q241317 &           computing platform &    hardware architecture and/or software framework &      (platform) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q1406 &            Microsoft Windows & family of operating systems produced for person... &       (Windows) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q14116 &                        macOS & operating system for Apple computers, launched ... &         (macOS) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &       https://www.wikidata.org/wiki/Q94 &                      Android & open-source operating system for mobile devices... &       (Android) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q48493 &                          iOS &                   mobile operating system by Apple &           (iOS) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q64350339 &                       iPadOS &                mobile operating system of the iPad &        (iPadOS) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &      https://www.wikidata.org/wiki/Q388 &                        Linux & operating system family that use the Linux kern... &         (Linux) \\
#  en\_core\_web\_sm & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q6368 &                  web browser & software application for retrieving, presenting... & (web, browsers) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q81945 & Voice over Internet Protocol & commonly refers to methods of delivering voice ... &          (VoIP) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &   https://www.wikidata.org/wiki/Q241317 &           computing platform &    hardware architecture and/or software framework &      (platform) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q1406 &            Microsoft Windows & family of operating systems produced for person... &       (Windows) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q14116 &                        macOS & operating system for Apple computers, launched ... &         (macOS) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &       https://www.wikidata.org/wiki/Q94 &                      Android & open-source operating system for mobile devices... &       (Android) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q48493 &                          iOS &                   mobile operating system by Apple &           (iOS) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q64350339 &                       iPadOS &                mobile operating system of the iPad &        (iPadOS) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &      https://www.wikidata.org/wiki/Q388 &                        Linux & operating system family that use the Linux kern... &         (Linux) \\
#  en\_core\_web\_lg & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q6368 &                  web browser & software application for retrieving, presenting... & (web, browsers) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q81945 & Voice over Internet Protocol & commonly refers to methods of delivering voice ... &          (VoIP) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q16963779 &                      instant & an infinitesimal moment in time, a moment whose... &       (instant) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &   https://www.wikidata.org/wiki/Q241317 &           computing platform &    hardware architecture and/or software framework &      (platform) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q22907849 &                      Discord & instant messenging and VOIP software targeted a... &       (Discord) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q1406 &            Microsoft Windows & family of operating systems produced for person... &       (Windows) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q14116 &                        macOS & operating system for Apple computers, launched ... &         (macOS) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &       https://www.wikidata.org/wiki/Q94 &                      Android & open-source operating system for mobile devices... &       (Android) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &    https://www.wikidata.org/wiki/Q48493 &                          iOS &                   mobile operating system by Apple &           (iOS) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... & https://www.wikidata.org/wiki/Q64350339 &                       iPadOS &                mobile operating system of the iPad &        (iPadOS) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &      https://www.wikidata.org/wiki/Q388 &                        Linux & operating system family that use the Linux kern... &         (Linux) \\
#  en\_core\_web\_md & Discord is an American VoIP and instant messagi... &     https://www.wikidata.org/wiki/Q6368 &                  web browser & software application for retrieving, presenting... & (web, browsers) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q3178518 &                      vedette & female entertainers with multiple talents for s... &       (vedette) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q685017 &                     Novembre &                                       Italian band &      (novembre) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q142 &                       France & republic with mainland in Europe and numerous o... &        (France) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q151885 &                      concept & mental representation or an abstract object or ... &       (concept) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q3103189 &                            ჳ &                                    Georgian letter &           (vie) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q1752259 &                        Stars &                           Canadian indie rock band &         (stars) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q33605 &                        Kesha &                         American singer-songwriter &         (Kesha) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &       https://www.wikidata.org/wiki/Q90 &                        Paris &                 capital and largest city of France &         (Paris) \\
# fr\_core\_news\_sm & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q2890404 &                       Hilton &              village in the state of New York, USA &        (Hilton) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q685017 &                     Novembre &                                       Italian band &      (novembre) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q3178518 &                      vedette & female entertainers with multiple talents for s... &       (vedette) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q142 &                       France & republic with mainland in Europe and numerous o... &        (France) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q151885 &                      concept & mental representation or an abstract object or ... &       (concept) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q3103189 &                            ჳ &                                    Georgian letter &           (vie) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q1752259 &                        Stars &                           Canadian indie rock band &         (stars) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q33605 &                        Kesha &                         American singer-songwriter &         (Kesha) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &       https://www.wikidata.org/wiki/Q90 &                        Paris &                 capital and largest city of France &         (Paris) \\
# fr\_core\_news\_lg & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q2890404 &                       Hilton &              village in the state of New York, USA &        (Hilton) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q685017 &                     Novembre &                                       Italian band &      (novembre) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q183 &                      Germany & federal parliamentary republic in central-weste... &            (de) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... & https://www.wikidata.org/wiki/Q18587457 &                   En premiär &                           painting by Anders Zorn‎ & (une, première) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q142 &                       France & republic with mainland in Europe and numerous o... &        (France) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q6517221 &                       Legacy &  episode of Star Trek: The Next Generation (S4 E6) &            (le) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q27905 &                         suit & categories into which the cards of a deck are d... &          (suit) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q397 &                        Latin & almost extinct Indo-European language of the It... &            (la) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q33605 &                        Kesha &                         American singer-songwriter &         (Kesha) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q47899 &                 Paris Hilton &      American socialite and television personality & (Paris, Hilton) \\
#  en\_core\_web\_sm & En novembre 2013, elle est la vedette de sa pro... & https://www.wikidata.org/wiki/Q18024818 &                         FUT3 &    protein-coding gene in the species Homo sapiens &           (les) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q851 &                 Saudi Arabia &                            kingdom in Western Asia &            (sa) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q174069 &                            Н &                                    Cyrillic letter &            (En) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q685017 &                     Novembre &                                       Italian band &      (novembre) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q523 &                         star & sphere of plasma held together by gravity, unde... &         (stars) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q27905 &                         suit & categories into which the cards of a deck are d... &          (suit) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q397 &                        Latin & almost extinct Indo-European language of the It... &            (la) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q3103189 &                            ჳ &                                    Georgian letter &           (vie) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q33605 &                        Kesha &                         American singer-songwriter &         (Kesha) \\
#  en\_core\_web\_lg & En novembre 2013, elle est la vedette de sa pro... &       https://www.wikidata.org/wiki/Q90 &                        Paris &                 capital and largest city of France &         (Paris) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &   https://www.wikidata.org/wiki/Q685017 &                     Novembre &                                       Italian band &      (novembre) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q397 &                        Latin & almost extinct Indo-European language of the It... &            (la) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... & https://www.wikidata.org/wiki/Q19544495 &                         Elle &                        2016 film by Paul Verhoeven &          (elle) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &  https://www.wikidata.org/wiki/Q3178518 &                      vedette & female entertainers with multiple talents for s... &       (vedette) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q183 &                      Germany & federal parliamentary republic in central-weste... &            (de) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q851 &                 Saudi Arabia &                            kingdom in Western Asia &            (sa) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q142 &                       France & republic with mainland in Europe and numerous o... &        (France) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q27905 &                         suit & categories into which the cards of a deck are d... &          (suit) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q523 &                         star & sphere of plasma held together by gravity, unde... &         (stars) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &      https://www.wikidata.org/wiki/Q397 &                        Latin & almost extinct Indo-European language of the It... &            (la) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &    https://www.wikidata.org/wiki/Q33605 &                        Kesha &                         American singer-songwriter &         (Kesha) \\
#  en\_core\_web\_md & En novembre 2013, elle est la vedette de sa pro... &       https://www.wikidata.org/wiki/Q90 &                        Paris &                 capital and largest city of France &         (Paris) \\
# \bottomrule
# \end{tabular}
#
# [{'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q22907849', 'label': 'Discord', 'description': 'instant messenging and VOIP software targeted at gamers', 'span': Discord}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q8765', 'label': 'Aragonese', 'description': 'Romance language', 'span': an}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q1164740', 'label': 'The American', 'description': '2010 American thriller film directed by Anton Corbijn', 'span': American}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q22907849', 'label': 'Discord', 'description': 'instant messenging and VOIP software targeted at gamers', 'span': Discord}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q1406', 'label': 'Microsoft Windows', 'description': 'family of operating systems produced for personal computers, servers, smartphones and embedded devices', 'span': Windows}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q14116', 'label': 'macOS', 'description': 'operating system for Apple computers, launched in 2001 as Mac OS X', 'span': macOS}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q94', 'label': 'Android', 'description': 'open-source operating system for mobile devices created by Google', 'span': Android}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q48493', 'label': 'iOS', 'description': 'mobile operating system by Apple', 'span': iOS}, {'modele': 'fr_core_news_sm', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q388', 'label': 'Linux', 'description': 'operating system family that use the Linux kernel, including GNU/Linux and Android', 'span': Linux}, {'modele': 'fr_core_news_lg', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q22907849', 'label': 'Discord', 'description': 'instant messenging and VOIP software targeted at gamers', 'span': Discord}, {'modele': 'fr_core_news_lg', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on Windows, macOS, Android, iOS, iPadOS, Linux, and in web browsers.', 'url': 'https://www.wikidata.org/wiki/Q8765', 'label': 'Aragonese', 'description': 'Romance language', 'span': an}, {'modele': 'fr_core_news_lg', 'contexte': 'Discord is an American VoIP and instant messaging social platform. Discord runs on W ...
# /tmp/ipykernel_3801/1778451559.py:24: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   table_latex = df.to_latex(index=False)

# %%
process()

# %%
Il s'agit d'un système conçu pour la langue anglaise contemporaine et adapté à des notions modernes
impossible de paramétrer la langue 
présence de nom commun : bien plus difficile de proposer une définitio adequat car comme il ne s'agit pas d'une entité nommée, il bien plus difficile en core de lui assigner un sens.
Une entités nommées a un référent unique, pour un nom commun la frontière entre ses différents sens est toujours plus trouble. Il est donc bien plus difficile d'associer une définition unique à un nom commun
