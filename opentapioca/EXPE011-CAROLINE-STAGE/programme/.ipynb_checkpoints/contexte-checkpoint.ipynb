# %% [markdown]
# 17/05/2023 au 25/05/2023
# objectif : faire la comparaison avec et sans contexte des performances du système d'entity linking de SpaCy
# contexte : notebook présenté lors de la réunion du 25/05/2023

# %% [markdown]
# # Evaluation comparative  du système d'entity linking de SpaCy

# %% [markdown]
# ## code donné par CKP

# %%
texte = lire_fichier(path)
text=nlp(texte)  
for ent in text.ents:
        list_resultats.append([ent.text, ent.start_char, ent.end_char, ent.label_,texte[ent.start_char-200:ent.start_char],texte[ent.end_char:ent.end_char+200]])

# %% [markdown]
# ## première adaptation

# %%
import glob
import spacy
import json


def lire_fichier(chemin):
    with open (chemin, "r", encoding="utf-8") as fichier:
        texte=fichier.read()
        return texte

list_resultats=[]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"




for path in glob.glob(path_corpora):
    texte = lire_fichier(path)
    nlp = spacy.load("fr_core_news_sm")
    nlp.add_pipe("entityLinker", last=True)
    text=nlp(texte) 
    list_resultats=[]
    for ent in text.ents:
        list_resultats.append([ent.text, ent.start_char, ent.end_char, ent.label_,texte[ent.start_char-200:ent.start_char],ent.text,texte[ent.end_char:ent.end_char+200]])
print (list_resultats[0])
print (list_resultats[70])
# Out:
# ['Norine Duclos', 76, 89, 'PER', '', " qu'ont\nlieu les plus egayantes veilles de notre vil-\nlage. Adonc, certain soir, comme j'entrais\nchez Norine, je la trouvai en train de precher\nses trois petiotes.\n- He MIandine, criait-elle, dpeche-t"]
# ['petiot\nRoux', 5007, 5018, 'PER', "t Jean-Claude;\nle dragon viendra pendant ce temps-la.\n- Je veux, au contraire, l'attendre pour\nchanter, dit la Rose d'un ton pique.\n- Chante, dit Gaspard, ou sinon...\n-- Tu deviens par trop bravache, ", ', dit Norine; tache un peu de te tenir\ntranquille.\n- Je vas chanter, moi, dit le vieux berger.l-\nMION VI1LAGE.\n- lEn ce cas-la, je me sauve, dit la petiote\nh Perpetue.\n- Non, dit le fieu de Toinon, so']

# %% [markdown]
# Nous vérifions ensuite dans le texte si nous retrouvons bien les mêmes valeurs

# %% [markdown]
# "Depuis un nombre innombrable d’hivers, c’est dans la maison de Norine Duclos qu’ont lieu les plus égayantes veillées de notre village. Adonc, certain soir, comme j’entrais chez Norine, je la trouvai en train de prêcher ses trois petiotes. "

# %% [markdown]
# "- Chante, toi, la Rose, dit Jean-Claude;
# le dragon viendra pendant ce temps-la.
# - Je veux, au contraire, l'attendre pour
# chanter, dit la Rose d'un ton pique.
# - Chante, dit Gaspard, ou sinon...
# -- Tu deviens par trop bravache, petiot
# Roux, dit Norine; tache un peu de te tenir
# tranquille.
# - Je vas chanter, moi, dit le vieux berger.l-
# MION VI1LAGE.
# - lEn ce cas-la, je me sauve, dit la petiote
# h Perpetue."

# %% [markdown]
# ### concaténation

# %%
import glob
import spacy
import json


def lire_fichier(chemin):
    with open (chemin, "r", encoding="utf-8") as fichier:
        texte=fichier.read()
        return texte

list_resultats=[]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"

for path in glob.glob(path_corpora):
    texte = lire_fichier(path)
    nlp = spacy.load("fr_core_news_sm")
    nlp.add_pipe("entityLinker", last=True)
    text=nlp(texte) 
    list_resultats=[]
    for ent in text.ents:
        contexte = str(texte[ent.start_char-100:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+100])
        list_resultats.append([ent.text, ent.start_char, ent.end_char, ent.label_,contexte])
print (list_resultats[0])
print (list_resultats[70])
# Out:
# ['Norine Duclos', 76, 89, 'PER', "Norine Duclos qu'ont\nlieu les plus egayantes veilles de notre vil-\nlage. Adonc, certain soir, comme j'entrais\nche"]
# ['petiot\nRoux', 5007, 5018, 'PER', "er, dit la Rose d'un ton pique.\n- Chante, dit Gaspard, ou sinon...\n-- Tu deviens par trop bravache, petiot\nRoux, dit Norine; tache un peu de te tenir\ntranquille.\n- Je vas chanter, moi, dit le vieux berger.l-\nMIO"]

# %% [markdown]
# ## Essai d'incorporation dans le code existant

# %% [markdown]
# ==> échec

# %%
import json
import spacy  # version 3.5
import glob


def lire_fichier(chemin):
    with open (chemin, "r", encoding="utf-8") as fichier:
        texte=fichier.read()
        return texte
def stocker(chemin, contenu):
    w =open(chemin, "w")
    w.write(json.dumps(contenu , indent = 2))
    w.close()
#modele=["sm","md","lg"]
modele=["md"]
# path_corpora = "../DATA/ELTeC-Fra_2023/*/*/*/*.txt"
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"
for mod in modele:
    print("Pour le modèle : ",mod,"\n")
    # nlp = spacy.load("en_core_web_%s"%mod)
    nlp = spacy.load("fr_core_news_%s"%mod)
    nlp.add_pipe("entityLinker", last=True)
    
    
    for path in glob.glob(path_corpora):
        print("Entrée : ",path)
        txt=lire_fichier(path)
        doc = nlp(txt[50])  
        #doc = nlp(txt) 
        i=0
        dico_sent_tok ={}
        
        
        for ent in doc._.linkedEntities: 
                ide = "ID"+str(i)
                url_00 = ent.get_url()
                label_00=ent.get_label()
                description=ent.get_description()
                span_00=ent.get_span()
                span_oo=str(span_00)
                doc2=nlp(span_oo)
                for ent in doc2.ents:#Pour le typage avec les labels de l'entity linking
                    
                    # print(en.label_)
                    dico_sent_tok[ide]={}
                    dico_sent_tok[ide]["url"]=url_00
                    dico_sent_tok[ide]["span"]=span_oo
                    dico_sent_tok[ide]["label"]=label_00
                    dico_sent_tok[ide]["description"]=description
                    dico_sent_tok[ide]["type"]=ent.label_#Pour le typage avec les labels de l'entity linking
                    #dico_sent_tok[ide]["contexte"]=doc[ent.start_char-200:ent.start_char],doc[ent.end_char:ent.end_char+200]
                    i+=1
                    print(dico_sent_tok[ide])
# Out:
# Pour le modèle :  md
#
# Entrée :  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt

# %%
==> impossible

# %% [markdown]
# ## enregistrer les valeurs avec leur contexte dans un dictionnaire

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 22 11:59:44 2023

@author: antonomaz
"""

import json
import spacy  # version 3.5
import glob


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    # Set up entity linker with knowledge base
    # Refer to Spacy documentation for entity linking setup

    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        dico = {}
        i = 1

        for ent in doc.ents:
            deb_contexte = str(doc[max(ent.start_char - 200, 0):ent.start_char])
            fin_contexte = str(doc[ent.end_char:min(ent.end_char + 200, len(doc))])
            context = deb_contexte + fin_contexte
            ide = "ID" + str(i)
            dico[ide] = {
                "texte": ent.text,
                "char_start": ent.start_char,
                "char_end": ent.end_char,
                "label": ent.label_,
                "contexte": context,
            }
            i += 1
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt

# %%
import json
import spacy  # version 3.5
import glob


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    # Set up entity linker with knowledge base
    # Refer to Spacy documentation for entity linking setup

    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        dico = {}
        i = 1

        for ent in doc.ents:
            deb_contexte = str(doc[max(ent.start_char - 200, 0):ent.start_char])
            fin_contexte = str(doc[ent.end_char:min(ent.end_char + 200, len(doc))])
            context = deb_contexte + fin_contexte
            ide = "ID" + str(i)
            dico[ide] = {
                "texte": ent.text,
                "char_start": ent.start_char,
                "char_end": ent.end_char,
                "label": ent.label_,
                "contexte": context,
            }
            i += 1
            print(dico)
            for cle, valeur in dico.items():
                entourage = dico.get("contexte")
                entite = dico.get("texte")
                liste_entourage = []
                liste_entite = []
                liste_entite.append(entite)
                liste_entourage.append(entourage)
            for entourages in liste_entourage : 
                for ent in doc._.linkedEntities:
                    url_entourage = ent.get_url()
                    liste_url_entourage = []
                    liste_url_entourage.append[url_entourage]
            for entites in liste_entite : 
                for ent in doc._.linkedEntities:
                    url_entite = ent.get_url()
                    liste_url_entite= []
                    liste_url_entite.append[url_entite]
            
            if [c for c in liste_entourage if c in liste_url_entite] : 
                common_value = True
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# {'ID1': {'texte': 'VEILLÉE', 'char_start': 4, 'char_end': 11, 'label': 'MISC', 'contexte': "UNE VEILLÉE. \nc'est dans la maison de Norine Duclos qu'ont lieu les plus égayantes veillées de notre village. Adonc, certain soir, comme j'entrais chez Norine, je la trouvai en train de prêcher ses trois petiotes. \n— Hé ! Mandine, criait-elle, dépêche-toi de balayer la maison ; plus vite que ça ! Surtout n'oublie pas le coin où la femme de Jean-Claude a épluché une pomme ce matin. Toi, la Rose, prends mon couvet et emplis-le. Habile [2] , habile. \nDésirée ! Monte sur l'escabeau et décroche une chandelle à la poutre ; trouve le chandelier. Bon ! voilà du cuivre qui terluit comme le dos d'une citrouille. Frotte, frotte ; là !... Faites excuse, Cellier, dit Norine, mais des fillettes, ça ne s'avise de rien, il faut tout leur commander. \nQuand on doit parler d'une ménagère, en voilà une ! Elle passe, à bon droit, pour la plus regardante de Saint-Brunelle ; on se mirerait dans son armoire en"}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 59
#      57         url_entourage = ent.get_url()
#      58         liste_url_entourage = []
# ---> 59         liste_url_entourage.append[url_entourage]
#      60 for entites in liste_entite :
#      61     for ent in doc._.linkedEntities:
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
import json
import spacy  # version 3.5
import glob


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    # Set up entity linker with knowledge base
    # Refer to Spacy documentation for entity linking setup

    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        dico = {}
        i = 1

        for ent in doc.ents:
            deb_contexte = str(doc[max(ent.start_char - 200, 0):ent.start_char])
            fin_contexte = str(doc[ent.end_char:min(ent.end_char + 200, len(doc))])
            context = deb_contexte + fin_contexte
            ide = "ID" + str(i)
            dico[ide] = {
                "texte": ent.text,
                "char_start": ent.start_char,
                "char_end": ent.end_char,
                "label": ent.label_,
                "contexte": context,
            }
            i += 1
            print(dico)

            # Move the following code outside the loop for proper variable scope
            liste_entourage = []
            liste_entite = []
            liste_url_entourage = []
            liste_url_entite = []

            for cle, valeur in dico.items():
                entourage = valeur["contexte"]
                entite = valeur["texte"]
                liste_entite.append(entite)
                liste_entourage.append(entourage)

            for ent in doc._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)

            for ent in doc._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)

            common_values = set(liste_entourage).intersection(liste_url_entite)

# %% [markdown]
# # générer un tableau et un graphique récapitulatif

# %%
import glob
import spacy
import json
import pandas as pd
import matplotlib.pyplot as plt

def lire_fichier(chemin):
    with open(chemin) as json_data: 
        dist = json.load(json_data)
    return dist

def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)

path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"

# Lists to store the results
common_urls_per_file = []
common_urls = []

# Loop through all files in the directory
for path in glob.glob(path_corpora):
    if "REN" in str(path):
        nlp = spacy.load("fr_core_news_lg")
        common_values = 0
        print(path)
        dictionnaires = lire_fichier(path)
        for cle, valeur in dictionnaires.items():
            liste_entourage = []
            liste_entite = []
            liste_url_entite = []
            liste_url_entourage = []
            entourage = valeur["contexte"]
            entite = valeur["texte"]
            liste_entite.append(entite)
            liste_entourage.append(entourage)
            nlp.add_pipe("entityLinker", last=True)
            doc = nlp(entourage[50000])
            doc2 = nlp(entite[50000])
            for ent in doc._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc2._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
            common_urls.extend(liste_url_entite)
            common_urls_per_file.append((path, set(liste_url_entite) & set(liste_url_entourage)))

# Summary table of common URLs
common_urls_table = pd.DataFrame(common_urls, columns=["Common URLs"])
print("Summary Table of Common URLs:")
print(common_urls_table)

# Graph of number of common URLs per JSON file
file_names = [file[0] for file in common_urls_per_file]
num_common_urls = [len(file[1]) for file in common_urls_per_file]

plt.figure(figsize=(12, 6))
plt.bar(file_names, num_common_urls)
plt.xlabel("JSON File")
plt.ylabel("Number of Common URLs")
plt.title("Number of Common URLs per JSON File")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 22 15:24:32 2023

@author: antonomaz
"""

import json
import spacy  # version 3.5
import glob


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    # Set up entity linker with knowledge base
    # Refer to Spacy documentation for entity linking setup

    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        dico = {}
        i = 1

        for ent in doc.ents:
            deb_contexte = str(doc[max(ent.start_char - 10, 0):ent.start_char])
            fin_contexte = str(doc[ent.end_char:min(ent.end_char + 10, len(doc))])
            context = deb_contexte + fin_contexte
            ide = "ID" + str(i)
            print(ide)
            dico[ide] = {
                "texte": ent.text,
                "char_start": ent.start_char,
                "char_end": ent.end_char,
                "label": ent.label_,
                "debcontexte": doc[ent.start_char-10:ent.start_char],
                "fincontexte": doc[ent.end_char:ent.end_char+10],
            }
            i += 1
            print(dico)
            stocker("%s_NER_contexte.json"%path,dico)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# ID1
# {'ID1': {'texte': 'VEILLÉE', 'char_start': 4, 'char_end': 11, 'label': 'MISC', 'debcontexte': , 'fincontexte': c'est dans la maison de Norine Duclos qu'ont}}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 58
#      56 i += 1
#      57 print(dico)
# ---> 58 stocker("%s_NER_contexte.json"%path,dico)
#
# Cell In[1], line 22, in stocker(chemin, contenu)
#      20 def stocker(chemin, contenu):
#      21     with open(chemin, "w") as w:
# ---> 22         json.dump(contenu, w, indent=2)
#
# File ~/anaconda3/lib/python3.10/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/anaconda3/lib/python3.10/json/encoder.py:431, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     429     yield from _iterencode_list(o, _current_indent_level)
#     430 elif isinstance(o, dict):
# --> 431     yield from _iterencode_dict(o, _current_indent_level)
#     432 else:
#     433     if markers is not None:
#
# File ~/anaconda3/lib/python3.10/json/encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~/anaconda3/lib/python3.10/json/encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~/anaconda3/lib/python3.10/json/encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File ~/anaconda3/lib/python3.10/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type Span is not JSON serializable

# %% [markdown]
# ## En enregistrant dans un dictionnaire

# %% [markdown]
# ça fait planter spyder systématiquement

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 22 15:24:32 2023

@author: antonomaz
""" 

import json
import spacy  # version 3.5
import glob


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    # Set up entity linker with knowledge base
    # Refer to Spacy documentation for entity linking setup

    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        list_resultats = []
        list_entites = []
        i = 1
        dico={}
        for ent in doc.ents:
            #deb_contexte = str(doc[max(ent.start_char - 10, 0):ent.start_char])
            #fin_contexte = str(doc[ent.end_char:min(ent.end_char + 10, len(doc))])
            #context = deb_contexte + fin_contexte
            contexte = str(texte[ent.start_char-100:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+100])
            ide = "ID" + str(i)
            print(ide)
            #list_entites.append(ent.text)
            #resultat = str(doc[ent.start_char-50:ent.start_char])+ str(ent.text) + str(doc[ent.end_char:ent.end_char+50])
            #list_resultats.append(resultat)
            dico[ide]={}
            dico[ide]["texte"]= ent.text
            dico[ide]["char_start"]= ent.start_char
            dico[ide]["char_end"]= ent.end_char
            dico[ide]["label"]= ent.label_
            dico[ide]["contexte"]= contexte
            i += 1
            
            print(dico)
            #print(list_resultats)
            #stocker("%s_NER_contexte.json"%path,dico)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## enregistrer dans une liste

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 22 15:24:32 2023

@author: antonomaz
""" 

import json
import spacy  # version 3.5
import glob


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/*.txt"

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    # Set up entity linker with knowledge base
    # Refer to Spacy documentation for entity linking setup

    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        list_resultats = []
        list_entites = []
        i = 1
        dico={}
        for ent in doc.ents:dans
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            list_entites.append(ent.text)
            list_resultats.append(contexte)
            #print(list_entites)
            
            #stocker("%s_NER_contexte.json"%path,dico)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed May 24 11:03:22 2023

@author: antonomaz
"""


import json
import spacy  # version 3.5
import glob
import matplotlib as plt
import matplotlib.pyplot as plt

import pandas as pd


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
common_urls_per_file = []
common_urls = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        list_resultats = []
        list_entites = []
        liste_url_entourage = []
        liste_url_entite = []
        
        i = 1
        dico={}
        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            
            doc = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc2._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
            common_urls.extend(liste_url_entite)
            common_urls_per_file.append((path, set(liste_url_entite) & set(liste_url_entourage)))

# Summary table of common URLs
common_urls_table = pd.DataFrame(common_urls, columns=["Common URLs"])
print("Summary Table of Common URLs:")
print(common_urls_table)

# Graph of number of common URLs per JSON file
file_names = [file[0] for file in common_urls_per_file]
num_common_urls = [len(file[1]) for file in common_urls_per_file]

plt.figure(figsize=(12, 6))
plt.bar(file_names, num_common_urls)
plt.xlabel("JSON File")
plt.ylabel("Number of Common URLs")
plt.title("Number of Common URLs per JSON File")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# Summary Table of Common URLs:
#                                      Common URLs
# 0         https://www.wikidata.org/wiki/Q3646180
# 1        https://www.wikidata.org/wiki/Q21450529
# 2           https://www.wikidata.org/wiki/Q69546
# 3         https://www.wikidata.org/wiki/Q3646180
# 4        https://www.wikidata.org/wiki/Q21450529
# ...                                          ...
# 3518311   https://www.wikidata.org/wiki/Q1062645
# 3518312    https://www.wikidata.org/wiki/Q205006
# 3518313   https://www.wikidata.org/wiki/Q2479774
# 3518314    https://www.wikidata.org/wiki/Q205006
# 3518315    https://www.wikidata.org/wiki/Q205006
#
# [3518316 rows x 1 columns]
# /tmp/ipykernel_3714/1422842801.py:80: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import json
import spacy  # version 3.5
import glob
import matplotlib.pyplot as plt
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)

modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
common_urls_per_file = []
common_urls = []
non_common_urls = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        list_resultats = []
        list_entites = []
        liste_url_entourage = []
        liste_url_entite = []

        i = 1
        dico={}
        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text

            doc = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc2._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)

            common_urls.extend(liste_url_entite)
            common_urls_per_file.append((path, set(liste_url_entite) & set(liste_url_entourage)))

        non_common_urls.extend(liste_url_entite)

# Calculate proportions
total_common_urls = len(common_urls)
total_non_common_urls = len(non_common_urls)
total_urls = total_common_urls + total_non_common_urls
common_urls_proportion = total_common_urls / total_urls
non_common_urls_proportion = total_non_common_urls / total_urls

# Create a bar plot
labels = ['Common URLs', 'Non-Common URLs']
proportions = [common_urls_proportion, non_common_urls_proportion]

plt.bar(labels, proportions, color=['blue', 'red'])
plt.xlabel('URL Types')
plt.ylabel('Proportion')
plt.title('Proportion of Common URLs and Non-Common URLs')
plt.show()
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed May 24 11:03:22 2023

@author: antonomaz
"""


import json
import spacy  # version 3.5
import glob
import matplotlib as plt
import matplotlib.pyplot as plt

import pandas as pd


def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte


def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)


modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
common_urls_per_file = []
common_urls = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        list_resultats = []
        list_entites = []
        
        
        i = 1
        dico={}
        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            
            doc = nlp(entite)
            doc2 = nlp(contexte)
            liste_url_entourage = []
            liste_url_entite = []
            for ent in doc._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc2._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
            common_urls.extend(liste_url_entite)
            common_urls_per_file.append((path, set(liste_url_entite) & set(liste_url_entourage)))

# Summary table of common URLs
common_urls_table = pd.DataFrame(common_urls, columns=["Common URLs"])
print("Summary Table of Common URLs:")
print(common_urls_table)

# Graph of number of common URLs per JSON file
file_names = [file[0] for file in common_urls_per_file]
num_common_urls = [len(file[1]) for file in common_urls_per_file]

plt.figure(figsize=(12, 6))
plt.bar(file_names, num_common_urls)
plt.xlabel("JSON File")
plt.ylabel("Number of Common URLs")
plt.title("Number of Common URLs per JSON File")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed May 24 13:58:02 2023

@author: antonomaz
"""

import json
import glob
import matplotlib.pyplot as plt
import spacy
import pandas as pd

def lire_fichier (chemin):
    with open(chemin) as json_data: 
        dist =json.load(json_data)
    return dist


def stocker_graph(nomfich): 
    
    name_fig = "%s.png"
    print(" nom de la figure ", name_fig)
    plt.ylabel("nombre d'entités liées")
    plt.xlabel("OCR Version")
    plt.xticks(fontsize=10,rotation=25)
    # plt.axis([-1,7,0,1])  
    # plt.legend(non="lower left",ncol=2, bbox_to_anchor=(0,0.98))
    # plt.legend 
    plt.gcf().set_size_inches(8, 9)
    plt.savefig(nomfich)
    plt.clf()
    
    return nomfich 

path_corpora = "../DATA/ELTeC-Fra_2023/*"

for subcorpus in glob.glob(path_corpora):
    x=["Réf"]
    # print(subcorpus)
    for path_version in glob.glob("%s/*"%subcorpus): 
        nlp = spacy.load("fr_core_news_sm")
        nlp.add_pipe("entityLinker", last=True)
        version_OCR = path_version.split("/")[-1]
        version_OCR = version_OCR.split("_")[-1]
        x.append(version_OCR)
        liste_non_sm = []
        liste_non_lg = []
        liste_intersect_sm = []
        liste_intersect_lg = []
        liste_non_ref_lg=[]
        liste_intersect_ref_lg=[] 
        liste_non_ref_sm=[]
        liste_intersect_ref_sm=[] 
        output=path_version.split("/")[-1]
        output=output.split("_")[0]        
        #print(x)
        for path in glob.glob("%s/*/*/*.json"%subcorpus):
            # liste_res=[]
            # print(path)
            texte = lire_fichier(path)
            doc = nlp(texte)
            list_resultats = []
            list_entites = []
            common_urls =[]
            common_urls_per_file =[]
            non = 0
            intersect = 0
            cK=0
            
            i = 1
            dico={}
            for ent in doc.ents:
                compteur = 1
                contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
                entite = ent.text
                
                doc = nlp(entite)
                doc2 = nlp(contexte)
                liste_url_entourage = []
                liste_url_entite = []
                intersect = 0
                for ent in doc._.linkedEntities:
                    url_entourage = ent.get_url()
                    liste_url_entourage.append(url_entourage)
                for ent in doc2._.linkedEntities:
                    url_entite = ent.get_url()
                    liste_url_entite.append(url_entite)
                common_urls.extend(liste_url_entite)
                for d in liste_url_entourage :
                    if d in liste_url_entite:
                        intersect = intersect + 1
                compteur =+1
                non=compteur-intersect
                common_urls_per_file.append((path, set(liste_url_entite) & set(liste_url_entourage)))
                nb_commun = len(common_urls_per_file) 
            if "REF" in path:
                if "sm" in path:
                    liste_non_ref_sm.append(non)
                    liste_intersect_ref_sm.append(intersect)
                else:
                    liste_non_ref_lg.append(non)
                    liste_intersect_ref_lg.append(intersect)

            else:
                if "sm" in path:
                    liste_non_sm.append(non)
                    liste_intersect_sm.append(intersect)
                else:
                    liste_non_lg.append(non)
                    liste_intersect_lg.append(intersect)
    print(path)
    print( liste_non_ref_lg,liste_intersect_ref_lg)
   
    liste_non_sm.insert(0,liste_non_ref_sm[0])
    liste_intersect_sm.insert(0,liste_intersect_ref_sm[0])
    liste_non_lg.insert(0,liste_non_ref_lg[0])
    liste_intersect_lg.insert(0,liste_intersect_ref_lg[0])
    dico_mod={}
    dico_mod["sm"]={}
    dico_mod["sm"]["non"]=liste_non_sm
    dico_mod["sm"]["intersect"]=liste_intersect_sm
    dico_mod["sm"]["bottom"]=liste_non_sm
    dico_mod["lg"]={}
    dico_mod["lg"]["non"]=liste_non_lg
    dico_mod["lg"]["intersect"]=liste_intersect_lg
    dico_mod["lg"]["bottom"]=liste_non_lg
       
    for k, va in dico_mod.items():
        print(k,va)
        for kk, vv in va.items():
            largeur_barre = 0.8
            ax=range(len(vv))
            if kk=="non":
                plt.bar(x,vv, width = largeur_barre, color = "red")
                plt.xticks(ax, x, rotation=90)
            if kk=="intersect":
                plt.bar(x, vv, width = largeur_barre, bottom =dico_mod[k]["bottom"] , color = "blue")
            plt.xticks(ax, x, rotation=90)
        stocker_graph("../DATA/%s_spaCy-%s-linking.png"%(output,k))

        # plt.show()
        # print(path)
        #
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 69
#      65 for path in glob.glob("%s/*/*/*.json"%subcorpus):
#      66     # liste_res=[]
#      67     # print(path)
#      68     texte = lire_fichier(path)
# ---> 69     doc = nlp(texte)
#      70     list_resultats = []
#      71     list_entites = []
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/language.py:1008, in Language.__call__(self, text, disable, component_cfg)
#     987 def __call__(
#     988     self,
#     989     text: Union[str, Doc],
#    (...)
#     992     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#     993 ) -> Doc:
#     994     """Apply the pipeline to some text. The text can span multiple sentences,
#     995     and can contain arbitrary whitespace. Alignment into the original string
#     996     is preserved.
#    (...)
#    1006     DOCS: https://spacy.io/api/language#call
#    1007     """
# -> 1008     doc = self._ensure_doc(text)
#    1009     if component_cfg is None:
#    1010         component_cfg = {}
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/language.py:1102, in Language._ensure_doc(self, doc_like)
#    1100 if isinstance(doc_like, bytes):
#    1101     return Doc(self.vocab).from_bytes(doc_like)
# -> 1102 raise ValueError(Errors.E1041.format(type=type(doc_like)))
#
# ValueError: [E1041] Expected a string, Doc, or bytes as input, but got: <class 'dict'>

# %%
import json
import spacy  # version 3.5
import glob
import matplotlib.pyplot as plt
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)

modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
common_urls_per_file = []
common_urls = []
non_common_urls = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        list_resultats = []
        list_entites = []
        compteur = 0
        intersect = 0

        i = 1
        dico={}
        for ent in doc.ents:
            
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            print(entite)
            liste_url_entourage = []
            liste_url_entite = []
            doc2 = nlp(entite)
            doc3 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
                print (liste_url_entite)
                for d in liste_url_entourage :
                    if d in liste_url_entite:
                        #print (d)
                        intersect = intersect + 1
            compteur +=1
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# VEILLÉE
# Norine Duclos
# ['https://www.wikidata.org/wiki/Q3646180']
# ['https://www.wikidata.org/wiki/Q3646180', 'https://www.wikidata.org/wiki/Q21450529']
# ['https://www.wikidata.org/wiki/Q3646180', 'https://www.wikidata.org/wiki/Q21450529', 'https://www.wikidata.org/wiki/Q69546']
# Norine
# ['https://www.wikidata.org/wiki/Q870']
# Hé
# ['https://www.wikidata.org/wiki/Q870']
# Mandine
# ['https://www.wikidata.org/wiki/Q870']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q41207']
# ['https://www.wikidata.org/wiki/Q41207', 'https://www.wikidata.org/wiki/Q28129894']
# ['https://www.wikidata.org/wiki/Q41207', 'https://www.wikidata.org/wiki/Q28129894', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q41207', 'https://www.wikidata.org/wiki/Q28129894', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q42397176']
# ['https://www.wikidata.org/wiki/Q41207', 'https://www.wikidata.org/wiki/Q28129894', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q42397176', 'https://www.wikidata.org/wiki/Q16866073']
# ['https://www.wikidata.org/wiki/Q41207', 'https://www.wikidata.org/wiki/Q28129894', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q42397176', 'https://www.wikidata.org/wiki/Q16866073', 'https://www.wikidata.org/wiki/Q7813319']
# ['https://www.wikidata.org/wiki/Q41207', 'https://www.wikidata.org/wiki/Q28129894', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q42397176', 'https://www.wikidata.org/wiki/Q16866073', 'https://www.wikidata.org/wiki/Q7813319', 'https://www.wikidata.org/wiki/Q519034']
# Désirée !
# ['https://www.wikidata.org/wiki/Q688493']
# ['https://www.wikidata.org/wiki/Q688493', 'https://www.wikidata.org/wiki/Q178113']
# Cellier
# ['https://www.wikidata.org/wiki/Q21501975']
# Norine
# ['https://www.wikidata.org/wiki/Q161276']
# ['https://www.wikidata.org/wiki/Q161276', 'https://www.wikidata.org/wiki/Q21501975']
# Saint-Brunelle
# ['https://www.wikidata.org/wiki/Q5308236']
# ['https://www.wikidata.org/wiki/Q5308236', 'https://www.wikidata.org/wiki/Q106106']
# Armandine, la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q945470']
# Désirée
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q945470']
# réserve de la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q945470']
# Norine
# ['https://www.wikidata.org/wiki/Q4026988']
# ['https://www.wikidata.org/wiki/Q4026988', 'https://www.wikidata.org/wiki/Q26714904']
# ['https://www.wikidata.org/wiki/Q4026988', 'https://www.wikidata.org/wiki/Q26714904', 'https://www.wikidata.org/wiki/Q15207004']
# ['https://www.wikidata.org/wiki/Q4026988', 'https://www.wikidata.org/wiki/Q26714904', 'https://www.wikidata.org/wiki/Q15207004', 'https://www.wikidata.org/wiki/Q82818']
# la Rose
# ['https://www.wikidata.org/wiki/Q28457633']
# ['https://www.wikidata.org/wiki/Q28457633', 'https://www.wikidata.org/wiki/Q5446007']
# ['https://www.wikidata.org/wiki/Q28457633', 'https://www.wikidata.org/wiki/Q5446007', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q28457633', 'https://www.wikidata.org/wiki/Q5446007', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q28457633']
# ['https://www.wikidata.org/wiki/Q28457633', 'https://www.wikidata.org/wiki/Q5446007', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q28457633', 'https://www.wikidata.org/wiki/Q7165022']
# garçonnière
# ['https://www.wikidata.org/wiki/Q3822506']
# ['https://www.wikidata.org/wiki/Q3822506', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q3822506', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q21199']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q1444969']
# ['https://www.wikidata.org/wiki/Q1444969', 'https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q539643']
# Perpétue
# ['https://www.wikidata.org/wiki/Q101935']
# ['https://www.wikidata.org/wiki/Q101935', 'https://www.wikidata.org/wiki/Q3027560']
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# ['https://www.wikidata.org/wiki/Q3027560', 'https://www.wikidata.org/wiki/Q18373']
# Garde-les
# ['https://www.wikidata.org/wiki/Q1092777']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q1092777']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051']
# ['https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464']
# Norine
# ['https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q5155503']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q5155503', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q5155503', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q237375']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q27031051']
# ['https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q5155503']
# ['https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q5155503', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q27031051', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q5155503', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q618']
# Basset
# ['https://www.wikidata.org/wiki/Q4868070']
# ['https://www.wikidata.org/wiki/Q4868070', 'https://www.wikidata.org/wiki/Q28129894']
# Roux
# ['https://www.wikidata.org/wiki/Q957769']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q791134']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q791134', 'https://www.wikidata.org/wiki/Q6750275']
# la Bassette
# ['https://www.wikidata.org/wiki/Q6750275']
# ['https://www.wikidata.org/wiki/Q6750275', 'https://www.wikidata.org/wiki/Q188451']
# ['https://www.wikidata.org/wiki/Q6750275', 'https://www.wikidata.org/wiki/Q188451', 'https://www.wikidata.org/wiki/Q1097080']
# La Rose
# ['https://www.wikidata.org/wiki/Q58680']
# ['https://www.wikidata.org/wiki/Q58680', 'https://www.wikidata.org/wiki/Q48103']
# ['https://www.wikidata.org/wiki/Q58680', 'https://www.wikidata.org/wiki/Q48103', 'https://www.wikidata.org/wiki/Q519034']
# Gaspard
# ['https://www.wikidata.org/wiki/Q495271']
# Trente-six !
# Gaspard
# la Rose !
# ['https://www.wikidata.org/wiki/Q180309']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q15444128']
# Hardi
# ['https://www.wikidata.org/wiki/Q180309']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q15444128']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q15444128', 'https://www.wikidata.org/wiki/Q1108141']
# Gaspard
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q15444128']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q15444128', 'https://www.wikidata.org/wiki/Q1108141']
# Norine
# ['https://www.wikidata.org/wiki/Q15444128']
# ['https://www.wikidata.org/wiki/Q15444128', 'https://www.wikidata.org/wiki/Q1108141']
# Gaspard
# ['https://www.wikidata.org/wiki/Q11574']
# Jacqueline
# ['https://www.wikidata.org/wiki/Q6898686']
# ['https://www.wikidata.org/wiki/Q6898686', 'https://www.wikidata.org/wiki/Q1799831']
# ['https://www.wikidata.org/wiki/Q6898686', 'https://www.wikidata.org/wiki/Q1799831', 'https://www.wikidata.org/wiki/Q3226476']
# ['https://www.wikidata.org/wiki/Q6898686', 'https://www.wikidata.org/wiki/Q1799831', 'https://www.wikidata.org/wiki/Q3226476', 'https://www.wikidata.org/wiki/Q391321']
# Gaspard
# Norine
# ['https://www.wikidata.org/wiki/Q1757650']
# ['https://www.wikidata.org/wiki/Q1757650', 'https://www.wikidata.org/wiki/Q945470']
# ['https://www.wikidata.org/wiki/Q1757650', 'https://www.wikidata.org/wiki/Q945470', 'https://www.wikidata.org/wiki/Q1426138']
# Désirée
# ['https://www.wikidata.org/wiki/Q1757650']
# ['https://www.wikidata.org/wiki/Q1757650', 'https://www.wikidata.org/wiki/Q945470']
# ['https://www.wikidata.org/wiki/Q1757650', 'https://www.wikidata.org/wiki/Q945470', 'https://www.wikidata.org/wiki/Q1426138']
# ['https://www.wikidata.org/wiki/Q1757650', 'https://www.wikidata.org/wiki/Q945470', 'https://www.wikidata.org/wiki/Q1426138', 'https://www.wikidata.org/wiki/Q5105328']
# Leroy
# ['https://www.wikidata.org/wiki/Q375619']
# ['https://www.wikidata.org/wiki/Q375619', 'https://www.wikidata.org/wiki/Q5105328']
# ['https://www.wikidata.org/wiki/Q375619', 'https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q1068404']
# ['https://www.wikidata.org/wiki/Q375619', 'https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q1068404', 'https://www.wikidata.org/wiki/Q580750']
# Hé
# ['https://www.wikidata.org/wiki/Q5105328']
# ['https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q1068404']
# ['https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q1068404', 'https://www.wikidata.org/wiki/Q580750']
# Désirée
# ['https://www.wikidata.org/wiki/Q11574']
# ['https://www.wikidata.org/wiki/Q11574', 'https://www.wikidata.org/wiki/Q945470']
# ['https://www.wikidata.org/wiki/Q11574', 'https://www.wikidata.org/wiki/Q945470', 'https://www.wikidata.org/wiki/Q5357120']
# ['https://www.wikidata.org/wiki/Q11574', 'https://www.wikidata.org/wiki/Q945470', 'https://www.wikidata.org/wiki/Q5357120', 'https://www.wikidata.org/wiki/Q984179']
# Roux
# ['https://www.wikidata.org/wiki/Q580750']
# ['https://www.wikidata.org/wiki/Q580750', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q580750', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q11573']
# Gaspard
# ['https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q1697305']
# Jacqueline
# ['https://www.wikidata.org/wiki/Q1697305']
# Roux
# ['https://www.wikidata.org/wiki/Q191118']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q391321']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q519034']
# Gaspard
# ['https://www.wikidata.org/wiki/Q391321']
# ['https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200']
# ['https://www.wikidata.org/wiki/Q391321', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q3711325']
# Pierre, le dragon
# ['https://www.wikidata.org/wiki/Q3303226']
# ['https://www.wikidata.org/wiki/Q3303226', 'https://www.wikidata.org/wiki/Q273441']
# ['https://www.wikidata.org/wiki/Q3303226', 'https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q3303226', 'https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# ['https://www.wikidata.org/wiki/Q3303226', 'https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q12608302']
# ['https://www.wikidata.org/wiki/Q3303226', 'https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q12608302', 'https://www.wikidata.org/wiki/Q40747']
# Chante
# ['https://www.wikidata.org/wiki/Q82435']
# ['https://www.wikidata.org/wiki/Q82435', 'https://www.wikidata.org/wiki/Q231043']
# ['https://www.wikidata.org/wiki/Q82435', 'https://www.wikidata.org/wiki/Q231043', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q82435', 'https://www.wikidata.org/wiki/Q231043', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q82435', 'https://www.wikidata.org/wiki/Q231043', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q7559']
# la Rose
# ['https://www.wikidata.org/wiki/Q231043']
# ['https://www.wikidata.org/wiki/Q231043', 'https://www.wikidata.org/wiki/Q7559']
# ['https://www.wikidata.org/wiki/Q231043', 'https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q191118']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q231043']
# ['https://www.wikidata.org/wiki/Q231043', 'https://www.wikidata.org/wiki/Q7559']
# Rose d'un ton piqué
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1505201']
# Chante
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1505201']
# Gaspard
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1505201']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Norine
# ['https://www.wikidata.org/wiki/Q201157']
# Perpétue
# ['https://www.wikidata.org/wiki/Q10464']
# fieu de Toinon
# Méchante bigote
# ['https://www.wikidata.org/wiki/Q6529813']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q6529813']
# ['https://www.wikidata.org/wiki/Q6529813', 'https://www.wikidata.org/wiki/Q3400985']
# Jeanneton
# ['https://www.wikidata.org/wiki/Q1062400']
# ['https://www.wikidata.org/wiki/Q1062400', 'https://www.wikidata.org/wiki/Q450598']
# Las
# Jeanneton
# ['https://www.wikidata.org/wiki/Q626325']
# Las
# Jeanneton
# Trois cavaliers de renom
# ['https://www.wikidata.org/wiki/Q162990']
# ['https://www.wikidata.org/wiki/Q162990', 'https://www.wikidata.org/wiki/Q7521081']
# Las
# ['https://www.wikidata.org/wiki/Q162990']
# Jeanneton
# ['https://www.wikidata.org/wiki/Q5323774']
# ['https://www.wikidata.org/wiki/Q5323774', 'https://www.wikidata.org/wiki/Q162990']
# Trois cavaliers de renom
# ['https://www.wikidata.org/wiki/Q162990']
# ['https://www.wikidata.org/wiki/Q162990', 'https://www.wikidata.org/wiki/Q631280']
# ['https://www.wikidata.org/wiki/Q162990', 'https://www.wikidata.org/wiki/Q631280', 'https://www.wikidata.org/wiki/Q65117675']
# ['https://www.wikidata.org/wiki/Q162990', 'https://www.wikidata.org/wiki/Q631280', 'https://www.wikidata.org/wiki/Q65117675', 'https://www.wikidata.org/wiki/Q631280']
# Las
# ['https://www.wikidata.org/wiki/Q631280']
# ['https://www.wikidata.org/wiki/Q631280', 'https://www.wikidata.org/wiki/Q65117675']
# ['https://www.wikidata.org/wiki/Q631280', 'https://www.wikidata.org/wiki/Q65117675', 'https://www.wikidata.org/wiki/Q631280']
# Jeanneton
# ['https://www.wikidata.org/wiki/Q631280']
# ['https://www.wikidata.org/wiki/Q631280', 'https://www.wikidata.org/wiki/Q65117675']
# ['https://www.wikidata.org/wiki/Q631280', 'https://www.wikidata.org/wiki/Q65117675', 'https://www.wikidata.org/wiki/Q13360264']
# Las
# ['https://www.wikidata.org/wiki/Q180083']
# Jeanneton
# ['https://www.wikidata.org/wiki/Q56508']
# Jeanneton
# Perpétue, dit le père Roux
# ['https://www.wikidata.org/wiki/Q206678']
# ['https://www.wikidata.org/wiki/Q206678', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q206678', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q206678', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q59220438']
# ['https://www.wikidata.org/wiki/Q206678', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q59220438', 'https://www.wikidata.org/wiki/Q208197']
# Marie
# ['https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q59220438']
# Remblay
# ['https://www.wikidata.org/wiki/Q59220438']
# ['https://www.wikidata.org/wiki/Q59220438', 'https://www.wikidata.org/wiki/Q3184003']
# Comment !
# ['https://www.wikidata.org/wiki/Q11573']
# Vermand
# ['https://www.wikidata.org/wiki/Q253276']
# ['https://www.wikidata.org/wiki/Q253276', 'https://www.wikidata.org/wiki/Q994711']
# Vermand
# ['https://www.wikidata.org/wiki/Q994711']
# ['https://www.wikidata.org/wiki/Q994711', 'https://www.wikidata.org/wiki/Q142']
# ['https://www.wikidata.org/wiki/Q994711', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q82435']
# de France
# ['https://www.wikidata.org/wiki/Q994711']
# ['https://www.wikidata.org/wiki/Q994711', 'https://www.wikidata.org/wiki/Q142']
# Roux
# ['https://www.wikidata.org/wiki/Q499594']
# ['https://www.wikidata.org/wiki/Q499594', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q499594', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q206621']
# Pierre
# ['https://www.wikidata.org/wiki/Q10200']
# ['https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q5155503']
# Remblay
# ['https://www.wikidata.org/wiki/Q678464']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q678464', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q5155503']
# Ch' solé
# ['https://www.wikidata.org/wiki/Q191609']
# ['https://www.wikidata.org/wiki/Q191609', 'https://www.wikidata.org/wiki/Q142237']
# Ch' mouguet flourit
# ['https://www.wikidata.org/wiki/Q142237']
# ['https://www.wikidata.org/wiki/Q142237', 'https://www.wikidata.org/wiki/Q1058541']
# V'nez
# ['https://www.wikidata.org/wiki/Q142237']
# ['https://www.wikidata.org/wiki/Q142237', 'https://www.wikidata.org/wiki/Q1058541']
# leu
# ['https://www.wikidata.org/wiki/Q33968']
# ['https://www.wikidata.org/wiki/Q33968', 'https://www.wikidata.org/wiki/Q630080']
# ['https://www.wikidata.org/wiki/Q33968', 'https://www.wikidata.org/wiki/Q630080', 'https://www.wikidata.org/wiki/Q42395']
# Eussiez
# ['https://www.wikidata.org/wiki/Q7279114']
# ['https://www.wikidata.org/wiki/Q7279114', 'https://www.wikidata.org/wiki/Q9973']
# ['https://www.wikidata.org/wiki/Q7279114', 'https://www.wikidata.org/wiki/Q9973', 'https://www.wikidata.org/wiki/Q7838854']
# ['https://www.wikidata.org/wiki/Q7279114', 'https://www.wikidata.org/wiki/Q9973', 'https://www.wikidata.org/wiki/Q7838854', 'https://www.wikidata.org/wiki/Q335927']
# Y foët
# ['https://www.wikidata.org/wiki/Q9973']
# ['https://www.wikidata.org/wiki/Q9973', 'https://www.wikidata.org/wiki/Q7838854']
# ['https://www.wikidata.org/wiki/Q9973', 'https://www.wikidata.org/wiki/Q7838854', 'https://www.wikidata.org/wiki/Q630080']
# ché
# ['https://www.wikidata.org/wiki/Q206678']
# ['https://www.wikidata.org/wiki/Q206678', 'https://www.wikidata.org/wiki/Q9973']
# ['https://www.wikidata.org/wiki/Q206678', 'https://www.wikidata.org/wiki/Q9973', 'https://www.wikidata.org/wiki/Q630080']
# Saint-Quentin
# ['https://www.wikidata.org/wiki/Q281096']
# ['https://www.wikidata.org/wiki/Q281096', 'https://www.wikidata.org/wiki/Q21450850']
# ['https://www.wikidata.org/wiki/Q281096', 'https://www.wikidata.org/wiki/Q21450850', 'https://www.wikidata.org/wiki/Q182744']
# Nom-de-Nom
# Roux
# ['https://www.wikidata.org/wiki/Q4698652']
# ['https://www.wikidata.org/wiki/Q4698652', 'https://www.wikidata.org/wiki/Q2561124']
# ['https://www.wikidata.org/wiki/Q4698652', 'https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q4698652', 'https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q4698652', 'https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q1143040']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q2561124']
# ['https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q3164791']
# Allez
# ['https://www.wikidata.org/wiki/Q7559']
# ['https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q5105328']
# ['https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q5105328']
# ['https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q3164791']
# Hé
# ['https://www.wikidata.org/wiki/Q450598']
# Nom-de-Nom
# ['https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q2561124']
# Ah !
# ['https://www.wikidata.org/wiki/Q2561124']
# ['https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q869406']
# ['https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q869406', 'https://www.wikidata.org/wiki/Q472666']
# ['https://www.wikidata.org/wiki/Q2561124', 'https://www.wikidata.org/wiki/Q869406', 'https://www.wikidata.org/wiki/Q472666', 'https://www.wikidata.org/wiki/Q7841232']
# Chausson-Chaussette
# ['https://www.wikidata.org/wiki/Q472666']
# ['https://www.wikidata.org/wiki/Q472666', 'https://www.wikidata.org/wiki/Q2961656']
# ['https://www.wikidata.org/wiki/Q472666', 'https://www.wikidata.org/wiki/Q2961656', 'https://www.wikidata.org/wiki/Q180309']
# ['https://www.wikidata.org/wiki/Q472666', 'https://www.wikidata.org/wiki/Q2961656', 'https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q1082350']
# M'
# ['https://www.wikidata.org/wiki/Q1082350']
# ['https://www.wikidata.org/wiki/Q1082350', 'https://www.wikidata.org/wiki/Q6750275']
# Sylvain
# ['https://www.wikidata.org/wiki/Q16281827']
# Nom-de-Nom
# ['https://www.wikidata.org/wiki/Q16281827']
# ['https://www.wikidata.org/wiki/Q16281827', 'https://www.wikidata.org/wiki/Q2239017']
# ['https://www.wikidata.org/wiki/Q16281827', 'https://www.wikidata.org/wiki/Q2239017', 'https://www.wikidata.org/wiki/Q3365977']
# Nom-de-Nom
# ['https://www.wikidata.org/wiki/Q188473']
# ['https://www.wikidata.org/wiki/Q188473', 'https://www.wikidata.org/wiki/Q2637489']
# ['https://www.wikidata.org/wiki/Q188473', 'https://www.wikidata.org/wiki/Q2637489', 'https://www.wikidata.org/wiki/Q20880877']
# Adonc
# ['https://www.wikidata.org/wiki/Q2637489']
# ['https://www.wikidata.org/wiki/Q2637489', 'https://www.wikidata.org/wiki/Q20880877']
# réserve de Gaspard
# ['https://www.wikidata.org/wiki/Q156389']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q7559']
# Rose
# ['https://www.wikidata.org/wiki/Q7559']
# ['https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q472666']
# Toussaint
# ['https://www.wikidata.org/wiki/Q472666']
# ['https://www.wikidata.org/wiki/Q472666', 'https://www.wikidata.org/wiki/Q945051']
# ['https://www.wikidata.org/wiki/Q472666', 'https://www.wikidata.org/wiki/Q945051', 'https://www.wikidata.org/wiki/Q956243']
# ['https://www.wikidata.org/wiki/Q472666', 'https://www.wikidata.org/wiki/Q945051', 'https://www.wikidata.org/wiki/Q956243', 'https://www.wikidata.org/wiki/Q6689698']
# Carrière-Fondue
# ['https://www.wikidata.org/wiki/Q461464']
# ['https://www.wikidata.org/wiki/Q461464', 'https://www.wikidata.org/wiki/Q180309']
# ['https://www.wikidata.org/wiki/Q461464', 'https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q190531']
# Chut !
# ['https://www.wikidata.org/wiki/Q21199']
# ['https://www.wikidata.org/wiki/Q21199', 'https://www.wikidata.org/wiki/Q2967709']
# ['https://www.wikidata.org/wiki/Q21199', 'https://www.wikidata.org/wiki/Q2967709', 'https://www.wikidata.org/wiki/Q2561124']
# Roux
# ['https://www.wikidata.org/wiki/Q18516840']
# ['https://www.wikidata.org/wiki/Q18516840', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q18516840', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q1670']
# ['https://www.wikidata.org/wiki/Q18516840', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q1670', 'https://www.wikidata.org/wiki/Q4739090']
# Ah !
# ['https://www.wikidata.org/wiki/Q390324']
# ['https://www.wikidata.org/wiki/Q390324', 'https://www.wikidata.org/wiki/Q1670']
# ['https://www.wikidata.org/wiki/Q390324', 'https://www.wikidata.org/wiki/Q1670', 'https://www.wikidata.org/wiki/Q869406']
# ['https://www.wikidata.org/wiki/Q390324', 'https://www.wikidata.org/wiki/Q1670', 'https://www.wikidata.org/wiki/Q869406', 'https://www.wikidata.org/wiki/Q450598']
# Assez !
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# ['https://www.wikidata.org/wiki/Q12608302']
# ['https://www.wikidata.org/wiki/Q12608302', 'https://www.wikidata.org/wiki/Q869406']
# Ah !
# ['https://www.wikidata.org/wiki/Q12608302']
# ['https://www.wikidata.org/wiki/Q12608302', 'https://www.wikidata.org/wiki/Q869406']
# ['https://www.wikidata.org/wiki/Q12608302', 'https://www.wikidata.org/wiki/Q869406', 'https://www.wikidata.org/wiki/Q28653703']
# Nom-de-Nom
# ['https://www.wikidata.org/wiki/Q869406']
# ['https://www.wikidata.org/wiki/Q869406', 'https://www.wikidata.org/wiki/Q6736712']
# ['https://www.wikidata.org/wiki/Q869406', 'https://www.wikidata.org/wiki/Q6736712', 'https://www.wikidata.org/wiki/Q11573']
# Te
# ['https://www.wikidata.org/wiki/Q2637489']
# ['https://www.wikidata.org/wiki/Q2637489', 'https://www.wikidata.org/wiki/Q220543']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Suffit !
# ['https://www.wikidata.org/wiki/Q1530412']
# ['https://www.wikidata.org/wiki/Q1530412', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q1530412', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2637489']
# ['https://www.wikidata.org/wiki/Q1530412', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2637489', 'https://www.wikidata.org/wiki/Q561854']
# Rose d'un air aimable
# ['https://www.wikidata.org/wiki/Q281096']
# ['https://www.wikidata.org/wiki/Q281096', 'https://www.wikidata.org/wiki/Q1530412']
# ['https://www.wikidata.org/wiki/Q281096', 'https://www.wikidata.org/wiki/Q1530412', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q281096', 'https://www.wikidata.org/wiki/Q1530412', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2637489']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q34442']
# Pierre
# ['https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q34442']
# Armandine
# ['https://www.wikidata.org/wiki/Q203005']
# Nom-de-Nom
# ['https://www.wikidata.org/wiki/Q82435']
# ['https://www.wikidata.org/wiki/Q82435', 'https://www.wikidata.org/wiki/Q45382']
# ['https://www.wikidata.org/wiki/Q82435', 'https://www.wikidata.org/wiki/Q45382', 'https://www.wikidata.org/wiki/Q5357120']
# Armandine
# ['https://www.wikidata.org/wiki/Q5357120']
# Remblay
# ['https://www.wikidata.org/wiki/Q17097794']
# ['https://www.wikidata.org/wiki/Q17097794', 'https://www.wikidata.org/wiki/Q156389']
# ['https://www.wikidata.org/wiki/Q17097794', 'https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q12608302']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q156389']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q12608302']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q12608302', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q12608302', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q17097794']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q12608302', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q17097794', 'https://www.wikidata.org/wiki/Q29561']
# la Remy
# ['https://www.wikidata.org/wiki/Q191118']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q318769']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q318769', 'https://www.wikidata.org/wiki/Q23009870']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q318769', 'https://www.wikidata.org/wiki/Q23009870', 'https://www.wikidata.org/wiki/Q367208']
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q44416']
# la Remy
# ['https://www.wikidata.org/wiki/Q633132']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q15436271']
# Roux
# ['https://www.wikidata.org/wiki/Q633132']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q15436271']
# ['https://www.wikidata.org/wiki/Q633132', 'https://www.wikidata.org/wiki/Q367208', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q15436271', 'https://www.wikidata.org/wiki/Q1368412']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q1336814']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q1336814']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q203005']
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q203005', 'https://www.wikidata.org/wiki/Q29561']
# Roux
# Norine
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q21450850']
# ['https://www.wikidata.org/wiki/Q21450850', 'https://www.wikidata.org/wiki/Q203005']
# ['https://www.wikidata.org/wiki/Q21450850', 'https://www.wikidata.org/wiki/Q203005', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q21450850', 'https://www.wikidata.org/wiki/Q203005', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q231043']
# Norine
# ['https://www.wikidata.org/wiki/Q21450850']
# ['https://www.wikidata.org/wiki/Q21450850', 'https://www.wikidata.org/wiki/Q203005']
# ['https://www.wikidata.org/wiki/Q21450850', 'https://www.wikidata.org/wiki/Q203005', 'https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q21450850', 'https://www.wikidata.org/wiki/Q203005', 'https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q231043']
# Norine
# ['https://www.wikidata.org/wiki/Q6529813']
# ['https://www.wikidata.org/wiki/Q6529813', 'https://www.wikidata.org/wiki/Q345127']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Perpétue
# ['https://www.wikidata.org/wiki/Q5155503']
# ['https://www.wikidata.org/wiki/Q5155503', 'https://www.wikidata.org/wiki/Q1196074']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Le bon Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# ['https://www.wikidata.org/wiki/Q3027560', 'https://www.wikidata.org/wiki/Q3103189']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# ['https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q2535134']
# ['https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q2535134', 'https://www.wikidata.org/wiki/Q2948542']
# sainte Vierge Marie
# ['https://www.wikidata.org/wiki/Q191118']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q2016301']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q2016301', 'https://www.wikidata.org/wiki/Q59220438']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q2016301', 'https://www.wikidata.org/wiki/Q59220438', 'https://www.wikidata.org/wiki/Q26714904']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q957769']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q2239017']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q2239017', 'https://www.wikidata.org/wiki/Q1336814']
# ['https://www.wikidata.org/wiki/Q957769', 'https://www.wikidata.org/wiki/Q2239017', 'https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q12608302']
# Mlle Léonie
# ['https://www.wikidata.org/wiki/Q2294']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q26869306']
# ['https://www.wikidata.org/wiki/Q26869306', 'https://www.wikidata.org/wiki/Q2366336']
# ['https://www.wikidata.org/wiki/Q26869306', 'https://www.wikidata.org/wiki/Q2366336', 'https://www.wikidata.org/wiki/Q1336814']
# ['https://www.wikidata.org/wiki/Q26869306', 'https://www.wikidata.org/wiki/Q2366336', 'https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q892376']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q484170']
# ['https://www.wikidata.org/wiki/Q484170', 'https://www.wikidata.org/wiki/Q1336814']
# ['https://www.wikidata.org/wiki/Q484170', 'https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q12608302']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Las !
# ['https://www.wikidata.org/wiki/Q5277153']
# ['https://www.wikidata.org/wiki/Q5277153', 'https://www.wikidata.org/wiki/Q532']
# Jeacquet
# Rose
# ['https://www.wikidata.org/wiki/Q41782']
# ['https://www.wikidata.org/wiki/Q41782', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q41782', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q519034']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q519034']
# Jeacquet
# ['https://www.wikidata.org/wiki/Q519034']
# Rose
# ['https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1059196']
# ['https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1059196', 'https://www.wikidata.org/wiki/Q2294']
# Jeacquet
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1059196']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q92764']
# Artaban
# ['https://www.wikidata.org/wiki/Q92764']
# ['https://www.wikidata.org/wiki/Q92764', 'https://www.wikidata.org/wiki/Q156389']
# Norine
# Plaisant
# ['https://www.wikidata.org/wiki/Q274581']
# ['https://www.wikidata.org/wiki/Q274581', 'https://www.wikidata.org/wiki/Q1092777']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Plaisant
# Pierre le dragon
# ['https://www.wikidata.org/wiki/Q1092777']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q16078362']
# Norine
# ['https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q45382']
# Expliquez
# ['https://www.wikidata.org/wiki/Q3303226']
# ['https://www.wikidata.org/wiki/Q3303226', 'https://www.wikidata.org/wiki/Q273441']
# Pierre
# ['https://www.wikidata.org/wiki/Q273441']
# ['https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q3184003']
# ['https://www.wikidata.org/wiki/Q273441', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q3184003', 'https://www.wikidata.org/wiki/Q750']
# Pierre
# ['https://www.wikidata.org/wiki/Q69546']
# ['https://www.wikidata.org/wiki/Q69546', 'https://www.wikidata.org/wiki/Q2078736']
# ['https://www.wikidata.org/wiki/Q69546', 'https://www.wikidata.org/wiki/Q2078736', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q69546', 'https://www.wikidata.org/wiki/Q2078736', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q1063745']
# ['https://www.wikidata.org/wiki/Q69546', 'https://www.wikidata.org/wiki/Q2078736', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q1063745', 'https://www.wikidata.org/wiki/Q2707807']
# Norine
# Doucettement
# ['https://www.wikidata.org/wiki/Q1697305']
# ['https://www.wikidata.org/wiki/Q1697305', 'https://www.wikidata.org/wiki/Q4162555']
# ['https://www.wikidata.org/wiki/Q1697305', 'https://www.wikidata.org/wiki/Q4162555', 'https://www.wikidata.org/wiki/Q752296']
# ['https://www.wikidata.org/wiki/Q1697305', 'https://www.wikidata.org/wiki/Q4162555', 'https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q1697305', 'https://www.wikidata.org/wiki/Q4162555', 'https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200']
# la Rose
# ['https://www.wikidata.org/wiki/Q4162555']
# ['https://www.wikidata.org/wiki/Q4162555', 'https://www.wikidata.org/wiki/Q752296']
# ['https://www.wikidata.org/wiki/Q4162555', 'https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q4162555', 'https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200']
# ['https://www.wikidata.org/wiki/Q4162555', 'https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q40747']
# Pierre
# ['https://www.wikidata.org/wiki/Q752296']
# ['https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200']
# ['https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q1532617']
# ['https://www.wikidata.org/wiki/Q752296', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q10200', 'https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q1532617', 'https://www.wikidata.org/wiki/Q8805']
# Gaspard
# Pierre
# ['https://www.wikidata.org/wiki/Q3211581']
# ['https://www.wikidata.org/wiki/Q3211581', 'https://www.wikidata.org/wiki/Q40747']
# Norine
# ['https://www.wikidata.org/wiki/Q7559']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q16078362']
# Maman
# ['https://www.wikidata.org/wiki/Q180887']
# ['https://www.wikidata.org/wiki/Q180887', 'https://www.wikidata.org/wiki/Q5446007']
# Tiens, ma Rose
# ['https://www.wikidata.org/wiki/Q7559']
# ['https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q208160']
# ['https://www.wikidata.org/wiki/Q7559', 'https://www.wikidata.org/wiki/Q208160', 'https://www.wikidata.org/wiki/Q519034']
# M'aimeras-tu
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q6750275']
# Rose
# ['https://www.wikidata.org/wiki/Q180309']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303', 'https://www.wikidata.org/wiki/Q76480958']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303', 'https://www.wikidata.org/wiki/Q76480958', 'https://www.wikidata.org/wiki/Q5464146']
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303', 'https://www.wikidata.org/wiki/Q76480958', 'https://www.wikidata.org/wiki/Q5464146', 'https://www.wikidata.org/wiki/Q1426138']
# Oh !
# ['https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303', 'https://www.wikidata.org/wiki/Q76480958']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303', 'https://www.wikidata.org/wiki/Q76480958', 'https://www.wikidata.org/wiki/Q5464146']
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2724303', 'https://www.wikidata.org/wiki/Q76480958', 'https://www.wikidata.org/wiki/Q5464146', 'https://www.wikidata.org/wiki/Q1426138']
# Pierre
# ['https://www.wikidata.org/wiki/Q9852']
# ...
# ['https://www.wikidata.org/wiki/Q23134335', 'https://www.wikidata.org/wiki/Q1059196', 'https://www.wikidata.org/wiki/Q5090537']
# ['https://www.wikidata.org/wiki/Q23134335', 'https://www.wikidata.org/wiki/Q1059196', 'https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677']
# ['https://www.wikidata.org/wiki/Q23134335', 'https://www.wikidata.org/wiki/Q1059196', 'https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661']
# du Nord
# ['https://www.wikidata.org/wiki/Q5090537']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q18119757']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819']
# Messieurs
# ['https://www.wikidata.org/wiki/Q5090537']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q18119757']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288']
# ['https://www.wikidata.org/wiki/Q5090537', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q16078362']
# Parisien connaft
# ['https://www.wikidata.org/wiki/Q18119757']
# ['https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819']
# ['https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288']
# ['https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q30600919']
# ['https://www.wikidata.org/wiki/Q18119757', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q30600919', 'https://www.wikidata.org/wiki/Q7252609']
# Paris
# ['https://www.wikidata.org/wiki/Q30600919']
# ['https://www.wikidata.org/wiki/Q30600919', 'https://www.wikidata.org/wiki/Q7252609']
# ['https://www.wikidata.org/wiki/Q30600919', 'https://www.wikidata.org/wiki/Q7252609', 'https://www.wikidata.org/wiki/Q90']
# ['https://www.wikidata.org/wiki/Q30600919', 'https://www.wikidata.org/wiki/Q7252609', 'https://www.wikidata.org/wiki/Q90', 'https://www.wikidata.org/wiki/Q7942475']
# de-
# ['https://www.wikidata.org/wiki/Q7942475']
# ['https://www.wikidata.org/wiki/Q7942475', 'https://www.wikidata.org/wiki/Q3387750']
# ['https://www.wikidata.org/wiki/Q7942475', 'https://www.wikidata.org/wiki/Q3387750', 'https://www.wikidata.org/wiki/Q465227']
# VILLAGE
# ['https://www.wikidata.org/wiki/Q3387750']
# ['https://www.wikidata.org/wiki/Q3387750', 'https://www.wikidata.org/wiki/Q465227']
# du Nord
# ['https://www.wikidata.org/wiki/Q1461413']
# ['https://www.wikidata.org/wiki/Q1461413', 'https://www.wikidata.org/wiki/Q12661']
# ['https://www.wikidata.org/wiki/Q1461413', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q41393']
# ['https://www.wikidata.org/wiki/Q1461413', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q41393', 'https://www.wikidata.org/wiki/Q6587194']
# lFrance
# ['https://www.wikidata.org/wiki/Q41393']
# ['https://www.wikidata.org/wiki/Q41393', 'https://www.wikidata.org/wiki/Q6587194']
# ['https://www.wikidata.org/wiki/Q41393', 'https://www.wikidata.org/wiki/Q6587194', 'https://www.wikidata.org/wiki/Q899409']
# ['https://www.wikidata.org/wiki/Q41393', 'https://www.wikidata.org/wiki/Q6587194', 'https://www.wikidata.org/wiki/Q899409', 'https://www.wikidata.org/wiki/Q631280']
# ['https://www.wikidata.org/wiki/Q41393', 'https://www.wikidata.org/wiki/Q6587194', 'https://www.wikidata.org/wiki/Q899409', 'https://www.wikidata.org/wiki/Q631280', 'https://www.wikidata.org/wiki/Q7897412']
# meme
# ['https://www.wikidata.org/wiki/Q453819']
# ['https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288']
# ['https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q180309']
# ['https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q219320']
# ['https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q219320', 'https://www.wikidata.org/wiki/Q122894']
# pou-r----
# s--
# ['https://www.wikidata.org/wiki/Q453819']
# ['https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288']
# ['https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q180309']
# ['https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288', 'https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q122894']
# Nord
# ['https://www.wikidata.org/wiki/Q14953']
# ['https://www.wikidata.org/wiki/Q14953', 'https://www.wikidata.org/wiki/Q122894']
# ['https://www.wikidata.org/wiki/Q14953', 'https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q12661']
# ['https://www.wikidata.org/wiki/Q14953', 'https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q12661', 'https://www.wikidata.org/wiki/Q1461413']
# Messieurs
# ['https://www.wikidata.org/wiki/Q1461413']
# ['https://www.wikidata.org/wiki/Q1461413', 'https://www.wikidata.org/wiki/Q1047476']
# ['https://www.wikidata.org/wiki/Q1461413', 'https://www.wikidata.org/wiki/Q1047476', 'https://www.wikidata.org/wiki/Q453819']
# ['https://www.wikidata.org/wiki/Q1461413', 'https://www.wikidata.org/wiki/Q1047476', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q1518288']
# AUX TRAINS DE TRAVAIL
# ['https://www.wikidata.org/wiki/Q1931128']
# ['https://www.wikidata.org/wiki/Q1931128', 'https://www.wikidata.org/wiki/Q453819']
# ['https://www.wikidata.org/wiki/Q1931128', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q7835862']
# ['https://www.wikidata.org/wiki/Q1931128', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q7835862', 'https://www.wikidata.org/wiki/Q21199']
# ['https://www.wikidata.org/wiki/Q1931128', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q7835862', 'https://www.wikidata.org/wiki/Q21199', 'https://www.wikidata.org/wiki/Q7865813']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q356936']
# ['https://www.wikidata.org/wiki/Q356936', 'https://www.wikidata.org/wiki/Q1308274']
# ['https://www.wikidata.org/wiki/Q356936', 'https://www.wikidata.org/wiki/Q1308274', 'https://www.wikidata.org/wiki/Q3164791']
# la France
# ['https://www.wikidata.org/wiki/Q122894']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q33038168']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q33038168', 'https://www.wikidata.org/wiki/Q44395']
# Roux
# ['https://www.wikidata.org/wiki/Q122894']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q142', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q33038168']
# Paris
# ['https://www.wikidata.org/wiki/Q5478058']
# ['https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157']
# ['https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598']
# ['https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q450598', 'https://www.wikidata.org/wiki/Q33038168']
# destination1
# MION VILLAGE
# ['https://www.wikidata.org/wiki/Q191118']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q48700367']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q48700367', 'https://www.wikidata.org/wiki/Q69546']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q48700367', 'https://www.wikidata.org/wiki/Q69546', 'https://www.wikidata.org/wiki/Q16043593']
# ['https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q48700367', 'https://www.wikidata.org/wiki/Q69546', 'https://www.wikidata.org/wiki/Q16043593', 'https://www.wikidata.org/wiki/Q465227']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ['https://www.wikidata.org/wiki/Q3164791', 'https://www.wikidata.org/wiki/Q3103189']
# Jopine
# ['https://www.wikidata.org/wiki/Q3184003']
# ['https://www.wikidata.org/wiki/Q3184003', 'https://www.wikidata.org/wiki/Q161519']
# ['https://www.wikidata.org/wiki/Q3184003', 'https://www.wikidata.org/wiki/Q161519', 'https://www.wikidata.org/wiki/Q7068814']
# ['https://www.wikidata.org/wiki/Q3184003', 'https://www.wikidata.org/wiki/Q161519', 'https://www.wikidata.org/wiki/Q7068814', 'https://www.wikidata.org/wiki/Q33038168']
# dix'jours
# ['https://www.wikidata.org/wiki/Q7068814']
# ['https://www.wikidata.org/wiki/Q7068814', 'https://www.wikidata.org/wiki/Q33038168']
# dCctour
# ['https://www.wikidata.org/wiki/Q82435']
# Rose
# ['https://www.wikidata.org/wiki/Q1063745']
# ['https://www.wikidata.org/wiki/Q1063745', 'https://www.wikidata.org/wiki/Q677']
# ['https://www.wikidata.org/wiki/Q1063745', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q17146837']
# ['https://www.wikidata.org/wiki/Q1063745', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# ['https://www.wikidata.org/wiki/Q1063745', 'https://www.wikidata.org/wiki/Q677', 'https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707', 'https://www.wikidata.org/wiki/Q519034']
# pdcti-
# tion-li
# ['https://www.wikidata.org/wiki/Q794']
# ['https://www.wikidata.org/wiki/Q794', 'https://www.wikidata.org/wiki/Q26911']
# ['https://www.wikidata.org/wiki/Q794', 'https://www.wikidata.org/wiki/Q26911', 'https://www.wikidata.org/wiki/Q347']
# ['https://www.wikidata.org/wiki/Q794', 'https://www.wikidata.org/wiki/Q26911', 'https://www.wikidata.org/wiki/Q347', 'https://www.wikidata.org/wiki/Q2566190']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Va, ma Rose
# ['https://www.wikidata.org/wiki/Q5105328']
# ['https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q519034']
# ['https://www.wikidata.org/wiki/Q5105328', 'https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q160070']
# Remblay
# ['https://www.wikidata.org/wiki/Q5478058']
# M'
# ['https://www.wikidata.org/wiki/Q4925706']
# ['https://www.wikidata.org/wiki/Q4925706', 'https://www.wikidata.org/wiki/Q56539707']
# ['https://www.wikidata.org/wiki/Q4925706', 'https://www.wikidata.org/wiki/Q56539707', 'https://www.wikidata.org/wiki/Q6750275']
# ['https://www.wikidata.org/wiki/Q4925706', 'https://www.wikidata.org/wiki/Q56539707', 'https://www.wikidata.org/wiki/Q6750275', 'https://www.wikidata.org/wiki/Q7401']
# Remblay
# ['https://www.wikidata.org/wiki/Q208160']
# ['https://www.wikidata.org/wiki/Q208160', 'https://www.wikidata.org/wiki/Q11402']
# ['https://www.wikidata.org/wiki/Q208160', 'https://www.wikidata.org/wiki/Q11402', 'https://www.wikidata.org/wiki/Q1896571']
# ['https://www.wikidata.org/wiki/Q208160', 'https://www.wikidata.org/wiki/Q11402', 'https://www.wikidata.org/wiki/Q1896571', 'https://www.wikidata.org/wiki/Q5478058']
# Jean-
# u-
# ['https://www.wikidata.org/wiki/Q11402']
# ['https://www.wikidata.org/wiki/Q11402', 'https://www.wikidata.org/wiki/Q1896571']
# ['https://www.wikidata.org/wiki/Q11402', 'https://www.wikidata.org/wiki/Q1896571', 'https://www.wikidata.org/wiki/Q5478058']
# ['https://www.wikidata.org/wiki/Q11402', 'https://www.wikidata.org/wiki/Q1896571', 'https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q465227']
# Claude
# ['https://www.wikidata.org/wiki/Q465227']
# ET S0UHAITS
# t
# PRILRL ET
# ['https://www.wikidata.org/wiki/Q156389']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q122894']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q191118']
# ['https://www.wikidata.org/wiki/Q156389', 'https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q191118', 'https://www.wikidata.org/wiki/Q899409']
# pre oux
# ['https://www.wikidata.org/wiki/Q33038168']
# ['https://www.wikidata.org/wiki/Q33038168', 'https://www.wikidata.org/wiki/Q90']
# Paris
# s0UII
# lcs pays oi vous pla-
# cerez
# ['https://www.wikidata.org/wiki/Q1542187']
# ['https://www.wikidata.org/wiki/Q1542187', 'https://www.wikidata.org/wiki/Q3184003']
# ['https://www.wikidata.org/wiki/Q1542187', 'https://www.wikidata.org/wiki/Q3184003', 'https://www.wikidata.org/wiki/Q5377270']
# ['https://www.wikidata.org/wiki/Q1542187', 'https://www.wikidata.org/wiki/Q3184003', 'https://www.wikidata.org/wiki/Q5377270', 'https://www.wikidata.org/wiki/Q56539707']
# M. Ceran
# ['https://www.wikidata.org/wiki/Q10464']
# ['https://www.wikidata.org/wiki/Q10464', 'https://www.wikidata.org/wiki/Q6736712']
# ['https://www.wikidata.org/wiki/Q10464', 'https://www.wikidata.org/wiki/Q6736712', 'https://www.wikidata.org/wiki/Q8441']
# lh-dessusAotyde-
# E.:c
# fuble mon chapeau
# ['https://www.wikidata.org/wiki/Q122894']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q1062645']
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q1062645', 'https://www.wikidata.org/wiki/Q205006']
# Wotre
# ['https://www.wikidata.org/wiki/Q2479774']
# ['https://www.wikidata.org/wiki/Q2479774', 'https://www.wikidata.org/wiki/Q205006']
# L
# FRUCTUBUx CBLLIER
# ['https://www.wikidata.org/wiki/Q205006']

# %%
import json
import spacy  # version 3.5
import glob
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
data = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        compteur = 0
        intersect = 0
        nb_entite = 0

        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            
            liste_url_entourage = []
            liste_url_entite = []
            doc3 = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
                for d in liste_url_entite:
                    if d in liste_url_entourage:
                        intersect += 1
                    compteur += 1
            nb_entite += 1
        
        non = compteur - intersect
        print("La REN de Spacy a identifié", nb_entite, "entités")
        print("L'entity linker a repéré", compteur, "entités")
        print("Il y a", intersect, "éléments communs")
        print("Il y a", non, "éléments qui ne sont pas en commun")
        
        data.append({
            "Modèle": mod,
            "Fichier": path,
            "Entités Spacy": nb_entite,
            "Entités Entity Linker": compteur,
            "Entités communes": intersect,
            "Entités non communes": non
        })

# Création du tableau récapitulatif
df = pd.DataFrame(data)
print("\nTableau récapitulatif :")
print(df)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# La REN de Spacy a identifié 790 entités
# L'entity linker a repéré 653 entités
# Il y a 602 éléments communs
# Il y a 51 éléments qui ne sont pas en commun
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# La REN de Spacy a identifié 1256 entités
# L'entity linker a repéré 1072 entités
# Il y a 817 éléments communs
# Il y a 255 éléments qui ne sont pas en commun
#
# Tableau récapitulatif :
#   Modèle                                            Fichier  Entités Spacy  \
# 0     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...            790
# 1     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...           1256
#
#    Entités Entity Linker  Entités communes  Entités non communes
# 0                    653               602                    51
# 1                   1072               817                   255

# %%
import spacy  # version 3.5
import glob
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
data = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        compteur = 0
        intersect = 0
        nb_entite = 0

        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            
            liste_url_entourage = []
            liste_url_entite = []
            doc3 = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
            for d in liste_url_entite:
                if d in liste_url_entourage:
                    intersect += 1
                compteur += 1
            nb_entite += 1
        
        non = compteur - intersect
        print("La REN de Spacy a identifié", nb_entite, "entités")
        print("L'entity linker a repéré", compteur, "entités")
        print("Il y a", intersect, "éléments communs")
        print("Il y a", non, "éléments qui ne sont pas en communs")
        
        data.append({
            "Modèle": mod,
            "Fichier": path,
            "Entités Spacy": nb_entite,
            "Entités Entity Linker": compteur,
            "Entités communes": intersect,
            "Entités non communes": non
        })

# Création du tableau récapitulatif
df = pd.DataFrame(data)

# Affichage du tableau au format LaTeX
table_latex = df.to_latex(index=False)
print("\nTableau récapitulatif au format LaTeX :")
print(table_latex)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# La REN de Spacy a identifié 790 entités
# L'entity linker a repéré 580 entités
# Il y a 534 éléments communs
# Il y a 46 éléments qui ne sont pas en communs
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# La REN de Spacy a identifié 1256 entités
# L'entity linker a repéré 813 entités
# Il y a 616 éléments communs
# Il y a 197 éléments qui ne sont pas en communs
#
# Tableau récapitulatif au format LaTeX :
# \begin{tabular}{llrrrr}
# \toprule
# Modèle &                                            Fichier &  Entités Spacy &  Entités Entity Linker &  Entités communes &  Entités non communes \\
# \midrule
#     md & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &            790 &                    580 &               534 &                    46 \\
#     md & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &           1256 &                    813 &               616 &                   197 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_8066/270253411.py:65: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   table_latex = df.to_latex(index=False)

# %%
import spacy  # version 3.5
import glob
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
data = []
tab_entite = []
for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        compteur = 0
        intersect = 0
        nb_entite = 0

        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            #print ("pour l'entité", entite)
            liste_url_entourage = []
            liste_url_entite = []
            doc3 = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
                #print("Il y a",len(liste_url_entite),"url correspondantes. Ce sont", liste_url_entite)
                tab_entite.append({
                    "Modèle": mod,
                    "Fichier": path,
                    "Entité reconnue par la REN de SpaCy": entite,
                    "nb d'entités repérées par l'Entity Linker": len(liste_url_entite),
                    "Entités communes par l'Entity Linker": liste_url_entite,
                })

            for d in liste_url_entite:
                if d in liste_url_entourage:
                    intersect += 1
                compteur += 1
            nb_entite += 1
        
        non = compteur - intersect
        print("La REN de Spacy a identifié", nb_entite, "entités")
        print("L'entity linker a repéré", compteur, "entités")
        print("Il y a", intersect, "éléments communs")
        print("Il y a", non, "éléments qui ne sont pas en communs")
        
        data.append({
            "Modèle": mod,
            "Fichier": path,
            "Entités Spacy": nb_entite,
            "Entités Entity Linker": compteur,
            "Entités communes": intersect,
            "Entités non communes": non
        })
        
        

# Création du tableau récapitulatif
#df = pd.DataFrame(data)
df2 = pd.DataFrame(tab_entite)
print (df2)
# Affichage du tableau au format LaTeX
#table_latex = df.to_latex(index=False)
#table_latex2 = df2.to_latex(index=False)
#print("\nTableau récapitulatif au format LaTeX :")
#print(table_latex)
#print("\nTableau récapitulatif au format LaTeX :")
#print(table_latex2)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# La REN de Spacy a identifié 790 entités
# L'entity linker a repéré 580 entités
# Il y a 534 éléments communs
# Il y a 46 éléments qui ne sont pas en communs
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# La REN de Spacy a identifié 1256 entités
# L'entity linker a repéré 813 entités
# Il y a 616 éléments communs
# Il y a 197 éléments qui ne sont pas en communs
#      Modèle                                            Fichier  \
# 0        md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 1        md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 2        md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 3        md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 4        md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# ...     ...                                                ...
# 1388     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 1389     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 1390     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 1391     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 1392     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
#
#             Entité reconnue par la REN de SpaCy  \
# 0                                 Norine Duclos
# 1                                   Jean-Claude
# 2                                     Désirée !
# 3                                       Cellier
# 4                            Armandine, la Rose
# ...                                         ...
# 1388               lcs pays oi vous pla-\ncerez
# 1389               lcs pays oi vous pla-\ncerez
# 1390                                   M. Ceran
# 1391  lh-dessusAotyde-\nE.:c\nfuble mon chapeau
# 1392                       L\nFRUCTUBUx CBLLIER
#
#       nb d'entités repérées par l'Entity Linker  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
# ...                                         ...
# 1388                                          1
# 1389                                          2
# 1390                                          1
# 1391                                          1
# 1392                                          1
#
#                    Entités communes par l'Entity Linker
# 0             [https://www.wikidata.org/wiki/Q21450529]
# 1              [https://www.wikidata.org/wiki/Q3164791]
# 2               [https://www.wikidata.org/wiki/Q945470]
# 3             [https://www.wikidata.org/wiki/Q21501975]
# 4               [https://www.wikidata.org/wiki/Q519034]
# ...                                                 ...
# 1388  [https://www.wikidata.org/wiki/Q1542187, https...
# 1389  [https://www.wikidata.org/wiki/Q1542187, https...
# 1390              [https://www.wikidata.org/wiki/Q8441]
# 1391              [https://www.wikidata.org/wiki/Q9325]
# 1392              [https://www.wikidata.org/wiki/Q6203]
#
# [1393 rows x 5 columns]

# %%
import spacy  # version 3.5
import glob
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
data = []
tab_entite = []
tab_noncommun = []
for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        compteur = 0
        intersect = 0
        nb_entite = 0

        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            #print ("pour l'entité", entite)
            liste_url_entourage = []
            liste_url_entite = []
            doc3 = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
                #print("Il y a",len(liste_url_entite),"url correspondantes. Ce sont", liste_url_entite)
                tab_entite.append({
                    "Modèle": mod,
                    "Fichier": path,
                    "Entité reconnue par la REN de SpaCy": entite,
                    "nb d'entités repérées par l'Entity Linker": len(liste_url_entite),
                    "Entités reconnues par l'Entity Linker": liste_url_entite,
                })

            for d in liste_url_entite:
                if d in liste_url_entourage:
                    intersect += 1
                else :
                    tab_noncommun.append({
                    "Modèle": mod,
                    "Fichier": path,
                    "Entité reconnue par la REN de SpaCy": entite,
                    "entités reconnues pour l'Entity Linker sans contexte": liste_url_entite,
                    "entités reconnues pour l'Entity Linker en contexte": liste_url_entourage,
                })
                compteur += 1
            nb_entite += 1
        
        non = compteur - intersect
        print("La REN de Spacy a identifié", nb_entite, "entités")
        print("L'entity linker a repéré", compteur, "entités")
        print("Il y a", intersect, "éléments communs")
        print("Il y a", non, "éléments qui ne sont pas en communs")
        
        data.append({
            "Modèle": mod,
            "Fichier": path,
            "Entités Spacy": nb_entite,
            "Entités Entity Linker": compteur,
            "Entités communes": intersect,
            "Entités non communes": non
        })
df3 = pd.DataFrame(data)
print (df3)
table_latex3 = df3.to_latex(index=False)
print(table_latex3)
#table_latex2 = df2.to_latex(index=False)
#print("\nTableau récapitulatif au format LaTeX :")
#print(table_latex)
#print("\nTableau récapitulatif au format LaTeX :")
#print(table_latex2)
      
        
tab_noncommun
# Création du tableau récapitulatif
#df = pd.DataFrame(data)
#df2 = pd.DataFrame(tab_entite)
#print (df2)
# Affichage du tableau au format LaTeX
#table_latex = df.to_latex(index=False)
#table_latex2 = df2.to_latex(index=False)
#print("\nTableau récapitulatif au format LaTeX :")
#print(table_latex)
#print("\nTableau récapitulatif au format LaTeX :")
#print(table_latex2)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# La REN de Spacy a identifié 790 entités
# L'entity linker a repéré 580 entités
# Il y a 534 éléments communs
# Il y a 46 éléments qui ne sont pas en communs
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# La REN de Spacy a identifié 1256 entités
# L'entity linker a repéré 813 entités
# Il y a 616 éléments communs
# Il y a 197 éléments qui ne sont pas en communs
#   Modèle                                            Fichier  Entités Spacy  \
# 0     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...            790
# 1     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...           1256
#
#    Entités Entity Linker  Entités communes  Entités non communes
# 0                    580               534                    46
# 1                    813               616                   197
# \begin{tabular}{llrrrr}
# \toprule
# Modèle &                                            Fichier &  Entités Spacy &  Entités Entity Linker &  Entités communes &  Entités non communes \\
# \midrule
#     md & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &            790 &                    580 &               534 &                    46 \\
#     md & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &           1256 &                    813 &               616 &                   197 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_8066/612821602.py:80: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   table_latex3 = df3.to_latex(index=False)
# [{'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Désirée !',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q945470'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q688493',
#    'https://www.wikidata.org/wiki/Q178113']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jacqueline',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q391321'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1697305']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'la Rose',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q519034'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q231043',
#    'https://www.wikidata.org/wiki/Q7559',
#    'https://www.wikidata.org/wiki/Q191118']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q231043',
#    'https://www.wikidata.org/wiki/Q7559']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': "Rose d'un ton piqué",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q1505201',
#    'https://www.wikidata.org/wiki/Q11247037'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q1505201']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6529813',
#    'https://www.wikidata.org/wiki/Q3400985']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': "Ch' solé",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q142237',
#    'https://www.wikidata.org/wiki/Q7559068'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q191609',
#    'https://www.wikidata.org/wiki/Q142237']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1082350',
#    'https://www.wikidata.org/wiki/Q6750275']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Roux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Pierre',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q40747'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Rose, ma promise',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q1426138'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q735276',
#    'https://www.wikidata.org/wiki/Q48103',
#    'https://www.wikidata.org/wiki/Q40747']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Rose, ma promise',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q1426138'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q735276',
#    'https://www.wikidata.org/wiki/Q48103',
#    'https://www.wikidata.org/wiki/Q40747']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6750275',
#    'https://www.wikidata.org/wiki/Q131802']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Morlincourt',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q1336814'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1155562']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Madame',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q17146837'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q5655097']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6750275',
#    'https://www.wikidata.org/wiki/Q11582']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Si la Rose',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q519034'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Dieu',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3027560'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Clarisse Manot',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q733658',
#    'https://www.wikidata.org/wiki/Q2777738'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q92764',
#    'https://www.wikidata.org/wiki/Q16866073']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Clarisse Manot',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q733658',
#    'https://www.wikidata.org/wiki/Q2777738'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q92764',
#    'https://www.wikidata.org/wiki/Q16866073']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Clarisse',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q733658'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q758446']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'MAIRESSE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q56539707'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q391321']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Pierre le dragon',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q40747',
#    'https://www.wikidata.org/wiki/Q7559'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Pierre le dragon',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q40747',
#    'https://www.wikidata.org/wiki/Q7559'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Devise',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q69068'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q53815']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Un beau matin',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q16866073'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Madame',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q17146837'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q18031324',
#    'https://www.wikidata.org/wiki/Q6914419']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'fontaine Sainte-Radegonde',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q838235',
#    'https://www.wikidata.org/wiki/Q581707'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2707807']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'fontaine Sainte-Radegonde',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q838235',
#    'https://www.wikidata.org/wiki/Q581707'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2707807']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Toussaint',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q945051'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Roux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1063745']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Ah !',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q869406'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q56539707']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Et Dizy',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q741536'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q22993132',
#    'https://www.wikidata.org/wiki/Q3055244']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Dizy',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q741536'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1047476',
#    'https://www.wikidata.org/wiki/Q3164791']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'X \nCE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q28561969',
#    'https://www.wikidata.org/wiki/Q484876'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6736712']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'X \nCE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q28561969',
#    'https://www.wikidata.org/wiki/Q484876'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6736712']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Morlincourt',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q1336814'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Gens',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q5533554'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q428500',
#    'https://www.wikidata.org/wiki/Q1062400']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Morlincourt',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q1336814'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q273724',
#    'https://www.wikidata.org/wiki/Q6850',
#    'https://www.wikidata.org/wiki/Q791134',
#    'https://www.wikidata.org/wiki/Q6750275']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Céran',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q859610'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q17146837',
#    'https://www.wikidata.org/wiki/Q56539707']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'Saint-Brunelle des noces',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q27477490'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q536986']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': 'du Nord',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q12661'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q56539707',
#    'https://www.wikidata.org/wiki/Q6750275',
#    'https://www.wikidata.org/wiki/Q7401']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Norine Duclos',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q21450529'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q3646180',
#    'https://www.wikidata.org/wiki/Q3711325']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'ditle pere\nRoux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q5478058',
#    'https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'ditle pere\nRoux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q5478058',
#    'https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q707878']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Roux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q7930254']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': "Rose d'un ton pique",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q11247037'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q519034']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Voila',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2351943'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'MION',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q16043593'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q11582']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pre Roux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q679614',
#    'https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q11582',
#    'https://www.wikidata.org/wiki/Q201157',
#    'https://www.wikidata.org/wiki/Q450598']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'la mere Rem-\nblay',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q13586859',
#    'https://www.wikidata.org/wiki/Q841355'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q13586859',
#    'https://www.wikidata.org/wiki/Q3184003']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'ca la religion',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q16',
#    'https://www.wikidata.org/wiki/Q9174'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q3184003',
#    'https://www.wikidata.org/wiki/Q9174',
#    'https://www.wikidata.org/wiki/Q586615',
#    'https://www.wikidata.org/wiki/Q3184003']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Vermand',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q994711'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q122894',
#    'https://www.wikidata.org/wiki/Q82435']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'voila',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2351943'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1062400',
#    'https://www.wikidata.org/wiki/Q191609',
#    'https://www.wikidata.org/wiki/Q11688697']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': "Ml'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2539'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q204']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Fut-cel',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q182132',
#    'https://www.wikidata.org/wiki/Q1052736'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q956243',
#    'https://www.wikidata.org/wiki/Q6689698',
#    'https://www.wikidata.org/wiki/Q6974681']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Fut-cel',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q182132',
#    'https://www.wikidata.org/wiki/Q1052736'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q956243',
#    'https://www.wikidata.org/wiki/Q6689698',
#    'https://www.wikidata.org/wiki/Q6974681']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'ca\nvous sauterait h',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q16',
#    'https://www.wikidata.org/wiki/Q122894'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q843400',
#    'https://www.wikidata.org/wiki/Q122894',
#    'https://www.wikidata.org/wiki/Q1412049',
#    'https://www.wikidata.org/wiki/Q5522763']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'vai',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q168548'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q914462',
#    'https://www.wikidata.org/wiki/Q568735',
#    'https://www.wikidata.org/wiki/Q48103',
#    'https://www.wikidata.org/wiki/Q11574']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2637489',
#    'https://www.wikidata.org/wiki/Q849422']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'L----\nMON VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q519034',
#    'https://www.wikidata.org/wiki/Q2637489']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Ml Leonie',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2539',
#    'https://www.wikidata.org/wiki/Q6526597'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2294']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Ml Leonie',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2539',
#    'https://www.wikidata.org/wiki/Q6526597'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2294']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'meme de la',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q978'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2351943',
#    'https://www.wikidata.org/wiki/Q26869306',
#    'https://www.wikidata.org/wiki/Q2366336']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'eit',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3516835'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q69546',
#    'https://www.wikidata.org/wiki/Q1595418',
#    'https://www.wikidata.org/wiki/Q244762']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'voila',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2351943'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': "sij'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2875922'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q191118',
#    'https://www.wikidata.org/wiki/Q6666169',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q405',
#    'https://www.wikidata.org/wiki/Q532']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Plaisant lh',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q9325'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q499594',
#    'https://www.wikidata.org/wiki/Q7234232',
#    'https://www.wikidata.org/wiki/Q122894']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Pierre le dragon',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q40747',
#    'https://www.wikidata.org/wiki/Q7559'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q281096',
#    'https://www.wikidata.org/wiki/Q122894',
#    'https://www.wikidata.org/wiki/Q465227',
#    'https://www.wikidata.org/wiki/Q82435']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Pierre le dragon',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q40747',
#    'https://www.wikidata.org/wiki/Q7559'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q281096',
#    'https://www.wikidata.org/wiki/Q122894',
#    'https://www.wikidata.org/wiki/Q465227',
#    'https://www.wikidata.org/wiki/Q82435']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'sit0t la veillee',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q191118'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q465227',
#    'https://www.wikidata.org/wiki/Q235']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'baisers-l.\n',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q320980'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q122894',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q32704']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'voila',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2351943'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q3084981',
#    'https://www.wikidata.org/wiki/Q519034']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Ohl',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q902860'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'I-\nMON VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q176440']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Iais',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q10533272'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'la Rose',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q519034'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1059190',
#    'https://www.wikidata.org/wiki/Q465227']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q34943'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q465227']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'queussi-qucumi',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q180309'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q24556',
#    'https://www.wikidata.org/wiki/Q956243']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'M. Ccran',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q8441'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q28129894',
#    'https://www.wikidata.org/wiki/Q5308236',
#    'https://www.wikidata.org/wiki/Q180309']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Lcs',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q1542187'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q532',
#    'https://www.wikidata.org/wiki/Q1098428',
#    'https://www.wikidata.org/wiki/Q899409',
#    'https://www.wikidata.org/wiki/Q465227']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'de-\ngott',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q65079587'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q465227']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'lille',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q19516'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q56539707']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q34943'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1904',
#    'https://www.wikidata.org/wiki/Q8441']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'per visuml Avez-vous ete\ngourmands, ivrognes avez-ous',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q7111291'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Riez',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q457002'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q11582',
#    'https://www.wikidata.org/wiki/Q499594']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Saint-\nBrunelle',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q4978987'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q3027560',
#    'https://www.wikidata.org/wiki/Q1595418']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'nMON VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q7042684',
#    'https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1595418']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'nMON VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q7042684',
#    'https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1595418']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'E E',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2091584',
#    'https://www.wikidata.org/wiki/Q2091584'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q8043',
#    'https://www.wikidata.org/wiki/Q47192',
#    'https://www.wikidata.org/wiki/Q9887']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'E E',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2091584',
#    'https://www.wikidata.org/wiki/Q2091584'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q8043',
#    'https://www.wikidata.org/wiki/Q47192',
#    'https://www.wikidata.org/wiki/Q9887']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'reae b  eeeer\na-e\n   ..',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q8805',
#    'https://www.wikidata.org/wiki/Q9659',
#    'https://www.wikidata.org/wiki/Q82435'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6958062',
#    'https://www.wikidata.org/wiki/Q82435']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'reae b  eeeer\na-e\n   ..',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q8805',
#    'https://www.wikidata.org/wiki/Q9659',
#    'https://www.wikidata.org/wiki/Q82435'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6958062',
#    'https://www.wikidata.org/wiki/Q82435']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'A2',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q888603'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q8043',
#    'https://www.wikidata.org/wiki/Q204']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'S\n ae el e',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q682'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q191118']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'P¬\n ’  irei eyle ſleieee\n ere',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q8043'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2294',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q191118']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'tSee\nmrergnr eie\n H',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q556'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q126899',
#    'https://www.wikidata.org/wiki/Q9887',
#    'https://www.wikidata.org/wiki/Q682',
#    'https://www.wikidata.org/wiki/Q9739',
#    'https://www.wikidata.org/wiki/Q362021',
#    'https://www.wikidata.org/wiki/Q191',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q32704']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'nliodee\n eei',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q5383787'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1096',
#    'https://www.wikidata.org/wiki/Q8043']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'ee eii S',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q682'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q82435',
#    'https://www.wikidata.org/wiki/Q8043']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pe ole e e  deiee lo e i e ſeesers\nſtſtee',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2097883',
#    'https://www.wikidata.org/wiki/Q9211'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q704740',
#    'https://www.wikidata.org/wiki/Q191']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pe ole e e  deiee lo e i e ſeesers\nſtſtee',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2097883',
#    'https://www.wikidata.org/wiki/Q9211'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q704740',
#    'https://www.wikidata.org/wiki/Q191']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'SdS',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q222067'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q11621076',
#    'https://www.wikidata.org/wiki/Q7294741',
#    'https://www.wikidata.org/wiki/Q191118',
#    'https://www.wikidata.org/wiki/Q844976']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'le edel t',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q353823',
#    'https://www.wikidata.org/wiki/Q191118'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q11621076',
#    'https://www.wikidata.org/wiki/Q7294741',
#    'https://www.wikidata.org/wiki/Q191118',
#    'https://www.wikidata.org/wiki/Q844976']},
#  {'Modèle': 'md',
# ...
#   'Entité reconnue par la REN de SpaCy': 'Tour',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q117934'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1573906',
#    'https://www.wikidata.org/wiki/Q7897412',
#    'https://www.wikidata.org/wiki/Q82435']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pre Roux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q679614',
#    'https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1108141']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pre Roux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q679614',
#    'https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q1108141']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'tc dchangd',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q18221'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q16859830',
#    'https://www.wikidata.org/wiki/Q1226318',
#    'https://www.wikidata.org/wiki/Q1155562',
#    'https://www.wikidata.org/wiki/Q17146837']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'gce',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q646545'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q7838854',
#    'https://www.wikidata.org/wiki/Q16859830',
#    'https://www.wikidata.org/wiki/Q28129894']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Paris',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q90'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Palais-Royal',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q2102344'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q733658',
#    'https://www.wikidata.org/wiki/Q871',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q3164791',
#    'https://www.wikidata.org/wiki/Q8805']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q161276',
#    'https://www.wikidata.org/wiki/Q6750275',
#    'https://www.wikidata.org/wiki/Q201456']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'voila',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q2351943'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q191118',
#    'https://www.wikidata.org/wiki/Q2450590']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'decide h',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q5249148',
#    'https://www.wikidata.org/wiki/Q122894'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2450590',
#    'https://www.wikidata.org/wiki/Q22906900',
#    'https://www.wikidata.org/wiki/Q12608302']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'decide h',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q5249148',
#    'https://www.wikidata.org/wiki/Q122894'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2450590',
#    'https://www.wikidata.org/wiki/Q22906900',
#    'https://www.wikidata.org/wiki/Q12608302']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Monsieur',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q1092777'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q191118',
#    'https://www.wikidata.org/wiki/Q203005',
#    'https://www.wikidata.org/wiki/Q10200',
#    'https://www.wikidata.org/wiki/Q6850']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pre Roux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q679614',
#    'https://www.wikidata.org/wiki/Q201157'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q201157',
#    'https://www.wikidata.org/wiki/Q914307']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'oh tegarde',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q204'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q3113364']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6850']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'grene',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q5607460'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6950135',
#    'https://www.wikidata.org/wiki/Q122894']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'haut le picd!',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q18027543'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q805079']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Est',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q663187'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q2413314']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Cadet Lambin',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q61668028',
#    'https://www.wikidata.org/wiki/Q56244845'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Cadet Lambin',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q61668028',
#    'https://www.wikidata.org/wiki/Q56244845'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'La d6solation de la desolation',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3815359'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q6898686',
#    'https://www.wikidata.org/wiki/Q2016301']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'MI',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q11660'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q7838854',
#    'https://www.wikidata.org/wiki/Q100391']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'je1\n-\n\nMON VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q235',
#    'https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'je1\n-\n\nMON VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q235',
#    'https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'je1\n-\n\nMON VILLAGE',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q235',
#    'https://www.wikidata.org/wiki/Q465227'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Saint-Brunelle des noces',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q27477490'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q36919',
#    'https://www.wikidata.org/wiki/Q273724',
#    'https://www.wikidata.org/wiki/Q106106',
#    'https://www.wikidata.org/wiki/Q791134',
#    'https://www.wikidata.org/wiki/Q6750275']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Jean-Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q3164791'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q191118',
#    'https://www.wikidata.org/wiki/Q17146837',
#    'https://www.wikidata.org/wiki/Q56539707',
#    'https://www.wikidata.org/wiki/Q44127',
#    'https://www.wikidata.org/wiki/Q7138867']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pou-r----\ns--',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q13609402',
#    'https://www.wikidata.org/wiki/Q180309'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q453819',
#    'https://www.wikidata.org/wiki/Q1518288',
#    'https://www.wikidata.org/wiki/Q180309',
#    'https://www.wikidata.org/wiki/Q122894']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Paris',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q90'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q5478058',
#    'https://www.wikidata.org/wiki/Q201157',
#    'https://www.wikidata.org/wiki/Q450598',
#    'https://www.wikidata.org/wiki/Q33038168']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': "M'",
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q160669'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q4925706',
#    'https://www.wikidata.org/wiki/Q56539707',
#    'https://www.wikidata.org/wiki/Q6750275',
#    'https://www.wikidata.org/wiki/Q7401']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Claude',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q34943'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q465227']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'pre oux',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q679614'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q33038168',
#    'https://www.wikidata.org/wiki/Q90']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'Paris',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q90'],
#   "entités reconnues pour l'Entity Linker en contexte": []},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'lh-dessusAotyde-\nE.:c\nfuble mon chapeau',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q9325'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q122894',
#    'https://www.wikidata.org/wiki/Q1062645',
#    'https://www.wikidata.org/wiki/Q205006']},
#  {'Modèle': 'md',
#   'Fichier': '../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt',
#   'Entité reconnue par la REN de SpaCy': 'L\nFRUCTUBUx CBLLIER',
#   "entités reconnues pour l'Entity Linker sans contexte": ['https://www.wikidata.org/wiki/Q6203'],
#   "entités reconnues pour l'Entity Linker en contexte": ['https://www.wikidata.org/wiki/Q205006']}]

# %% [markdown]
# ## création de la fonction `tableau()`

# %%
def tableau(data):
    # Création du tableau récapitulatif
    df = pd.DataFrame(data)
    print (df)
    table_latex = df.to_latex(index=False)
    print(table_latex)
