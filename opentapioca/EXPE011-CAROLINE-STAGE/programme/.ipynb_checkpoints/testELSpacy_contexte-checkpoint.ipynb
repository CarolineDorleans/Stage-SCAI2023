# %% [markdown]
# 17/05/2023 au 25/05/2023
# objectif : faire la comparaison avec et sans contexte des performances du système d'entity linking de SpaCy
# contexte : notebook présenté lors de la réunion du 25/05/2023

# %% [markdown]
# # Evaluation comparative  du système d'entity linking de SpaCy

# %% [markdown]
# ## code donné par CKP

# %%
texte = lire_fichier(path)
text=nlp(texte)  
for ent in text.ents:
        list_resultats.append([ent.text, ent.start_char, ent.end_char, ent.label_,texte[ent.start_char-200:ent.start_char],texte[ent.end_char:ent.end_char+200]])

# %% [markdown]
# ## Première adaptation

# %%
import glob
import spacy
import json


def lire_fichier(chemin):
    with open (chemin, "r", encoding="utf-8") as fichier:
        texte=fichier.read()
        return texte

list_resultats=[]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"

for path in glob.glob(path_corpora):
    texte = lire_fichier(path)
    nlp = spacy.load("fr_core_news_sm")
    nlp.add_pipe("entityLinker", last=True)
    text=nlp(texte) 
    list_resultats=[]
    for ent in text.ents:
        list_resultats.append([ent.text, ent.start_char, ent.end_char, ent.label_,texte[ent.start_char-200:ent.start_char],ent.text,texte[ent.end_char:ent.end_char+200]])
print (list_resultats[0])
print (list_resultats[70])
# Out:
# ['Norine Duclos', 76, 89, 'PER', '', " qu'ont\nlieu les plus egayantes veilles de notre vil-\nlage. Adonc, certain soir, comme j'entrais\nchez Norine, je la trouvai en train de precher\nses trois petiotes.\n- He MIandine, criait-elle, dpeche-t"]
# ['petiot\nRoux', 5007, 5018, 'PER', "t Jean-Claude;\nle dragon viendra pendant ce temps-la.\n- Je veux, au contraire, l'attendre pour\nchanter, dit la Rose d'un ton pique.\n- Chante, dit Gaspard, ou sinon...\n-- Tu deviens par trop bravache, ", ', dit Norine; tache un peu de te tenir\ntranquille.\n- Je vas chanter, moi, dit le vieux berger.l-\nMION VI1LAGE.\n- lEn ce cas-la, je me sauve, dit la petiote\nh Perpetue.\n- Non, dit le fieu de Toinon, so']

# %% [markdown]
# ### Nous vérifions ensuite dans le texte si nous retrouvons bien les mêmes valeurs

# %% [markdown]
# "Depuis un nombre innombrable d’hivers, c’est dans la maison de Norine Duclos qu’ont lieu les plus égayantes veillées de notre village. Adonc, certain soir, comme j’entrais chez Norine, je la trouvai en train de prêcher ses trois petiotes. "

# %% [markdown]
# "- Chante, toi, la Rose, dit Jean-Claude;
# le dragon viendra pendant ce temps-la.
# - Je veux, au contraire, l'attendre pour
# chanter, dit la Rose d'un ton pique.
# - Chante, dit Gaspard, ou sinon...
# -- Tu deviens par trop bravache, petiot
# Roux, dit Norine; tache un peu de te tenir
# tranquille.
# - Je vas chanter, moi, dit le vieux berger.l-
# MION VI1LAGE.
# - lEn ce cas-la, je me sauve, dit la petiote
# h Perpetue."

# %% [markdown]
# ## Nous procédons à la NER puis appliquons l'entity linking aux entités hors contexte ...

# %%
import json
import spacy  # version 3.5
import glob
import matplotlib.pyplot as plt
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte

def stocker(chemin, contenu):
    with open(chemin, "w") as w:
        json.dump(contenu, w, indent=2)

modele = ["md"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
common_urls_per_file = []
common_urls = []
non_common_urls = []

modele=["sm","md","lg"]

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        list_resultats = []
        list_entites = []
        compteur = 0
        intersect = 0

        i = 1
        dico={}
        for ent in doc.ents:
            
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            print(entite)
            liste_url_entourage = []
            liste_url_entite = []
            doc2 = nlp(entite)
            doc3 = nlp(contexte)
            for ent in doc3._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc2._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
                for d in liste_url_entourage :
                    if d in liste_url_entite:
                        #print (d)
                        intersect = intersect + 1
            print (liste_url_entite)
            compteur +=1
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# VEILLÉE
# []
# Norine Duclos
# ['https://www.wikidata.org/wiki/Q21450529']
# Norine
# []
# Hé
# []
# Mandine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Désirée !
# ['https://www.wikidata.org/wiki/Q945470']
# Cellier
# ['https://www.wikidata.org/wiki/Q21501975']
# Norine
# []
# Saint-Brunelle
# []
# Armandine, la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# réserve de la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Norine
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# garçonnière
# ['https://www.wikidata.org/wiki/Q3822506']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Perpétue
# []
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Garde-les
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Basset
# ['https://www.wikidata.org/wiki/Q4868070']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# la Bassette
# []
# La Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Gaspard
# []
# Trente-six !
# []
# Gaspard
# []
# la Rose !
# ['https://www.wikidata.org/wiki/Q519034']
# Hardi
# ['https://www.wikidata.org/wiki/Q15444128']
# Gaspard
# []
# Norine
# []
# Gaspard
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Gaspard
# []
# Norine
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# Leroy
# ['https://www.wikidata.org/wiki/Q1068404']
# Hé
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Pierre, le dragon
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# Chante
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Rose d'un ton piqué
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1505201', 'https://www.wikidata.org/wiki/Q11247037']
# Chante
# []
# Gaspard
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Norine
# []
# Perpétue
# []
# fieu de Toinon
# []
# Méchante bigote
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jeanneton
# []
# Las
# []
# Jeanneton
# []
# Las
# []
# Jeanneton
# []
# Trois cavaliers de renom
# ['https://www.wikidata.org/wiki/Q162990']
# Las
# []
# Jeanneton
# []
# Trois cavaliers de renom
# ['https://www.wikidata.org/wiki/Q162990']
# Las
# []
# Jeanneton
# []
# Las
# []
# Jeanneton
# []
# Jeanneton
# []
# Perpétue, dit le père Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Marie
# ['https://www.wikidata.org/wiki/Q59220438']
# Remblay
# []
# Comment !
# []
# Vermand
# ['https://www.wikidata.org/wiki/Q994711']
# Vermand
# ['https://www.wikidata.org/wiki/Q994711']
# de France
# ['https://www.wikidata.org/wiki/Q142']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Remblay
# []
# Ch' solé
# ['https://www.wikidata.org/wiki/Q142237', 'https://www.wikidata.org/wiki/Q7559068']
# Ch' mouguet flourit
# []
# V'nez
# []
# leu
# ['https://www.wikidata.org/wiki/Q42395']
# Eussiez
# []
# Y foët
# ['https://www.wikidata.org/wiki/Q9973']
# ché
# []
# Saint-Quentin
# ['https://www.wikidata.org/wiki/Q182744']
# Nom-de-Nom
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Allez
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Hé
# []
# Nom-de-Nom
# []
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Chausson-Chaussette
# ['https://www.wikidata.org/wiki/Q2961656', 'https://www.wikidata.org/wiki/Q180309']
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# Sylvain
# ['https://www.wikidata.org/wiki/Q16281827']
# Nom-de-Nom
# []
# Nom-de-Nom
# []
# Adonc
# []
# réserve de Gaspard
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Toussaint
# ['https://www.wikidata.org/wiki/Q945051']
# Carrière-Fondue
# ['https://www.wikidata.org/wiki/Q461464', 'https://www.wikidata.org/wiki/Q190531']
# Chut !
# ['https://www.wikidata.org/wiki/Q2967709']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Assez !
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Nom-de-Nom
# []
# Te
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Suffit !
# []
# Rose d'un air aimable
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2637489']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Armandine
# []
# Nom-de-Nom
# []
# Armandine
# []
# Remblay
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# la Remy
# ['https://www.wikidata.org/wiki/Q367208']
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# la Remy
# ['https://www.wikidata.org/wiki/Q367208']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Perpétue
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Le bon Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# sainte Vierge Marie
# ['https://www.wikidata.org/wiki/Q59220438']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Mlle Léonie
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Las !
# []
# Jeacquet
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jeacquet
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jeacquet
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Artaban
# []
# Norine
# []
# Plaisant
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Plaisant
# []
# Pierre le dragon
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# Norine
# []
# Expliquez
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Norine
# []
# Doucettement
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Gaspard
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Norine
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Maman
# ['https://www.wikidata.org/wiki/Q180887']
# Tiens, ma Rose
# ['https://www.wikidata.org/wiki/Q519034']
# M'aimeras-tu
# ['https://www.wikidata.org/wiki/Q6750275']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Oh !
# ['https://www.wikidata.org/wiki/Q2724303']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Oh !
# ['https://www.wikidata.org/wiki/Q2724303']
# Jure-moi
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Ça
# []
# Jure
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Norine
# []
# Oh !
# ['https://www.wikidata.org/wiki/Q2724303']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Rose :
# on a comme deux cœurs
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q573837']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Norine
# []
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Norine
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# bravacherie
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Tope
# []
# Rose, les hommes
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q548924']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Tiens !
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Rose, ma promise
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1426138']
# PARIGOTS
# []
# Thérèse
# ['https://www.wikidata.org/wiki/Q3527366']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# Hé
# []
# Toinon
# []
# Tournez
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# Toinon
# []
# Jean-Claude aller
# ['https://www.wikidata.org/wiki/Q3164791']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# queussi-queumi
# ['https://www.wikidata.org/wiki/Q180309']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Feuillants
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Thérèse
# ['https://www.wikidata.org/wiki/Q3527366']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# Toinon
# []
# Si
# []
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Ouvrez !
# []
# Mes petiots
# []
# bon Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Favette
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jeacquet
# []
# Jeacquet
# []
# M.
# ['https://www.wikidata.org/wiki/Q8441']
# Jeacquet
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Oh !
# ['https://www.wikidata.org/wiki/Q2724303']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Maria, la sorcière
# ['https://www.wikidata.org/wiki/Q2845', 'https://www.wikidata.org/wiki/Q1984125']
# Maria
# ['https://www.wikidata.org/wiki/Q2845']
# Brûlée
# []
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# émotionnée
# []
# catimini
# []
# Savoyard
# []
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# Savoyard
# []
# Savoyard
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Allez
# []
# Céran
# ['https://www.wikidata.org/wiki/Q859610']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Céran
# ['https://www.wikidata.org/wiki/Q859610']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Morlinval
# []
# Saint-Brunelle
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# La Rose
# ['https://www.wikidata.org/wiki/Q519034']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Allez, allez !
# []
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Saint-Brunelle
# []
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Toinon
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Norine
# []
# Si la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Saint-Brunelle
# []
# Saint-Brunelle
# []
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# Pâques
# []
# Evigilabunt alii in vitam æternam
# ['https://www.wikidata.org/wiki/Q4726594', 'https://www.wikidata.org/wiki/Q18357695']
# alii in opprobrium
# ['https://www.wikidata.org/wiki/Q4726594']
# Mes chers frères !
# []
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# per visum !
# []
# Auriez
# []
# Vos mains
# ['https://www.wikidata.org/wiki/Q6736712']
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Bjitt
# []
# Riez
# ['https://www.wikidata.org/wiki/Q457002']
# Saint-Brunelle
# []
# Jeacquet le menteur
# ['https://www.wikidata.org/wiki/Q282163']
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Mlle Dorothée
# ['https://www.wikidata.org/wiki/Q448910']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# Saint-Brunelle
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Adonc
# []
# Clarisse Manot
# ['https://www.wikidata.org/wiki/Q733658', 'https://www.wikidata.org/wiki/Q2777738']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Content
# []
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Perpétue
# []
# Jeacquet le menteur
# ['https://www.wikidata.org/wiki/Q282163']
# Toinon
# []
# Clarisse Manot
# ['https://www.wikidata.org/wiki/Q733658', 'https://www.wikidata.org/wiki/Q2777738']
# cabaretière de Saint-Brunelle
# []
# dimanche de Pâques
# ['https://www.wikidata.org/wiki/Q5277153']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Hé
# []
# lurot
# []
# Va vitement t'asseoir,
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Thérèse
# ['https://www.wikidata.org/wiki/Q3527366']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Tâche
# []
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Tiens
# []
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Supposez
# []
# État
# ['https://www.wikidata.org/wiki/Q1069376']
# Charité
# ['https://www.wikidata.org/wiki/Q23815652']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Hé
# []
# Cellier
# ['https://www.wikidata.org/wiki/Q21501975']
# gouaillant
# []
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Ça
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# prise d'Alger
# ['https://www.wikidata.org/wiki/Q3561']
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Alger
# ['https://www.wikidata.org/wiki/Q3561']
# Sylvain
# ['https://www.wikidata.org/wiki/Q16281827']
# Nom-de-Nom
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Vive le roi
# ['https://www.wikidata.org/wiki/Q61037170']
# Jeacquet
# []
# Amen
# ['https://www.wikidata.org/wiki/Q58373']
# Vive le roi
# ['https://www.wikidata.org/wiki/Q61037170']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Jeacquet
# []
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# MAIRESSE
# ['https://www.wikidata.org/wiki/Q56539707']
# Gaspard
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre le dragon
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# Allez !
# []
# Devise
# ['https://www.wikidata.org/wiki/Q69068']
# Norine
# []
# Cachez
# []
# Saint-Brunelle
# []
# Allez
# []
# Cachez
# []
# Cachez
# []
# Fillettes
# []
# Norine
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# Armandine
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Un beau matin
# ['https://www.wikidata.org/wiki/Q16866073']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# catimini
# []
# Rose, la fillette
# ['https://www.wikidata.org/wiki/Q519034']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# Ma Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Norine
# []
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# ravigoter
# []
# Norine
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# Armandine
# []
# Rose, je viens vous tendre la main
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1670']
# Oh !
# ['https://www.wikidata.org/wiki/Q2724303']
# Norine
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Norine
# []
# rendez-
# []
# Norine
# []
# Allons
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Norine
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Armandine
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# Saint-Brunelle
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre le dragon
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# bon Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Toinon
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# sou
# []
# Saint-Brunelle
# []
# Craintifs
# []
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Morlinval
# []
# Morlinval
# []
# Céran
# ['https://www.wikidata.org/wiki/Q859610']
# fontaine Sainte-Radegonde
# ['https://www.wikidata.org/wiki/Q838235', 'https://www.wikidata.org/wiki/Q581707']
# niche Maria, la sorcière
# ['https://www.wikidata.org/wiki/Q695992', 'https://www.wikidata.org/wiki/Q2845', 'https://www.wikidata.org/wiki/Q1984125']
# Vulcain
# ['https://www.wikidata.org/wiki/Q44532']
# Saint-Brunelle
# []
# Gaspard
# []
# Denis
# ['https://www.wikidata.org/wiki/Q244380']
# fieu de Toinon
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Norine
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Denis
# ['https://www.wikidata.org/wiki/Q244380']
# Norine
# []
# Toinon
# []
# fieu de Toinon
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Denis
# ['https://www.wikidata.org/wiki/Q244380']
# Gaspard
# []
# fieu de Toinon
# []
# Vive la France !
# ['https://www.wikidata.org/wiki/Q142']
# B
# ['https://www.wikidata.org/wiki/Q618']
# Morlinval
# []
# Gaspard
# []
# Denis
# ['https://www.wikidata.org/wiki/Q244380']
# fieu de Toinon
# []
# Saint-Brunelle
# []
# pré Brugnon
# []
# pré Brugnon
# []
# Saint-Brunelle
# []
# mitan-côte
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q48699908']
# pré Brugnon
# []
# Adonc
# []
# pré Brugnon
# []
# couvent Brugnon
# []
# Toussaint
# ['https://www.wikidata.org/wiki/Q945051']
# pré Brugnon
# []
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Lambin
# ['https://www.wikidata.org/wiki/Q56244845']
# Perpétue
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Adonc
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Arrive
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Père Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Parle !
# ['https://www.wikidata.org/wiki/Q7138867']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Adonc
# []
# Attrape
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Saint-Brunelle
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Dizy l'avare
# ['https://www.wikidata.org/wiki/Q741536', 'https://www.wikidata.org/wiki/Q17049755']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Clarisse Manot
# ['https://www.wikidata.org/wiki/Q733658', 'https://www.wikidata.org/wiki/Q2777738']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Croyez-le
# []
# Hommes-sans-Têtes
# []
# Poulains
# []
# réserve des furolles
# []
# Norine
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Perpétue, tout terluit du haut
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Garnissons nos poches
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# Denis
# ['https://www.wikidata.org/wiki/Q244380']
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Pardine
# []
# Tiens
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Norine
# []
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Cellier
# ['https://www.wikidata.org/wiki/Q21501975']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# Rose au bras du maître d'école
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q3084981', 'https://www.wikidata.org/wiki/Q3303226', 'https://www.wikidata.org/wiki/Q273441']
# Vive
# []
# Vive
# []
# T'as un brave cœur !
# ['https://www.wikidata.org/wiki/Q22906900']
# Allez
# []
# Adonc
# []
# Désirée
# ['https://www.wikidata.org/wiki/Q945470']
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# cria Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Et Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# gouailla Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Me
# ['https://www.wikidata.org/wiki/Q619989']
# Clarisse Manot
# ['https://www.wikidata.org/wiki/Q733658', 'https://www.wikidata.org/wiki/Q2777738']
# enfeuiller
# []
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Me
# ['https://www.wikidata.org/wiki/Q619989']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Baptiste
# ['https://www.wikidata.org/wiki/Q63538437']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Baptiste
# ['https://www.wikidata.org/wiki/Q63538437']
# Baptiste
# ['https://www.wikidata.org/wiki/Q63538437']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Brugnon
# []
# Pater
# []
# Ave
# []
# sainte
# []
# Norine
# []
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# La Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Cellier
# ['https://www.wikidata.org/wiki/Q21501975']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Norine
# []
# Pardonnez-lui
# []
# Vive
# []
# Rose, le gars Denis
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q531813', 'https://www.wikidata.org/wiki/Q244380']
# Denis
# ['https://www.wikidata.org/wiki/Q244380']
# Norine
# []
# Rose du déshonneur
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# X
# CE
# ['https://www.wikidata.org/wiki/Q28561969', 'https://www.wikidata.org/wiki/Q484876']
# IL VOUS PLAIRA
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Pierrette
# ['https://www.wikidata.org/wiki/Q7192558']
# Norine
# []
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Gaspard
# []
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Gaspard
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Clarisse Manot
# ['https://www.wikidata.org/wiki/Q733658', 'https://www.wikidata.org/wiki/Q2777738']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# montagne blanche
# []
# Satané
# []
# Bah !
# ['https://www.wikidata.org/wiki/Q633132']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# colonne Vendôme
# ['https://www.wikidata.org/wiki/Q1234920', 'https://www.wikidata.org/wiki/Q214575']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Palais-Royal
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q2102344']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Palais-Royal
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q2102344']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Quoi !
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Saint-Brunelle
# []
# Excusez
# []
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# Parisien
# []
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# Parisiens
# ['https://www.wikidata.org/wiki/Q3072544']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Sortez des maisons, gais moissonneurs
# ['https://www.wikidata.org/wiki/Q536986']
# Alerte
# ['https://www.wikidata.org/wiki/Q22661961']
# Bonnets blancs
# []
# Alerte !
# ['https://www.wikidata.org/wiki/Q22661961']
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Sortez des maisons, gais moissonneurs
# ['https://www.wikidata.org/wiki/Q536986']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Gens
# ['https://www.wikidata.org/wiki/Q5533554']
# Morlinval
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Argent ! maudit argent !
# ['https://www.wikidata.org/wiki/Q2301367', 'https://www.wikidata.org/wiki/Q936472']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Céran
# ['https://www.wikidata.org/wiki/Q859610']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# lune
# ['https://www.wikidata.org/wiki/Q3518248']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Cadet Lambin
# ['https://www.wikidata.org/wiki/Q61668028', 'https://www.wikidata.org/wiki/Q56244845']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Courons
# []
# Mon pauvre homme !
# ['https://www.wikidata.org/wiki/Q12608302']
# Courons
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Saint-Brunelle
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# XII
# L'ÉPIDÉMIE
# []
# Cellier
# ['https://www.wikidata.org/wiki/Q21501975']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Céran
# ['https://www.wikidata.org/wiki/Q859610']
# Monsieur Céran
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q859610']
# Saint-Brunelle
# []
# Franciers
# []
# Céran
# ['https://www.wikidata.org/wiki/Q859610']
# Monsieur Céran
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q859610']
# Monsieur Céran
# ['https://www.wikidata.org/wiki/Q1092777', 'https://www.wikidata.org/wiki/Q859610']
# Tenez
# []
# Courez
# []
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Parlez-moi de cette bête-là
# ['https://www.wikidata.org/wiki/Q1444969']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Thérèse
# ['https://www.wikidata.org/wiki/Q3527366']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Thérèse
# ['https://www.wikidata.org/wiki/Q3527366']
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# Céran
# ['https://www.wikidata.org/wiki/Q859610']
# Mon bon ami
# ['https://www.wikidata.org/wiki/Q4940943']
# Saint-Brunelle des noces
# ['https://www.wikidata.org/wiki/Q27477490']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Autrefois
# []
# Saint-Brunelle
# []
# Las
# []
# le boursicaut
# []
# Saint-Brunelle
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# renie-Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Vénus
# ['https://www.wikidata.org/wiki/Q19898149']
# Bérénice
# ['https://www.wikidata.org/wiki/Q19877407']
# Cassiopée
# ['https://www.wikidata.org/wiki/Q2941296']
# La Rose
# ['https://www.wikidata.org/wiki/Q519034']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Expliquez
# []
# XIII
# UNE PÉTITION
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Messieurs
# []
# du Nord
# ['https://www.wikidata.org/wiki/Q12661']
# Messieurs
# []
# Parisien
# []
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# du Nord
# ['https://www.wikidata.org/wiki/Q12661']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# du Nord
# ['https://www.wikidata.org/wiki/Q12661']
# Messieurs
# []
# dussiez
# []
# Agréez
# []
# Messieurs
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Hein
# ['https://www.wikidata.org/wiki/Q1595911']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Avisez
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# répandre vitement
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Va, ma Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Remblay
# []
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# Allez !
# []
# Ta !
# ['https://www.wikidata.org/wiki/Q1123']
# Remblay
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Ah !
# ['https://www.wikidata.org/wiki/Q869406']
# Saint-Brunelle !
# []
# SOUHAITS
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# SOUHAITS
# []
# M. Céran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q859610']
# FRUCTUEUX CELLIER
# ['https://www.wikidata.org/wiki/Q21501975']
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# YEILLEE
# []
# Norine Duclos
# ['https://www.wikidata.org/wiki/Q21450529']
# Norine
# []
# precher
# []
# petiotes
# []
# dpeche-toi
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7813319']
# Jean-
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# epluchc
# []
# Ha-
# M1ON
# []
# Desiree Mlonte
# ['https://www.wikidata.org/wiki/Q467925']
# Bonl
# []
# Cellier
# ['https://www.wikidata.org/wiki/Q21501975']
# Norine
# []
# Saint-Brunelle
# []
# Desirde
# []
# Norine
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ditle pere
# Roux
# ['https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157']
# Perpetue, vous ne savez qu'oflenser le
# bon Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Garde-les
# []
# Jcan-Claude
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q34943']
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Par
# 1
# []
# meme
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# la Bassette
# []
# maniere
# []
# La Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Gaspard
# []
# giroflees h
# ['https://www.wikidata.org/wiki/Q122894']
# M1ON VILLAGtE.
#
# []
# Gaspard
# []
# gca
# []
# Gaspardl
# []
# Norine
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Gaspard
# []
# Desiree
# ['https://www.wikidata.org/wiki/Q467925']
# mere
# Leroy
# ['https://www.wikidata.org/wiki/Q13586859', 'https://www.wikidata.org/wiki/Q1068404']
# endever
# []
# Dsirce
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Jacque-
# line
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Rose
# MON VILLAGE
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q465227']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Rose d'un ton pique
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q11247037']
# Gaspard
# []
# petiot
# Roux
# []
# Norine
# []
# MION
# ['https://www.wikidata.org/wiki/Q16043593']
# fieu de Toinon
# []
# Reste
# []
# Jean Claude
# ['https://www.wikidata.org/wiki/Q7521081', 'https://www.wikidata.org/wiki/Q34943']
# Woilh
# []
# MIais
# []
# Lasl
# []
# Lasl
# []
# Jeanneton
# []
# long.s--------------
# MION
# ['https://www.wikidata.org/wiki/Q16043593']
# Voila
# ['https://www.wikidata.org/wiki/Q2351943']
# renom.-
#
# []
# Jeanneton
# []
# Voila
# ['https://www.wikidata.org/wiki/Q2351943']
# Lasl
# []
# Jeanneton
# []
# Lasl
# []
# Jeanneton
# []
# Jeanneton
# []
# MION
# ['https://www.wikidata.org/wiki/Q16043593']
# hel petiote erpctue
# []
# pre Roux
# ['https://www.wikidata.org/wiki/Q679614', 'https://www.wikidata.org/wiki/Q201157']
# Mlarie
# []
# la mere Rem-
# blay
# ['https://www.wikidata.org/wiki/Q13586859', 'https://www.wikidata.org/wiki/Q841355']
# ca la religion
# ['https://www.wikidata.org/wiki/Q16', 'https://www.wikidata.org/wiki/Q9174']
# mre
# ['https://www.wikidata.org/wiki/Q586615']
# Je ne suis mi dcja
# ['https://www.wikidata.org/wiki/Q253276']
# Yer-
# []
# Vermand
# ['https://www.wikidata.org/wiki/Q994711']
# l ditle
# dragon
# ['https://www.wikidata.org/wiki/Q7559']
# Pierre t
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q191118']
# Remblay
# []
# voila
# ['https://www.wikidata.org/wiki/Q2351943']
# Ch' sole
# ['https://www.wikidata.org/wiki/Q11688697']
# Ch' mouguet flourit
# []
# ch' lepene
# []
# leu
# ['https://www.wikidata.org/wiki/Q42395']
# Eussiez
# []
# Pierre-Louis Gosseu
# ['https://www.wikidata.org/wiki/Q56540250']
# Venez
# []
# Venez
# []
# Venez
# []
# Ayez
# []
# c0te de Saint-Quentin
# ['https://www.wikidata.org/wiki/Q182744']
# ftt-cel
# La
# ['https://www.wikidata.org/wiki/Q1052736']
# garcons
# []
# Nom-de-Nom
# []
# Roux i Jean-Claude
# ['https://www.wikidata.org/wiki/Q201157', 'https://www.wikidata.org/wiki/Q3164791']
# ca
# []
# pcut-etre
# le dragon
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q7559']
# Allez
# []
# Jean-MION
# []
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# HIel pere Nom-de-Nom
# ['https://www.wikidata.org/wiki/Q5478058']
# Chaus-
# son-Chaussette
# ['https://www.wikidata.org/wiki/Q180309']
# Ml'
# ['https://www.wikidata.org/wiki/Q2539']
# Sylvain
# ['https://www.wikidata.org/wiki/Q16281827']
# Nom-de-Nom
# []
# k
# M1ON
# []
# Nom-de-Nom
# []
# Adonc
# []
# Gaspard
# []
# dragon
# ['https://www.wikidata.org/wiki/Q7559']
# Tous-
# saint
# []
# dc loup
# ['https://www.wikidata.org/wiki/Q6689698']
# Fut-cel
# ['https://www.wikidata.org/wiki/Q182132', 'https://www.wikidata.org/wiki/Q1052736']
# Je
# sille Mledor
# []
# Carriere-Fondue
# ['https://www.wikidata.org/wiki/Q5046378', 'https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q190531']
# battaisle briquet
# ['https://www.wikidata.org/wiki/Q18516840']
# Mlon
# finot
# []
# ca
# []
# ca
# vous sauterait h
# ['https://www.wikidata.org/wiki/Q16', 'https://www.wikidata.org/wiki/Q122894']
# garel Por-
# ['https://www.wikidata.org/wiki/Q5522763']
# mon de-
# bourroir
# []
# Qu'est-ce donc que tu avais fait de ton
# briquet?
# ['https://www.wikidata.org/wiki/Q18516840']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# ton debour-
# roir
#
# []
# embarrasl
# []
# M0N
# []
# Je le tournais,
# je le...
#
# []
# Jean Claude
# ['https://www.wikidata.org/wiki/Q7521081', 'https://www.wikidata.org/wiki/Q34943']
# ca
# []
# Norine
# []
# Nom-
# de-Nom
# []
# I Cette
# main-l
# []
# Iroid
# []
# MIon
# ['https://www.wikidata.org/wiki/Q16043593']
# Mlon
# []
# triple galop
# ['https://www.wikidata.org/wiki/Q698092']
# vai
# ['https://www.wikidata.org/wiki/Q168548']
# I
# []
# VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# Te voila
# []
# queueln
#
# []
# le dragon
# ['https://www.wikidata.org/wiki/Q7559']
# Jean Claude
# ['https://www.wikidata.org/wiki/Q7521081', 'https://www.wikidata.org/wiki/Q34943']
# Suflit1
#
# 1I
# 1
# I
# 1
#
# []
# L----
# MON VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# Rose d'un air aimable
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q2637489']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Allons
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# routel
#
# []
# ca
# []
# Armandine
# []
# ca
# me frapperait d'un coup mortel
# ['https://www.wikidata.org/wiki/Q16', 'https://www.wikidata.org/wiki/Q45382']
# Nom-de-Nom
# []
# Armandine
# []
# ca
# []
# les peres
# ['https://www.wikidata.org/wiki/Q57410']
# meres surtout
# []
# mere Remblay
# ['https://www.wikidata.org/wiki/Q13586859']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# kemy
# []
# ...
#
# []
# Ia Remy
# ['https://www.wikidata.org/wiki/Q367208']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# VIILLAGE
# []
# Norine
# []
# Defunt
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Mlor-
# lincourt;
# []
# prechant
# []
# Le bon Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# ble
# []
# plein so-i.---
# M0N VILLAGE
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q465227']
# ventru
# []
# lFaut
# []
# tra-
# vailler
# []
# sainte
# Vierge Marie
# ['https://www.wikidata.org/wiki/Q59220438']
# Morlin-
# []
# Ml Leonie
# ['https://www.wikidata.org/wiki/Q2539', 'https://www.wikidata.org/wiki/Q6526597']
# lcgitime
# []
# Mlais
# []
# meme de la
# ['https://www.wikidata.org/wiki/Q978']
# Morlincoutt
# []
# communel
#
# []
# Mlorlincourtl
# []
# eit
# ['https://www.wikidata.org/wiki/Q3516835']
# dfunt
# []
# LLL
# ['https://www.wikidata.org/wiki/Q1716401']
# g-----
# MO N
# ['https://www.wikidata.org/wiki/Q1581']
# voila
# ['https://www.wikidata.org/wiki/Q2351943']
# Lasl
# []
# Jeacquet
# []
# Dicu
# []
# amel
# h
# IIIMON VILLAGE
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q465227']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# dejh tard
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jeac-
# quet
# []
# Artaban
# []
# endever
# []
# sij'
# ['https://www.wikidata.org/wiki/Q2875922']
# Norine
# []
# ma-
# niere
# []
# pres
# []
# Plaisant lh
# ['https://www.wikidata.org/wiki/Q9325']
# Pierre le dragon
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q7559']
# ca
# []
# Expliquez
# []
# ccole
# []
# Pierre et de la Rose
# ['https://www.wikidata.org/wiki/Q40747', 'https://www.wikidata.org/wiki/Q519034']
# sit0t la veillee
# ['https://www.wikidata.org/wiki/Q191118']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Norine
# []
# blmer
# []
# bDoucettement
# []
# Rose ou-
# vrit laporte de sa chambre
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# LL-.----------==-=x=-MON
# []
# Gaspard
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# baisers-l.
#
# ['https://www.wikidata.org/wiki/Q320980']
# h Norine,
# ['https://www.wikidata.org/wiki/Q122894']
# venir?MON V1LLAGE
# []
# ous
# []
# ous avons
# aides autrefois
# []
# voila
# ['https://www.wikidata.org/wiki/Q2351943']
# Maman
# ['https://www.wikidata.org/wiki/Q180887']
# conmne
# []
# Ml'aimeras-tu
# []
# Rose?
# ['https://www.wikidata.org/wiki/Q519034']
# meme
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# MIais
# []
# Ohl
# ['https://www.wikidata.org/wiki/Q902860']
# Jure-moi
# []
# MON VILLA GE
# ['https://www.wikidata.org/wiki/Q18711']
# dragon
# ['https://www.wikidata.org/wiki/Q7559']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# peeer
# []
# Jure
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# i Norine
# []
# I-
# MON VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# ca
# []
# Iais
# ['https://www.wikidata.org/wiki/Q10533272']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# .A9
# Ayant repondu
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# ca
# []
# ve-1
# MION
# []
# ma mere elle-meme
# ['https://www.wikidata.org/wiki/Q13586859', 'https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q978']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Norine
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# gca
# []
# saintete
# []
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# ca
# []
# garcon
# []
# garcon
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Rose, les hommes, de meme
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q548924', 'https://www.wikidata.org/wiki/Q978']
# Pierre
#
# ['https://www.wikidata.org/wiki/Q40747']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# ma mere
# ['https://www.wikidata.org/wiki/Q13586859']
# viensl
#
# []
# Rose, ma promise
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q1426138']
# h Jean-
# Claude
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q34943']
# Norine
# []
# Toinon
# []
# Morlincourt Vous
# ['https://www.wikidata.org/wiki/Q1336814']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M. Cran
# ['https://www.wikidata.org/wiki/Q8441', 'https://www.wikidata.org/wiki/Q5181875']
# Voila
# ['https://www.wikidata.org/wiki/Q2351943']
# Oui-dal
# Claude
# ['https://www.wikidata.org/wiki/Q1139389']
# Toinon
# []
# Jean-
# lMON VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# queussi-qucumi
# ['https://www.wikidata.org/wiki/Q180309']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Morlincourt tot
# ['https://www.wikidata.org/wiki/Q1336814', 'https://www.wikidata.org/wiki/Q230100']
# t0t
# ['https://www.wikidata.org/wiki/Q191118']
# M. Ceran
# ['https://www.wikidata.org/wiki/Q8441']
# Feuil-
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Therese
# ['https://www.wikidata.org/wiki/Q2298877']
# Ceran
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ete
# []
# Norine
# []
# Toinon
# []
# MIO N VIILI.AGIE
# ['https://www.wikidata.org/wiki/Q18039976']
# gcns inconnus
# []
# moi
# vous aimerai
# Et Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Ceran
# []
# VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ca:
# - A
# []
# Notre mere
# ['https://www.wikidata.org/wiki/Q13586859']
# MION
# ['https://www.wikidata.org/wiki/Q16043593']
# bon Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# vOUS
# []
# M. Ce-
# ran
# ['https://www.wikidata.org/wiki/Q8441']
# Fa-
# vette
# []
# - Qu'
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# mi-
# sres
# []
# Jeacquet
# []
# Jeacquet
# []
# M.
# ['https://www.wikidata.org/wiki/Q8441']
# Jeacquet
# []
# HIier
# []
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# M. Ccran
# ['https://www.wikidata.org/wiki/Q8441']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Ohl
# ['https://www.wikidata.org/wiki/Q902860']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Ceran
# []
# Mlaria
# []
# mere
# ['https://www.wikidata.org/wiki/Q13586859']
# MIaria
# []
# Brlee
# []
# c0td
# []
# Lcs
# ['https://www.wikidata.org/wiki/Q1542187']
# M0N
# []
# de-
# gott
# ['https://www.wikidata.org/wiki/Q65079587']
# MIadame
# []
# votrc tcmps
# []
# aillcurs
# []
# lille
# ['https://www.wikidata.org/wiki/Q19516']
# tourneuse
# []
# planta
# lh
# ['https://www.wikidata.org/wiki/Q9325']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# catimini
# []
# Savoyard
# []
# bSavoyard-l
# ['https://www.wikidata.org/wiki/Q180309']
# VILLAGI
# []
# ILe
# []
# garcon
# []
# Savoyard
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Ceran
# []
# Jean-
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# presider
# []
# Ceran
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ca
# []
# ter
# ['https://www.wikidata.org/wiki/Q31482']
# etrc
# []
# Mor-
# linval
# []
# ous observez
#
# []
# Saint-Brunelle
# []
# vicux hu-
# guenot
# []
# pere Roux
# ['https://www.wikidata.org/wiki/Q5478058', 'https://www.wikidata.org/wiki/Q201157']
# voilha
# []
# MON v1LLAGE
# []
# Ceran
# []
# Jean-
# []
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# Norine
# []
# La Rose
# ['https://www.wikidata.org/wiki/Q519034']
# M. Ceran
# ['https://www.wikidata.org/wiki/Q8441']
# MIais
# []
# cher
# []
# aupauvre
# []
# village.1
# MON ILLAGE
# []
# madame
# lamairesse
# ['https://www.wikidata.org/wiki/Q17146837']
# M. Ceran
# ['https://www.wikidata.org/wiki/Q8441']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# L-------
# []
# LE CURE
# ----bI
# ia
# MONSIEUI
# ['https://www.wikidata.org/wiki/Q1144476']
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# mechancetes debitees
# []
# h Norine
# ['https://www.wikidata.org/wiki/Q122894']
# veillee.1
# []
# Si la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Saint-Brunelle
# []
# maniere
# []
# notre
# mairessc:
# - Mlonsieur
# []
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# I8
# MiON
# ['https://www.wikidata.org/wiki/Q2479238']
# Mlonsieur
# []
# Paques fleuries
# []
# beni
# ['https://www.wikidata.org/wiki/Q233169']
# Cra-
# chez
# []
# vaila
# []
# alii
# in opprohrium
# ['https://www.wikidata.org/wiki/Q4726594']
# Mes chers freresl
# a e vaisvous parler de l'enfer
# ['https://www.wikidata.org/wiki/Q1213581']
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# mes freres
# ['https://www.wikidata.org/wiki/Q5280186']
# pCechd
# []
# Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# per visuml Avez-vous ete
# gourmands, ivrognes avez-ous
# ['https://www.wikidata.org/wiki/Q7111291']
# souill
# []
# VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# ...
# Vive
# []
# Apies
# []
# peres sans
# ['https://www.wikidata.org/wiki/Q57410']
# sces sabotsl
# Adonc
# []
# B
# ['https://www.wikidata.org/wiki/Q618']
# MON VILLAGkE.
# ['https://www.wikidata.org/wiki/Q235']
# meme
# []
# ca
# []
# les peres, les meres
# ['https://www.wikidata.org/wiki/Q57410']
# ca
# []
# cOnnaissent
# []
# Morlinval
# []
# VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# voila
# ['https://www.wikidata.org/wiki/Q2351943']
# Gaspard
# []
# fieu de Toinon
# []
# Allons
# []
# C'est vrai, trois noces l Tout
# Saint-Brunelle
# ['https://www.wikidata.org/wiki/Q27477490']
# seraitl
# Ahl voila
# ['https://www.wikidata.org/wiki/Q4695154', 'https://www.wikidata.org/wiki/Q2351943']
# Comprenez
# []
# Voilh
# []
# ca
# []
# Brugnon
# []
# pre
# []
# entrcr
# []
# ide
# []
# pre Brugnon
# ['https://www.wikidata.org/wiki/Q679614']
# Saint-Brunelle
# []
# pre Brugnon
# ['https://www.wikidata.org/wiki/Q679614']
# Adonc
# []
# pre Brugnon
# ['https://www.wikidata.org/wiki/Q679614']
# couvent Brugnon
# []
# Toussaint derniere
# ['https://www.wikidata.org/wiki/Q945051']
# pre Brugnon
# ['https://www.wikidata.org/wiki/Q679614']
# A32
# ['https://www.wikidata.org/wiki/Q381232']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# annee
# ca
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# tcmps
# []
# estafilader
# []
# cipiter
# []
# ILambin
# []
# Perpetue
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# MON VILILAGE
# []
# Rou, berger
# ['https://www.wikidata.org/wiki/Q2875909', 'https://www.wikidata.org/wiki/Q450598']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# dcux tetes
# de huguenots
# []
# Adonc
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# vitement
# []
# attendl
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jcan-Claude cn empoi-
# gnant
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q34943', 'https://www.wikidata.org/wiki/Q148']
# ca
# []
# Houx allougea
# ['https://www.wikidata.org/wiki/Q1344443']
# Jugezl ca
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ime de contrebandel
# ['https://www.wikidata.org/wiki/Q11976980']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# T'arreteras
# []
# Ah bicn ouil
# ['https://www.wikidata.org/wiki/Q869406']
# lepere Roux
# ['https://www.wikidata.org/wiki/Q201157']
# causel dit
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ca
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# enl
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Saint-
# Brunelle
# ['https://www.wikidata.org/wiki/Q4978987']
# convenul
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# gca
# []
# h Jean-Claude
# ['https://www.wikidata.org/wiki/Q122894', 'https://www.wikidata.org/wiki/Q3164791']
# bDizy l'avare
# ['https://www.wikidata.org/wiki/Q17049755']
# lcs
# ['https://www.wikidata.org/wiki/Q1542187']
# Jean-Claude:
#
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# bonheurs.1
# []
# Clarisse Manot
# ['https://www.wikidata.org/wiki/Q733658', 'https://www.wikidata.org/wiki/Q2777738']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Croyez-le
# []
# honnetel
# Son
# []
# dte vitement regle
# ['https://www.wikidata.org/wiki/Q2901296']
# MIais
# []
# IHIommes-sans-Tetes
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q180309']
# rabachcra
# []
# ha-
# sard
# []
# fosses
# Poulains
# ['https://www.wikidata.org/wiki/Q243260']
# furolles
# []
# LES N0CES
# IY
# LES NOCES
# []
# Norine
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Perpelue
# []
# en-
# fourne
# []
# defourne
# []
# pre Roux
# ['https://www.wikidata.org/wiki/Q679614', 'https://www.wikidata.org/wiki/Q201157']
# honnele
# []
# M0N
# []
# retroussee
# []
# Voila
# ['https://www.wikidata.org/wiki/Q2351943']
# Allons  je met-
#
# ['https://www.wikidata.org/wiki/Q1045105']
# Garnissons nos poches
# []
# D6siree
# []
# Norine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# M0N
# []
# voixt emotionnee:
# - Faut
# ['https://www.wikidata.org/wiki/Q5438363']
# quii
# - Pardine
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# chambre-l
# []
# Rose
# et Norine
# ['https://www.wikidata.org/wiki/Q519034']
# avisee
# []
# Cel-
# lier
# []
# Jcan-Claude
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q34943']
# ba-
# biller
# ['https://www.wikidata.org/wiki/Q47458707']
# vis pa-
# raitre
# ['https://www.wikidata.org/wiki/Q203767']
# Norine
# []
# Rose au bras du maitre d'ecole
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q3084981', 'https://www.wikidata.org/wiki/Q16859830']
# VILLAGI
# []
# ca... longtemps,
# les uns au bout des autres... de meme
# []
# Lamariee
# []
# cha-
# cun
# []
# MION
# ['https://www.wikidata.org/wiki/Q16043593']
# bient0t dites
# []
# monsicur lc curds'
# []
# gargcon
# []
# Adonc
# []
# ruban
# delie
# ['https://www.wikidata.org/wiki/Q2171475']
# cctte ceremonie
# ['https://www.wikidata.org/wiki/Q858216']
# D6siree
# []
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# Jean-
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# bDizy
# []
# cria Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Et Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# gouailla Dizy
# ['https://www.wikidata.org/wiki/Q741536']
# Mlais
# []
# corteges defilent
# []
# pcut
# []
# meme
# []
# Tichons, plutot
# que de blmer
# []
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# premire
# []
# Me voili encore obligd
# ['https://www.wikidata.org/wiki/Q619989']
# reconnais-s''--
# []
# marie
# []
# pte ar-
# rosdd'un verre debon cidre
# ['https://www.wikidata.org/wiki/Q468474', 'https://www.wikidata.org/wiki/Q65088791', 'https://www.wikidata.org/wiki/Q16258506']
# ct bient0t
# ['https://www.wikidata.org/wiki/Q261247', 'https://www.wikidata.org/wiki/Q191118']
# T1I
# []
# enfeuiller
# []
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Me voil maintenant
# ['https://www.wikidata.org/wiki/Q619989']
# letemps
# []
# moi
#
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ma-
# niere
# []
# Baptiste
# ['https://www.wikidata.org/wiki/Q63538437']
# Jean-Claude
# et
# ['https://www.wikidata.org/wiki/Q3164791']
# Norine
# []
# ca
#
# ['https://www.wikidata.org/wiki/Q16']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ca
# []
# MI0N
# []
# Baptiste
# ['https://www.wikidata.org/wiki/Q63538437']
# Baptiste
# ['https://www.wikidata.org/wiki/Q63538437']
# Tour
# ['https://www.wikidata.org/wiki/Q117934']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ca:
#
# []
# tcher
# []
# betes
# []
# pre Roux
# ['https://www.wikidata.org/wiki/Q679614', 'https://www.wikidata.org/wiki/Q201157']
# Pater
# et cinq Ave
# ['https://www.wikidata.org/wiki/Q2319007']
# Norine
# []
# Roseet
# []
# ILe
# []
# tc dchangd
# ['https://www.wikidata.org/wiki/Q18221']
# M0N
# []
# atten-
# tionnee
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# gce
# ['https://www.wikidata.org/wiki/Q646545']
# ccole
# []
# La Rose
# est devenue bonne couturire
# ['https://www.wikidata.org/wiki/Q519034']
# Inoi
# ['https://www.wikidata.org/wiki/Q30587709']
# Cellicr
# []
# VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# peres
# ['https://www.wikidata.org/wiki/Q57410']
# meres
# []
# Rosc
# []
# Pardonnez-lui
# []
# Vive
# []
# Rose, le gars
# Decnis
# ['https://www.wikidata.org/wiki/Q519034', 'https://www.wikidata.org/wiki/Q531813']
# mre Denis
# ['https://www.wikidata.org/wiki/Q586615', 'https://www.wikidata.org/wiki/Q244380']
# Norine
# []
# Jean-
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# ca
# []
# CE 0U'IL V0US
# ['https://www.wikidata.org/wiki/Q484876', 'https://www.wikidata.org/wiki/Q1204']
# M0N
# []
# Pierre
# ['https://www.wikidata.org/wiki/Q40747']
# Pierrette
# ['https://www.wikidata.org/wiki/Q7192558']
# paratt
# calme
# []
# attachec
# []
# ete
# []
# 7a r rIIImne
# []
# Cran
# ['https://www.wikidata.org/wiki/Q5181875']
# celte idee-la
# []
# Jean Claude
# ['https://www.wikidata.org/wiki/Q7521081', 'https://www.wikidata.org/wiki/Q34943']
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Ceran
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Ca
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Gaspard
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# onl
# ['https://www.wikidata.org/wiki/Q7071915']
# Mlais
# []
# Gaspard
# []
# Jacqueline
# ['https://www.wikidata.org/wiki/Q391321']
# Roux
# 0us
# ['https://www.wikidata.org/wiki/Q201157']
# Clarisse Manot
# ['https://www.wikidata.org/wiki/Q733658', 'https://www.wikidata.org/wiki/Q2777738']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# montagne blanche
# []
# ca
# []
# manibre
# []
# ta-
# quinerie
# []
# ca
# []
# ca
# []
# colonne Vend0me
# ['https://www.wikidata.org/wiki/Q1234920']
# Manot
# ['https://www.wikidata.org/wiki/Q2777738']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# ca
# []
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# ca
# []
# aupres
# []
# decoree
# []
# Clarisse
# ['https://www.wikidata.org/wiki/Q733658']
# Palais-Royal
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q2102344']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Mlorlincourt
# []
# meme
# les gens
# ['https://www.wikidata.org/wiki/Q899409']
# beeusee de butiues
# []
# Mlorlin-
# []
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# ricn
# []
# MIais
# []
# Jean
# Claude
# ['https://www.wikidata.org/wiki/Q7521081', 'https://www.wikidata.org/wiki/Q34943']
# deshonore Saint-Brunelle Fal-
# lait demander
# []
# voila
# ['https://www.wikidata.org/wiki/Q2351943']
# decide h
# ['https://www.wikidata.org/wiki/Q5249148', 'https://www.wikidata.org/wiki/Q122894']
# Monsieur
# ['https://www.wikidata.org/wiki/Q1092777']
# malhon-
# ntete
# []
# Parisien
# []
# Monsicur, vous devez
# []
# Jean-Claude, tu as joliment
# rpondul
# ['https://www.wikidata.org/wiki/Q3164791']
# Parisiens
# ['https://www.wikidata.org/wiki/Q3072544']
# pre Roux
# ['https://www.wikidata.org/wiki/Q679614', 'https://www.wikidata.org/wiki/Q201157']
# camaradel1
# LA M01SSONl
#
# []
# Sortez des maisons
# ['https://www.wikidata.org/wiki/Q536986']
# Les blcs
# []
# Alerte
# ['https://www.wikidata.org/wiki/Q22661961']
# Bonnets blancs
# []
# Alertel
# []
# rendez-yous
# ['https://www.wikidata.org/wiki/Q180309']
# dejeu-
# nant
# []
# pa-
# rieront
# []
# annee
# []
# oN VILLAGIE
# []
# ca
# []
# ble
# []
# pays.r---
# 182
# MON VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# Morlinval
# []
# Morlincourt
# ['https://www.wikidata.org/wiki/Q1336814']
# oh tegarde
# ['https://www.wikidata.org/wiki/Q204']
# ca rcjouit
# l'eil
# ['https://www.wikidata.org/wiki/Q883068']
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# Assurde
# []
# moissols
# de la Fance
# ['https://www.wikidata.org/wiki/Q17927077']
# ble
# []
# gca
# []
# meme
# []
# ble
# []
# grene
# ['https://www.wikidata.org/wiki/Q5607460']
# haut le picd!
# ['https://www.wikidata.org/wiki/Q18027543']
# piedl
# []
# MION
# ['https://www.wikidata.org/wiki/Q16043593']
# Plut0t fuait
# []
# Est
# ['https://www.wikidata.org/wiki/Q663187']
# En voil une de chaleur
# []
# sommes-nous
# harassdsl
# []
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Pourvu
# []
# ne186
# OY VILLAGE
# []
# epidemiel
# Fut-cel
# ['https://www.wikidata.org/wiki/Q182132', 'https://www.wikidata.org/wiki/Q1052736']
# Ceran
# []
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# lune
# ['https://www.wikidata.org/wiki/Q3518248']
# ble
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Cadet Lambin
# ['https://www.wikidata.org/wiki/Q61668028', 'https://www.wikidata.org/wiki/Q56244845']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# ble
# []
# Voilh
# []
# Mon pauvre fieul
# []
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# meres
# []
# La d6solation de la desolation
# ['https://www.wikidata.org/wiki/Q3815359']
# h Saint-Brunellel
#
# ['https://www.wikidata.org/wiki/Q122894']
# Qu'une bonne ame
# ['https://www.wikidata.org/wiki/Q4824411']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# ca
# []
# Cel-
# lier
# []
# enmoi-
# meme
# []
# commissio
# []
# MI
# ['https://www.wikidata.org/wiki/Q11660']
# Ceran
# []
# MI0N
# []
# Cran
# ['https://www.wikidata.org/wiki/Q5181875']
# Ceran
# []
# Fran-
# ciers
# []
# Ceran
# []
# Monsieur Ceran
# ['https://www.wikidata.org/wiki/Q1092777']
# Monsieur Ceran
# ['https://www.wikidata.org/wiki/Q1092777']
# ouil
#
# []
# tete
# []
# Tenez
# []
# Allons
# []
# Courez
# []
# Ceran
# []
# Parlez-moi
# []
# cctte bete
# []
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# MIa-
#
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Ceran
# []
# The-
# rese
# []
# unl
# []
# Ceran
# []
# madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Ceran
# []
# je1
# -
#
# MON VILLAGE
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q235', 'https://www.wikidata.org/wiki/Q465227']
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# guerissez
# []
# guerissez
#
# []
# Saint-Brunelle des noces
# ['https://www.wikidata.org/wiki/Q27477490']
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Allez
# []
# allez
# []
# Jean-
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# Ceran
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Saint-Brunelle, on
# se detournait de ceux qui avaient l'cpidemie
# []
# -kl
# -
# 1
# 1
# I0N VILLAGE
# ['https://www.wikidata.org/wiki/Q180309', 'https://www.wikidata.org/wiki/Q465227']
# ma-
# lades
# []
# Lasl
# []
# guere d'ecus
# ['https://www.wikidata.org/wiki/Q36919', 'https://www.wikidata.org/wiki/Q273724']
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# renie-Dieu
# ['https://www.wikidata.org/wiki/Q3027560']
# a Honnete j'ai vecu, honnete je mourrai
# []
# ca
# []
# Venus
# ['https://www.wikidata.org/wiki/Q313']
# Berenice
# ['https://www.wikidata.org/wiki/Q196653']
# Cassiopeel
# Le maltre d'cole
# ['https://www.wikidata.org/wiki/Q334001']
# fillel
# []
# madame
# la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# srs
# []
# Madame
# ['https://www.wikidata.org/wiki/Q17146837']
# repetez-le
# []
# autrefoisl
# []
# meme laisir
# []
# Expliquez
# []
# voila
# ['https://www.wikidata.org/wiki/Q2351943']
# mures
# []
# II
# L.
# presss
# ['https://www.wikidata.org/wiki/Q320980']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# madame la mairesse
# ['https://www.wikidata.org/wiki/Q17146837', 'https://www.wikidata.org/wiki/Q56539707']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# la Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Voilh
# []
# Messieurs
# []
# du Nord
# ['https://www.wikidata.org/wiki/Q12661']
# Messieurs
# []
# Parisien connaft
# []
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# de-
# []
# VILLAGE
# ['https://www.wikidata.org/wiki/Q465227']
# du Nord
# ['https://www.wikidata.org/wiki/Q12661']
# lFrance
# []
# meme
# []
# pou-r----
# s--
# ['https://www.wikidata.org/wiki/Q13609402', 'https://www.wikidata.org/wiki/Q180309']
# Nord
# ['https://www.wikidata.org/wiki/Q12661']
# Messieurs
# []
# AUX TRAINS DE TRAVAIL
# ['https://www.wikidata.org/wiki/Q1931128', 'https://www.wikidata.org/wiki/Q453819', 'https://www.wikidata.org/wiki/Q7835862']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# la France
# ['https://www.wikidata.org/wiki/Q142']
# Roux
# ['https://www.wikidata.org/wiki/Q201157']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# destination1
# MION VILLAGE
# ['https://www.wikidata.org/wiki/Q16043593', 'https://www.wikidata.org/wiki/Q465227']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Jopine
# []
# dix'jours
# []
# dCctour
# []
# Rose
# ['https://www.wikidata.org/wiki/Q519034']
# pdcti-
# tion-li
# ['https://www.wikidata.org/wiki/Q347']
# Jean-Claude
# ['https://www.wikidata.org/wiki/Q3164791']
# Va, ma Rose
# ['https://www.wikidata.org/wiki/Q519034']
# Remblay
# []
# M'
# ['https://www.wikidata.org/wiki/Q160669']
# Remblay
# []
# Jean-
# u-
# []
# Claude
# ['https://www.wikidata.org/wiki/Q34943']
# ET S0UHAITS
# t
# PRILRL ET
# ['https://www.wikidata.org/wiki/Q191118']
# pre oux
# ['https://www.wikidata.org/wiki/Q679614']
# Paris
# ['https://www.wikidata.org/wiki/Q90']
# s0UII
# []
# lcs pays oi vous pla-
# cerez
# ['https://www.wikidata.org/wiki/Q1542187', 'https://www.wikidata.org/wiki/Q3184003']
# M. Ceran
# ['https://www.wikidata.org/wiki/Q8441']
# lh-dessusAotyde-
# E.:c
# fuble mon chapeau
# ['https://www.wikidata.org/wiki/Q9325']
# Wotre
# []
# L
# FRUCTUBUx CBLLIER
# ['https://www.wikidata.org/wiki/Q6203']

# %% [markdown]
# ## Nous comparons ensuite les URLs obtenues lors du linking pour les entités en contexte et hors contexte

# %%
import json
import spacy  # version 3.5
import glob
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte
    
def tableau(data):
    # Création du tableau récapitulatif
    df = pd.DataFrame(data)
    print (df)
    table_latex = df.to_latex(index=False)
    print(table_latex)

modele=["sm","md","lg"]
path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
donnee = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        compteur = 0
        intersect = 0
        nb_entite = 0

        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            
            liste_url_entourage = []
            liste_url_entite = []
            doc3 = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
                for d in liste_url_entite:
                    if d in liste_url_entourage:
                        intersect += 1
                    compteur += 1
            nb_entite += 1
        
        non = compteur - intersect
        print("La REN de Spacy a identifié", nb_entite, "entités")
        print("L'entity linker a repéré", compteur, "entités")
        print("Il y a", intersect, "éléments communs")
        print("Il y a", non, "éléments qui ne sont pas en commun")

        donnee.append({
            "Modèle": mod,
            "Fichier": path,
            "Entités reconnues par Spacy": nb_entite,
            "Entités reconnues par l'Entity Linker": compteur,
            "Entités avec URLs communes ": intersect,
            "Entités avec URLs non communes": non
        })
tableau(donnee)
# Out:
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# La REN de Spacy a identifié 790 entités
# L'entity linker a repéré 653 entités
# Il y a 602 éléments communs
# Il y a 51 éléments qui ne sont pas en commun
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# La REN de Spacy a identifié 1256 entités
# L'entity linker a repéré 1072 entités
# Il y a 817 éléments communs
# Il y a 255 éléments qui ne sont pas en commun
#   Modèle                                            Fichier  \
# 0     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 1     md  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
#
#    Entités reconnues par Spacy  Entités reconnues par l'Entity Linker  \
# 0                          790                                    653
# 1                         1256                                   1072
#
#    Entités avec URLs communes   Entités avec URLs non communes
# 0                          602                              51
# 1                          817                             255
# \begin{tabular}{llrrrr}
# \toprule
# Modèle &                                            Fichier &  Entités reconnues par Spacy &  Entités reconnues par l'Entity Linker &  Entités avec URLs communes  &  Entités avec URLs non communes \\
# \midrule
#     md & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                          790 &                                    653 &                          602 &                              51 \\
#     md & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                         1256 &                                   1072 &                          817 &                             255 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_3388/539984079.py:15: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   table_latex = df.to_latex(index=False)

# %% [markdown]
# ## Nous avons étudié le nombre d'URL associé à chaque entité

# %%
import spacy 
import glob
import pandas as pd

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte
def tableau(data):
    # Création du tableau récapitulatif
    df = pd.DataFrame(data)
    print (df)
    table_latex = df.to_latex(index=False)
    print(table_latex)

modele=["sm","md","lg"]

path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
data = []
tab_entite = []
for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load("fr_core_news_" + mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        print("Entrée:", path)
        texte = lire_fichier(path)
        doc = nlp(texte)
        compteur = 0
        intersect = 0
        nb_entite = 0

        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            #print ("pour l'entité", entite)
            liste_url_entourage = []
            liste_url_entite = []
            doc3 = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                liste_url_entourage.append(url_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                liste_url_entite.append(url_entite)
                #print("Il y a",len(liste_url_entite),"url correspondantes. Ce sont", liste_url_entite)
                tab_entite.append({
                    "Modèle": mod,
                    "Fichier": path,
                    "Entité reconnue par la REN de SpaCy": entite,
                    "nb d'entités repérées par l'Entity Linker pour cette entité": len(liste_url_entite),
                    "url(s) liée(s) par l'Entity Linker pour cette entité": liste_url_entite,
                })

            for d in liste_url_entite:
                if d in liste_url_entourage:
                    intersect += 1
                compteur += 1
            nb_entite += 1
        
        non = compteur - intersect
        #print("La REN de Spacy a identifié", nb_entite, "entités")
        #print("L'entity linker a repéré", compteur, "entités")
        #print("Il y a", intersect, "éléments communs")
        #print("Il y a", non, "éléments qui ne sont pas en communs")
        
        data.append({
            "Modèle": mod,
            "Fichier": path,
            "Entités Spacy": nb_entite,
            "Entités Entity Linker": compteur,
            "Entités communes": intersect,
            "Entités non communes": non
        })
        
        
tableau(tab_entite)
# Out:
# Pour le modèle: sm
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# Pour le modèle: md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# Pour le modèle: lg
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
#      Modèle                                            Fichier  \
# 0        sm  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 1        sm  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 2        sm  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 3        sm  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# 4        sm  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/RE...
# ...     ...                                                ...
# 4169     lg  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 4170     lg  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 4171     lg  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 4172     lg  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
# 4173     lg  ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OC...
#
#             Entité reconnue par la REN de SpaCy  \
# 0                                 Norine Duclos
# 1                                   Jean-Claude
# 2                                          Rose
# 3                                     emplis-le
# 4                                     Désirée !
# ...                                         ...
# 4169                                     Claude
# 4170                                      Paris
# 4171                                   M. Ceran
# 4172  lh-dessusAotyde-\nE.:c\nfuble mon chapeau
# 4173  lh-dessusAotyde-\nE.:c\nfuble mon chapeau
#
#       nb d'entités repérées par l'Entity Linker pour cette entité  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 4169                                                  1
# 4170                                                  1
# 4171                                                  1
# 4172                                                  1
# 4173                                                  2
#
#      url(s) liée(s) par l'Entity Linker pour cette entité
# 0             [https://www.wikidata.org/wiki/Q21450529]
# 1              [https://www.wikidata.org/wiki/Q3164791]
# 2               [https://www.wikidata.org/wiki/Q519034]
# 3               [https://www.wikidata.org/wiki/Q180309]
# 4               [https://www.wikidata.org/wiki/Q945470]
# ...                                                 ...
# 4169             [https://www.wikidata.org/wiki/Q34943]
# 4170                [https://www.wikidata.org/wiki/Q90]
# 4171              [https://www.wikidata.org/wiki/Q8441]
# 4172  [https://www.wikidata.org/wiki/Q180309, https:...
# 4173  [https://www.wikidata.org/wiki/Q180309, https:...
#
# [4174 rows x 5 columns]
# /tmp/ipykernel_3388/2682745239.py:13: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   table_latex = df.to_latex(index=False)
# \begin{tabular}{lllrl}
# \toprule
# Modèle &                                            Fichier &                Entité reconnue par la REN de SpaCy &  nb d'entités repérées par l'Entity Linker pour cette entité & url(s) liée(s) par l'Entity Linker pour cette entité \\
# \midrule
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                      Norine Duclos &                                                  1 &          [https://www.wikidata.org/wiki/Q21450529] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                          emplis-le &                                                  1 &            [https://www.wikidata.org/wiki/Q180309] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                          Désirée ! &                                                  1 &            [https://www.wikidata.org/wiki/Q945470] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Cellier &                                                  1 &          [https://www.wikidata.org/wiki/Q21501975] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Désirée &                                                  1 &            [https://www.wikidata.org/wiki/Q945470] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                 réserve de la Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           bon Dieu &                                                  1 &           [https://www.wikidata.org/wiki/Q3027560] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Basset &                                                  1 &           [https://www.wikidata.org/wiki/Q4868070] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Voilà &                                                  1 &          [https://www.wikidata.org/wiki/Q18395683] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Rose ! &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Hardi &                                                  1 &          [https://www.wikidata.org/wiki/Q15444128] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                         Jacqueline &                                                  1 &            [https://www.wikidata.org/wiki/Q391321] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Denis &                                                  1 &            [https://www.wikidata.org/wiki/Q244380] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Désirée &                                                  1 &            [https://www.wikidata.org/wiki/Q945470] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                         mère Leroy &                                                  1 &           [https://www.wikidata.org/wiki/Q1068404] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Désirée &                                                  1 &            [https://www.wikidata.org/wiki/Q945470] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                         Jacqueline &                                                  1 &            [https://www.wikidata.org/wiki/Q391321] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                  Pierre, le dragon &                                                  1 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                  Pierre, le dragon &                                                  2 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                           Trois cavaliers de renom &                                                  1 &            [https://www.wikidata.org/wiki/Q162990] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                           Trois cavaliers de renom &                                                  1 &            [https://www.wikidata.org/wiki/Q162990] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Marie &                                                  1 &          [https://www.wikidata.org/wiki/Q59220438] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Vermand &                                                  1 &            [https://www.wikidata.org/wiki/Q994711] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                          de France &                                                  1 &               [https://www.wikidata.org/wiki/Q142] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                      Saint-Quentin &                                                  1 &            [https://www.wikidata.org/wiki/Q182744] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Ah ! &                                                  1 &            [https://www.wikidata.org/wiki/Q869406] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                Chausson-Chaussette &                                                  1 & [https://www.wikidata.org/wiki/Q2961656, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                Chausson-Chaussette &                                                  2 & [https://www.wikidata.org/wiki/Q2961656, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Sylvain &                                                  1 &          [https://www.wikidata.org/wiki/Q16281827] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                          Toussaint &                                                  1 &            [https://www.wikidata.org/wiki/Q945051] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                    Carrière-Fondue &                                                  1 & [https://www.wikidata.org/wiki/Q461464, https:/... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                    Carrière-Fondue &                                                  2 & [https://www.wikidata.org/wiki/Q461464, https:/... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                    Carrière-Fondue &                                                  3 & [https://www.wikidata.org/wiki/Q461464, https:/... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                    Et ton amadou ? &                                                  1 &           [https://www.wikidata.org/wiki/Q4739090] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                  De mon autre main &                                                  1 &              [https://www.wikidata.org/wiki/Q1670] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Ah ! &                                                  1 &            [https://www.wikidata.org/wiki/Q869406] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Ah ! &                                                  1 &            [https://www.wikidata.org/wiki/Q869406] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Remy &                                                  1 &            [https://www.wikidata.org/wiki/Q367208] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Remy &                                                  1 &            [https://www.wikidata.org/wiki/Q367208] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Vieux &                                                  1 &           [https://www.wikidata.org/wiki/Q1013514] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Cellier &                                                  1 &          [https://www.wikidata.org/wiki/Q21501975] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                               Bonsoir la compagnie &                                                  1 &           [https://www.wikidata.org/wiki/Q5155503] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Voilà &                                                  1 &          [https://www.wikidata.org/wiki/Q18395683] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Le bon Dieu &                                                  1 &           [https://www.wikidata.org/wiki/Q3027560] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                sainte Vierge Marie &                                                  1 &          [https://www.wikidata.org/wiki/Q59220438] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Roux &                                                  1 &            [https://www.wikidata.org/wiki/Q201157] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                     Plaisant là n' &                                                  1 &             [https://www.wikidata.org/wiki/Q21199] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                   Pierre le dragon &                                                  1 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                   Pierre le dragon &                                                  2 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                               Pierre et de la Rose &                                                  1 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                               Pierre et de la Rose &                                                  2 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Maman &                                                  1 &            [https://www.wikidata.org/wiki/Q180887] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                             laisse-moi mon courage &                                                  1 &            [https://www.wikidata.org/wiki/Q208160] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Oh ! &                                                  1 &           [https://www.wikidata.org/wiki/Q2724303] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                  Pierre, je t'aime &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             là-bas &                                                  1 & [https://www.wikidata.org/wiki/Q180309, https:/... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             là-bas &                                                  2 & [https://www.wikidata.org/wiki/Q180309, https:/... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Oh ! &                                                  1 &           [https://www.wikidata.org/wiki/Q2724303] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                             Pierre, et dépêche-toi &                                                  1 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                             Pierre, et dépêche-toi &                                                  2 & [https://www.wikidata.org/wiki/Q40747, https://... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Oh ! &                                                  1 &           [https://www.wikidata.org/wiki/Q2724303] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            vois-tu &                                                  1 & [https://www.wikidata.org/wiki/Q4802575, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            vois-tu &                                                  2 & [https://www.wikidata.org/wiki/Q4802575, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            vois-tu &                                                  3 & [https://www.wikidata.org/wiki/Q4802575, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                                 M' &                                                  1 &            [https://www.wikidata.org/wiki/Q160669] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Ma foi &                                                  1 &           [https://www.wikidata.org/wiki/Q5464146] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              Bah ! &                                                  1 &            [https://www.wikidata.org/wiki/Q633132] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                       Moi je blâme &                                                  1 &           [https://www.wikidata.org/wiki/Q1770346] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                       donne-moi ton cœur de soldat &                                                  1 &            [https://www.wikidata.org/wiki/Q604532] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                              viens &                                                  1 &            [https://www.wikidata.org/wiki/Q735276] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Pierre &                                                  1 &             [https://www.wikidata.org/wiki/Q40747] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Thérèse &                                                  1 &           [https://www.wikidata.org/wiki/Q3527366] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  1 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  2 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           Oui-da ! &                                                  1 & [https://www.wikidata.org/wiki/Q7110327, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           Oui-da ! &                                                  2 & [https://www.wikidata.org/wiki/Q7110327, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           Oui-da ! &                                                  3 & [https://www.wikidata.org/wiki/Q7110327, https:... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                             Claude &                                                  1 &             [https://www.wikidata.org/wiki/Q34943] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                     queussi-queumi &                                                  1 &            [https://www.wikidata.org/wiki/Q180309] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Morlincourt &                                                  1 &           [https://www.wikidata.org/wiki/Q1336814] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  1 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  2 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                            Thérèse &                                                  1 &           [https://www.wikidata.org/wiki/Q3527366] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Ah ! &                                                  1 &            [https://www.wikidata.org/wiki/Q869406] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  1 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  2 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                                Mes &                                                  1 &          [https://www.wikidata.org/wiki/Q16948281] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           bon Dieu &                                                  1 &           [https://www.wikidata.org/wiki/Q3027560] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  1 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  2 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                      Allons donc ! &                                                  1 &           [https://www.wikidata.org/wiki/Q4733092] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                 madame la mairesse &                                                  1 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                 madame la mairesse &                                                  2 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  1 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                           M. Céran &                                                  2 & [https://www.wikidata.org/wiki/Q8441, https://w... \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     sm & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/REF... &                                               Oh ! &                                                  1 &           [https://www.wikidata.org/wiki/Q2724303] \\
# ...
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                                ble &                                                  1 &           [https://www.wikidata.org/wiki/Q4925706] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                                gca &                                                  1 &          [https://www.wikidata.org/wiki/Q59638131] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               meme &                                                  1 &               [https://www.wikidata.org/wiki/Q978] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                    Argent l maudit argent\textbackslash nEn voil &                                                  1 & [https://www.wikidata.org/wiki/Q2301367, https:... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                    Argent l maudit argent\textbackslash nEn voil &                                                  2 & [https://www.wikidata.org/wiki/Q2301367, https:... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                              bl s'6-\textbackslash ngrenait..... &                                                  1 &             [https://www.wikidata.org/wiki/Q25362] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                          pere Roux &                                                  1 & [https://www.wikidata.org/wiki/Q5478058, https:... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                          pere Roux &                                                  2 & [https://www.wikidata.org/wiki/Q5478058, https:... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                             berger &                                                  1 &            [https://www.wikidata.org/wiki/Q450598] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                       Cadet Lambin &                                                  1 & [https://www.wikidata.org/wiki/Q61668028, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                       Cadet Lambin &                                                  2 & [https://www.wikidata.org/wiki/Q61668028, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                                ble &                                                  1 &           [https://www.wikidata.org/wiki/Q4925706] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                          la France &                                                  1 &               [https://www.wikidata.org/wiki/Q142] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                h Saint-Brunellel\textbackslash n &                                                  1 &            [https://www.wikidata.org/wiki/Q122894] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                   h Saint-Brunelle &                                                  1 &            [https://www.wikidata.org/wiki/Q122894] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                     Monsieur Ceran &                                                  1 &           [https://www.wikidata.org/wiki/Q1092777] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               tete &                                                  1 &            [https://www.wikidata.org/wiki/Q388242] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                     Allons, je vais me pre-\textbackslash nparer &                                                  1 &           [https://www.wikidata.org/wiki/Q4733092] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                           M. Ceran &                                                  1 &              [https://www.wikidata.org/wiki/Q8441] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                             MIa-\textbackslash ndame la mairesse &                                                  1 & [https://www.wikidata.org/wiki/Q901407, https:/... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                             MIa-\textbackslash ndame la mairesse &                                                  2 & [https://www.wikidata.org/wiki/Q901407, https:/... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                           M. Ceran &                                                  1 &              [https://www.wikidata.org/wiki/Q8441] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                            la Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                 madame la mairesse &                                                  1 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                 madame la mairesse &                                                  2 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                 madame la mairesse &                                                  1 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                 madame la mairesse &                                                  2 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                      Jean-\textbackslash nClaude &                                                  1 &             [https://www.wikidata.org/wiki/Q34943] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                           M. Ceran &                                                  1 &              [https://www.wikidata.org/wiki/Q8441] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               meme &                                                  1 &               [https://www.wikidata.org/wiki/Q978] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                         pere\textbackslash nRoux &                                                  1 &           [https://www.wikidata.org/wiki/Q5478058] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                           Berenice &                                                  1 &            [https://www.wikidata.org/wiki/Q196653] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               cole &                                                  1 &            [https://www.wikidata.org/wiki/Q334001] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                            la Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                  Action de separer &                                                  1 &           [https://www.wikidata.org/wiki/Q2634111] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                            la Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                 madame la mairesse &                                                  1 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                 madame la mairesse &                                                  2 & [https://www.wikidata.org/wiki/Q17146837, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                            la Rose &                                                  1 &            [https://www.wikidata.org/wiki/Q519034] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                            du Nord &                                                  1 &             [https://www.wikidata.org/wiki/Q12661] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                              Paris &                                                  1 &                [https://www.wikidata.org/wiki/Q90] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                                ION &                                                  1 &           [https://www.wikidata.org/wiki/Q3387750] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               meme &                                                  1 &               [https://www.wikidata.org/wiki/Q978] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                            pou-r----\textbackslash ns--\textbackslash n208\textbackslash nIO &                                                  1 & [https://www.wikidata.org/wiki/Q13609402, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                            pou-r----\textbackslash ns--\textbackslash n208\textbackslash nIO &                                                  2 & [https://www.wikidata.org/wiki/Q13609402, https... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                               Nord &                                                  1 &             [https://www.wikidata.org/wiki/Q12661] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                              AUX TRAINS DE TRAVAIL &                                                  1 & [https://www.wikidata.org/wiki/Q453819, https:/... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                              AUX TRAINS DE TRAVAIL &                                                  2 & [https://www.wikidata.org/wiki/Q453819, https:/... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                          pere Roux &                                                  1 & [https://www.wikidata.org/wiki/Q5478058, https:... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                          pere Roux &                                                  2 & [https://www.wikidata.org/wiki/Q5478058, https:... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                             berger &                                                  1 &            [https://www.wikidata.org/wiki/Q450598] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                        Jean-Claude &                                                  1 &           [https://www.wikidata.org/wiki/Q3164791] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                         negligence &                                                  1 &            [https://www.wikidata.org/wiki/Q160070] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                       pere Remblay &                                                  1 &           [https://www.wikidata.org/wiki/Q5478058] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                             Claude &                                                  1 &             [https://www.wikidata.org/wiki/Q34943] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                              Paris &                                                  1 &                [https://www.wikidata.org/wiki/Q90] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &                                           M. Ceran &                                                  1 &              [https://www.wikidata.org/wiki/Q8441] \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &          lh-dessusAotyde-\textbackslash nE.:c\textbackslash nfuble mon chapeau &                                                  1 & [https://www.wikidata.org/wiki/Q180309, https:/... \\
#     lg & ../DATA/ELTeC-Fra\_2023/ADAM/ADAM\_krakenbase/OCR... &          lh-dessusAotyde-\textbackslash nE.:c\textbackslash nfuble mon chapeau &                                                  2 & [https://www.wikidata.org/wiki/Q180309, https:/... \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Entités qui n'ont pas les mêmes URLs liées en contexte et hors contexte

# %%
import spacy  # version 3.5
import glob
import pandas as pd
import os

def lire_fichier(chemin):
    with open(chemin, "r", encoding="utf-8") as fichier:
        texte = fichier.read()
        return texte
def tableau(data):
    # Création du tableau récapitulatif
    df = pd.DataFrame(data)
    print (df)
    table_latex = df.to_latex(index=False)
    print(table_latex)

modele=["fr_core_news_sm","fr_core_news_md","fr_core_news_lg", "en_core_web_sm", "en_core_web_md", "en_core_web_lg"]


path_corpora = "../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/*/*.txt"
donnee = []
tab_entite = []
tab_noncommun = []
tab_basename = []

for mod in modele:
    print("Pour le modèle:", mod, "\n")
    nlp = spacy.load(mod)
    nlp.add_pipe("entityLinker", last=True)
    for path in glob.glob(path_corpora):
        basename = os.path.basename(path)
        if basename in tab_basename :
            pass
        else :
            tab_basename.append(basename)
        print("Entrée:", path)
        texte = lire_fichier(path)
        
        
        doc = nlp(texte)
        compteur = 0
        intersect = 0
        nb_entite = 0
        

        for ent in doc.ents:
            contexte = str(texte[ent.start_char-50:ent.start_char])+str(ent.text)+ str(texte[ent.end_char:ent.end_char+50])
            entite = ent.text
            #print ("pour l'entité", entite)
            liste_url_entourage = []
            liste_url_entite = []
            liste_label_entourage = []
            liste_label_entite = []
            liste_description_entourage = []
            liste_description_entite = []
            doc3 = nlp(entite)
            doc2 = nlp(contexte)
            for ent in doc2._.linkedEntities:
                url_entourage = ent.get_url()
                label_entourage = ent.get_label()
                description_entourage = ent.get_description()
                liste_url_entourage.append(url_entourage)
                liste_label_entourage.append(label_entourage)
                liste_description_entourage.append (description_entourage)
                liste_description_entite = []
                concat_entourage = nom_entourage," : ",description_entourage
                #print (concat_entourage)
                liste_concat_entourage.append(concat_entourage)
            for ent in doc3._.linkedEntities:
                url_entite = ent.get_url()
                nom_entite = ent.get_label()
                description_entite = ent.get_description()
                concat_entite = str(nom_entite) + " : " + description_entite
                #print (concat_entite)
                liste_url_entite.append(url_entite)
                liste_concat_entite.append(concat_entite)
                #print("Il y a",len(liste_url_entite),"url correspondantes. Ce sont", liste_url_entite)
                tab_entite.append({
                    "Modèle": mod,
                    "Fichier": basename,
                    "Entité reconnue par la REN de SpaCy": entite,
                    "nb d'entités repérées par l'Entity Linker": len(liste_url_entite),
                    "Entités reconnues par l'Entity Linker": liste_concat_entite,
                })

            for d in liste_url_entite:
                if d in liste_url_entourage:
                    intersect += 1
                else :
                    tab_noncommun.append({
                    "Modèle": mod,
                    "Fichier": basename,
                    "Entité reconnue par la REN de SpaCy": entite,
                    "entités reconnues pour l'Entity Linker sans contexte": liste_concat_entite,
                    "entités reconnues pour l'Entity Linker en contexte": liste_concat_entourage,
                })
                compteur += 1
            nb_entite += 1
        
        non = compteur - intersect
        #print("La REN de Spacy a identifié", nb_entite, "entités")
        #print("L'entity linker a repéré", compteur, "entités")
        #print("Il y a", intersect, "éléments communs")
        #print("Il y a", non, "éléments qui ne sont pas en communs")
        
        donnee.append({
            "Modèle": mod,
            "Fichier": basename,
            "Entités Spacy": nb_entite,
            "Entités Entity Linker": compteur,
            "Entités communes": intersect,
            "Entités non communes": non
        })
tableau(tab_entite)
#tableau(donnee)
#tableau(tab_noncommun)
# Out:
# Pour le modèle: fr_core_news_sm
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# Pour le modèle: fr_core_news_md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# Pour le modèle: fr_core_news_lg
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# Pour le modèle: en_core_web_sm
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/OCR/ADAM_Mon-village_Kraken-base.txt
# Pour le modèle: en_core_web_md
#
# Entrée: ../DATA/ELTeC-Fra_2023/ADAM/ADAM_krakenbase/REF/ADAM_Mon-village_REF.txt
